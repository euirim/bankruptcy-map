# %%
import sys
import os
import re
sys.path.append("..")

import spacy
nlp = spacy.load("en_core_web_lg")

from utils.case import Case, DocketEntry, Document, Party
DATA_LOCATION = "../data/results_nysb_all_chap_11"

# %%
def find_repeat(s):
    tokens = s.split()
    if len(tokens) <= 1:
        return s
    if len(tokens) == 4:
        if tokens[0] == tokens[2] and tokens[1] == tokens[3]:
            return tokens[0]+" "+tokens[1]
    if len(tokens) == 6:
        if tokens[0] == tokens[3] and tokens[1] == tokens[4] and tokens[2] == tokens[5]:
            return tokens[0]+" "+tokens[1]+" "+tokens[2]
    return s

# %%
#aggregate orgs mentioned in file
remove_words = ['po box', 'el', 'signature'] #words to remove from an entity
def clean_org(orig):
    cleaned = orig.lower().strip()
    cleaned = re.sub('  ', ' ', cleaned)
    cleaned = re.sub('[^A-Za-z0-9 ]+', '', cleaned)
    cleaned = find_repeat(cleaned)
    
    no_spaces = re.sub(' +', '', cleaned)
    if (len(no_spaces) == 0):
        return ""
    #all the same letter (i.e. 'iii iii iii')
    if (no_spaces == len(no_spaces) * no_spaces[0]):
        return ""
    
    # remove remove_words from entity
    for word in remove_words:
        cleaned = re.sub(word, '', cleaned)
    
    tokens = cleaned.split()
    if len(tokens) <= 1:
        return ""
    if len(max(tokens, key=len)) <= 2: #no token longer than 2 characters
        return ""
    if tokens[0] == "the":
        return ""
    for token in tokens: #get rid of zip codes -> presume address
        if token.isdigit() and len(token) == 5:
            return ""
    
    #get rid of trailing whitespace
    cleaned = cleaned.rstrip()
    if cleaned.isdigit():
        return ""
    return cleaned

blacklist = ["court", "united states", 'debtors', 'social security', 'motion', "employer", "debtor",
             'form', 'docket', 'state of', 'agreement', 'floor', 'street', 'taxpayer', 'petition', "fee", "number"]

def most_freq_orgs(ents):
    orgs = {}
    for ent in ents:
        if ent.label_ == "ORG":
            org = clean_org(ent.text)
            #blacklist certain org words:
            for word in blacklist:
                if word in org:
                    org = ""
                    break
            if org == "":
                continue
            if org in orgs:
                orgs[org] += 1
            else:
                orgs[org] = 1
    return orgs

# %%
#aggregate people mentioned in file
remove_words_ppl = ["signature"]

def clean_name(orig):
    cleaned = orig.lower().strip()
    cleaned = re.sub('  ', ' ', cleaned)
    cleaned = re.sub('[^A-Za-z ]+', '', cleaned)
    
    tokens = cleaned.split()
    if (len(tokens) <= 1): 
        return "" 
    if len(max(tokens, key=len)) <= 2: #no token longer than 2 characters
        return ""
    
    # remove remove_words from entity
    for word in remove_words_ppl:
        cleaned = re.sub(word, '', cleaned)
    
    cleaned = find_repeat(cleaned)
        
    #all the same letter (i.e. 'iii iii iii')
    no_spaces = re.sub(' +', '', cleaned)
    if (no_spaces == len(no_spaces) * no_spaces[0]):
        return ""
    
    #get rid of trailing whitespace
    cleaned = cleaned.rstrip()
    return cleaned

blacklist_ppl = ["court", "clerk", "name of", "debtor", "united states"]

def most_freq_persons(ents):
    people = {}
    for ent in ents:
        if ent.label_ == "PERSON":
            person = clean_name(ent.text)
            #blacklist certain org words:
            for word in blacklist_ppl:
                if word in person:
                    person = ""
                    break
            if person == "":
                continue
            if person in people:
                people[person] += 1
            else:
                people[person] = 1
    return people

# %%
# move potential non-people in ppl to org 
company_indicator = ["inc", "llc", "llp", "corp"]

#adds name, count to dict
def add_to_dict(d, name, count):
    if name in d:
        d[name] = d[name] + count
    else:
        d[name] = count
    return d

#move things that are actually orgs from ppl to orgs
def move_ppl_to_orgs(orgs,ppl):
    to_delete = []
    for person, count in ppl.items():
        tokens = person.split()
        if tokens[-1] in company_indicator:
            orgs = add_to_dict(orgs,person,count)
            to_delete.append(person)
    for delete in to_delete:
        del ppl[delete]
    return orgs, ppl

# %%
def print_top_3(A):
    top_keys = sorted(A, key=A.get, reverse=True)[:3]
    for key in top_keys:
        print (A[key],key)

# %%
def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]

#returns if it's close (bool), string before, string after (one will become the other)
def close_enough(s1,s2):
    dist = levenshteinDistance(s1,s2)
    #one contained in another
    if s1 in s2 and dist < 8:
        return True, s2, s1
    if s2 in s1 and dist < 8:
        return True, s1, s2
    #edit distance is small
    if dist < 3:
        return True, s1, s2 #this is an arbitrary choice
    return False, None, None
    
#combines similar entities
def agg_dict(A):
    print(A)
    combined = {} # before:after
    
    for s1 in A.keys():
        for s2 in A.keys():
            if s1 == s2: 
                continue
            is_close, before, after = close_enough(s1,s2)
            if s1 == after:
                continue
            if is_close:
                # make sure not a loop
                if after not in combined or combined[after] != before:
                    combined[before] = after
                    print(before,"->", after)
#                 if combined[after] == before:
#                     continue
#                 combined[before] = after
#                 print(before,"->", after)
                
    to_delete = []
    for before, after in combined.items():
        item = after
        count = A[before]
        A = add_to_dict(A, item, count)
        to_delete.append(before)
    for delete in to_delete:
        del A[delete]
    print(A)
    return A

# %%
# EXTRACT ORGS AND PPL INTO MAPS
file_to_orgs = {} # maps file name to a map of orgs + counts
file_to_ppl = {} # maps file name to a map of people + counts

for file in os.listdir(DATA_LOCATION):
    doc = nlp(open(os.path.join(DATA_LOCATION, file)).read())
    orgs = most_freq_orgs(doc.ents)
    ppl = most_freq_persons(doc.ents)
    orgs, ppl = move_ppl_to_orgs(orgs, ppl)
    print(file)
    print("ORGS:", orgs)
    print("PPL:", ppl)
    print("\n")
    file_to_ppl[file] = ppl
    file_to_orgs[file] = orgs
# Out:
# 6938010
# ORGS: {'3 clearing bank': 1, 'tm garden inc': 1, 'paolo secondo': 1, 'tenant of residential property': 1, 'garden inc': 1}
# PPL: {'allan l gropper': 1, 'lawrence morrison': 1, 'paolo secondo': 1}
#
#
# 16798867
# ORGS: {'ybrant media acquisition': 1, 'ybrant digital limited': 2, 's sanford p rosen': 1, 'rosen  associates': 1, 'pc 747': 1}
# PPL: {'sanford p rosen': 1}
#
#
# 6949417
# ORGS: {'life extension realty llc': 3, 'limited liability company': 1, 'limited liability partnership': 1, ' health care business': 1, ' commodity broker': 1, ' clearing bank': 1, 'north american industry classification system': 1, 'shenwick  associates': 2, 'state fill': 1, 'sl green realty corp': 1, 'pas owner llc': 1, 'green realty corp': 1, 'lexington avenue': 1, 'litigant couns for life extension realty llc': 1}
# PPL: {'eric braverman': 2, 'james h shenwick': 2, 'matthew leonardi': 1, 'stempel bennett': 1}
#
#
# 11079394
# ORGS: {'mf global holdings ltd': 2, 'plan administrator': 1, 'sapere cta fund': 1, 'global holdings ltd': 1, 'global finance usa inc': 1, 'mf global capital llc': 2, 'global market services llc': 2, 'mf global holdings usa inc': 2, 'mf global finance usa inc': 1, 'mf global fx clear llc': 1, 'mf global inc': 2, 'sapere cta': 1, 'litigation trustee': 1, 'litigation trust': 2, 'louis j f': 1, 'decision and order': 1, 'colead class couns': 1, 'individual defendants sapere cta fund': 1, 'mf global': 1, 'mf globals': 2, 'eo insurers': 1, 'mfg plaintiffs': 1, 'securities lead plaintiffs': 1, 's nader': 1}
# PPL: {'bruce bennett': 1, 'michael schneidereit': 1, 'jane rue wittstein': 1, 'ev flonv t t f': 1, 'nader tavakoli': 2, 'deangelis v corzine': 1, 'jon s corzine': 2, 'bradley abelow': 1, 'henri steenkamp': 1, 'vinay mahaj': 1, 'edith obrien': 1, 'james c francis': 1, 'graber decl': 2, 'settlement furthermore': 1, 'salvatore j graziano': 1, 'javier bleichmar': 1}
#
#
# 11078625
# ORGS: {'morrison  foerster llp brett h miller': 1, 'plan administrator': 1, 'sun hung kai commodities limited': 3, 'see ag': 2, 'craig a damast morrison  f oerster llp': 1}
# PPL: {'melissa a hager': 2, 'craig a damast': 2, 'i adjourned matters': 1, 'brett h miller': 1}
#
#
# 6881149
# ORGS: {'westchester pending ridge et al': 1, 'mosods chofetz chaim inc': 1, 'a hazardous material': 1, 'highview road': 2, 'aryeh zaks': 1, 'highview road suffern': 1, 'tax consolidation group': 1, 'mosdos chofetz chaim inc': 3, 'a mitch l greene': 1, 'robinson brog leinwand greene et al': 1}
# PPL: {'munish weintraub': 1, 'mayer zaks': 1, 'aryeh zaks': 1, 'print name': 1, 'r bankr': 1}
#
#
# 63245566
# ORGS: {'john llc': 1, 'goldberg weprin finkel goldstein llp': 2}
# PPL: {'sean h': 1, 'kevin j nash': 2, 'paul schwartzberg': 1, 'eastern time': 1, 'sean h lane': 1}
#
#
# 6937855
# ORGS: {'statement of financial affairs': 1}
# PPL: {'frank a ortiz tel': 1, 'norma e ortiz': 2, 'martha de j': 1, 'martin glenn': 1}
#
#
# 6871731
# ORGS: {'boston generating': 7, 'sithe boston generating': 1, 'exon boston generating': 1, 'fifth avenue': 2, ' single asset real estate': 1, 'llp  railroad': 1, ' clearing bank': 1, 'tenant of residential preperty': 1, 'boston generatin llc': 1, 'latham  watkins llp d': 1, 'states code': 1, 'ebg holdings llc': 5, 'fore river devopment': 1, 'mystic devopment': 1, 'bg new england power services': 1, 'bg boston services': 1, 'llc action by': 1, 'a daware limited liability company': 1, 'constlation holdings inc': 2, 'constlation energy group inc': 1, 'retention of professionals': 1, 'latham  watkins llp': 3, 'jp morgan securities': 1, 'perla weinberg partners': 1, 'brown rudnick llp': 1, 'fti consulting': 1, 'anderson kill  olick': 1, 'authorized representative of the company': 1, 'joint administration requested': 2, 'department of creditor': 5, 'agency loan operations': 1, 'credit suisse': 1, 'administrative agent for the lenders': 1, 'lipton rosen  katz': 1, 'harold olsen stroock  stroock  lavan llp': 1, 'distrigas of massachusetts': 1, 'stroock  stroock  lavan llp': 1, 'commerce road': 2, 'trade debt': 2, 'mitsubishi power systems inc': 1, 'spectra energy': 1, 'pension benet guaranty corporation': 1, 'national grid': 1, 'exxon mobile': 1, 'borden  remington corporation': 1, 'integrated it solutions': 1, 'agent or department of creditor familiar with claim': 1, 'city clerk': 1, 'general couns': 5, 'overland road waltham': 1, 'ma 024511729': 1, 'solutions center': 1, 'new england controls inc': 1, 'clean harbors': 1, 'avenida empresa': 1, 'control components inc': 1, 'dept 2544': 1, 'chalmers  kubeck north air industrial park': 1, 'atlantic contracting  special': 1, 'general couns 55': 1, 'standard  poors': 1, 'mechanical dynamics  analysis': 1, 'american blvd': 1, 'adams valves inc': 1, 'stallion companies': 1, 'mitchl services inc': 1, 'capco crane  hoist inc': 1, 'keystone engineering corp': 1, 'joint administration': 2, 'ebg holdings': 1, 'eguityholder percent ownership': 2, 'new astoria generating company holdings': 1, 'us power generating company us': 1, 'madison dearborn capital partners iv': 1, 'ownership of new astoria generating company holdin': 1}
# PPL: {'boston generatin': 1, 'j baker': 1, 'robert j rosenberg': 1, 'caroline a reckler': 1, 'kimberly a posin': 1, 'jeff hunter': 8, 'financial ofcer': 4, 'brown rudnick': 2, 'r bankr': 1, 'helen fung': 1, 'michael s benn': 1, 'scott k charles wachtell': 1, 'benjamin son credit suisse': 1, 'charles parker': 1, 'robert hyland': 1, 'koji hasegawa': 1, 'peggy fero': 1, 'gregory l ebel': 1, 'israel goldowitz': 1, 'michael matarazzo': 1, 'john parker': 1, 'rex w tillerson': 1, 'robert bogan': 1, 'thomas h oconnor': 1, 'alan brilliant': 1, 'jim wood': 1, 'tom ramundo': 1, 'manseld ma': 1, 'alan s mckim': 1, 'longwater dr': 1, 'elise st': 1, 'scott mccoy': 1, 'paul camara': 1, 'michael e berlan': 1, 'daniel webster': 1, 'power generatin com': 1}
#
#
# 6938026
# ORGS: {'new hope software inc': 16, 'orange county pools inc': 1, 'zipcode zipcode': 1, 'heat care business': 1, ' recognition ofa foreign corporation': 1, '       iii 149': 1, 'orane count pools inc': 1, 'exhibit c': 1, 'tenant of residential property': 1, 'genova  malin': 1, 'firm name': 1, 'wiccopee construction inc': 2, 'american express open line of credit po': 1, 'lincoln parkway fort wayne': 1, 'american express business platinum card': 2, 'ge commercial dist': 2, 'il 606754651 ltd financial services': 1, 'collections for bank of america': 1, 'international leisure': 1, 'swimline corporation 191': 2, 'wilbar international': 2, 'strong industries inc': 1, 'hayward pool products': 2, 'nj 071935218': 1, 'seaboard industries': 2, 'jetline products': 1, 'schedule d  creditors': 1, '191017346 value 3': 1, 'internal revenue service lien': 1, 'comptroller of the currency': 1, 'board of governors': 1, 'nys dept': 1, 'taxation and finance payroll tax bankruptcy section': 1, 'schedule e report': 1, 'lf4fu bankruptcy2015': 1, 'schedule f creditors holding': 3, 'american express open line of credit': 1, 'certied drive': 1, 'hayward industries inc': 1, 'international leisure products': 1, 'jetline products inc': 1, 'construction ac': 1, 'ii ltd financial services': 1, 'lp collections for bank of america 7322': 1, 'master spas inc': 1, 'strong industries': 1, 'box 108': 1, 'swimn play inc': 1, '1v2 canada': 1, 'freditnrc i': 1}
# PPL: {'oran e': 1, 'filing fee': 1, 'thomas genova': 2, 'wappingers falls': 1, 'vincent moscatello': 3, 'r bankr': 4, 'john doe': 4, 'van winkle avenue': 1, 'vin van vic': 2, 'related data': 1, 'van winkle avenue hawthorne': 1}
#
#
# 6881147
# ORGS: {'mosdos chofetz chaim inc': 5, 'citizens bank': 1, 'alarm co': 1, 'general property maintenance': 1, 'fire sprinkler maintenance': 1, 'silverman foundation': 1, 'nys dept': 1, 'tax  finance': 1, 'cloverdale lane monsey': 1, 'golard drive monsey': 1, 'orange and rockland utilities inc': 1, 'w rte': 1, 'moti ectric inc': 1, 'bedford ave': 1, 'wldone insulation': 1, 'koznitz dr': 1}
# PPL: {'rabbi aryeh zaks': 1, 'dis uted s': 1, 'ezra beyman': 1, 'michael leibov': 1, 'aryeh zaks': 2, 'abe waldman': 1, 'i rabbi aryeh zaks': 1}
#
#
# 60314722
# ORGS: {'setoffs list': 1, 'nautilus capital llc v': 1, 'dates total': 1, 'law office': 1, 'health care': 1, 'none financial institution': 1, 'statement of financial affairs for nonindividuals filing for bankruptcy': 1}
# PPL: {'julio e portilla': 1, 'avi douek': 1, 'mylene liggett': 3}
#
#
# 57363983
# ORGS: {'bowling green': 1}
# PPL: {}
# 6864620
# ORGS: {'henry inc': 2, 'chief executive': 1, 'morgan stanley senior funding inc': 1, 'administrative agent and syndication agent': 1, 'morgan stanley': 1, 'financial distress and efforts to raise capital': 1, 'dorman  fawcett': 5, 'dorman  fawcetts': 1, 'washington national airport 1 aviation circle': 1, 'indianapolis airport authority': 1, 'international air terminal llc': 1, 'mineta san jose international airport': 1, 'customer data': 2, 'widepoint corporation': 1, 'henry incorporated': 1, 'andll identity solutions': 1, 'difrancesco bateman coley': 1, 'kunzman davis  lehrer': 1, 'bain capital valhalla partners': 1, 'boston office 8000': 1, 'hig ventures': 1, 'rho capital partners': 1, 'suite 1350': 1, 'oak investment partners': 1, 'bertram capital management llc operational research consultants inc': 1, 'waples mill san mateo': 1, 'west fid road san francisco': 1}
# PPL: {'james e moroney': 4, 'steven brill': 1, 'ciistnmer data': 1, 'john f kennedy': 1, 'ronald regan': 1, 'h weir cook memorial drive': 1, 'henry apa': 1, 'todd ruback': 1, 'fred sturgis': 1, 'robert grady': 1, 'h kairouz': 1, 'ren riley': 1, 'jason booma': 1, 'john siegel': 1, 'jim fleming': 1, 'vic parker': 1, 'david ibnale': 1, 'morton binn fairfax': 1}
#
#
# 6884839
# ORGS: {'waterscape resort llc': 1, 'usc section': 1, 'alexander hamilton custom house': 1, 'bowling green': 1, 's stuart m bernstein': 1}
# PPL: {}
#
#
# 11068846
# ORGS: {'morrison  foerster llp 1290 avenue': 2, 'holdings ltd': 1, 'mf global finance usa inc': 2, 'mf global capital llc': 2, 'global market services': 1, 'global holdings usa inc': 2, 'mf global holdings ltd': 2, 'global holdings ltd': 3, 'lyondl chemical company et al': 1, 'frontier airlines holdings inc': 1, 'fortunofine jewry': 1, 'movie gallery inc': 1, 'tweeter home entmt group inc': 1, 're dana corp': 1, 'mnsicland holding corp': 1, 'dphi corp': 1, 'winndixie stores': 1, 'commodity futures trading commission': 1, 'no prior re uest': 1, 'mf global fx': 1, 'clear llc': 1, 'mf global inc': 1}
# PPL: {'brett h miller': 2, 'lorenzo marinuzzi': 2, 'melissa a hager': 2, 'r bankr': 2, 'louis j freeh': 2, 'laurie r f erber pursuant to local bankruptcy rule': 1, 'd del': 1, 's brett h miller': 1, 'j freeh': 1, 'martin glenn': 1}
#
#
# 6864627
# ORGS: {'wls fargo center': 2, 'mn 554023901 tephone': 2, 'henry inc': 1, 'buyer of the assets': 1}
# PPL: {'stephen m mertz': 2, 'gary s lee': 1, 'dennis p orr': 2, 'renee l freimuth': 2, 'henry incorporated': 2, 's gary s lee gary s lee': 1}
#
#
# 6932789
# ORGS: {' commodity broker  clearing bank': 1, 'exhibit c': 1, 'tenant of residential property': 1, 'omc inc': 4, 'firm name': 1, 'authorized individual': 1, 'adt security services billing bankruptcy dept': 1, 'north centre ave': 1, 'ste 400': 1, 'advanced testing  balancing': 1, 'micha drive syosset': 1, 'air distribution enterprises': 1, 'allstate insulation corp': 1, 'american express': 1, 'amtrust north america po': 1, 'anthony thomas boiler corp': 1, 'apple auto  truck care inc': 1, 'att mobility': 1, 'aurora bank fsb': 1, 'bank of america': 1, 'merrill lynch': 1, 'north lasalle st': 1, 'sales  1453': 1, 'brooklyn fan  blower': 1, 'brown  brown of ny inc 595': 1, 'raildroadavenue closter': 1, ' 4804 bld': 1, 'na 701': 1, 'costco wholesale': 1, 'cywiak  co': 1, 'danilo carting co': 1, 'deutsche bank trust comp amer': 1, 'donnly mechanical': 1, 'encompass insurance co po': 1, 'equitable ste 4044': 1, 'exterminare pest control': 1, 'exxon mobil': 1, 'federal express': 1, 'oser avenue hauppauge': 1, 'ford motor credit po': 1, 'ford motor credit company': 1, 'ford motor credit company po': 1, 'fl 336313111': 1, 'gm insulation': 1, 'hess plaze woodbridge': 1, 'imperial damper': 1, 'independant testing  balance': 1, 'merrick road': 1, 'internal revenue service': 1, 'interstate mechanical services': 1, 'railroad avenue closter': 1, 'intrepid control services': 1, 'ny 100225803': 1, 'ktc sales': 1, 'general contracting inc': 1, 'jlm fund': 1, 'marcus avenue new': 1, 'marcus avenue lake': 6, 'mtc ind': 1, 'wfare fund': 3, 'lovl safety mgmt co': 1, 'mcnichols co': 1, 'mercedes benz financial': 1, 'greenbaum rowe smith  davis l 75': 1, 'livingston ave': 1, 'napco copy graphics': 1, 'navistar financial corp': 1, 'ny state insurance fund workers compensation': 1, 'legalaffairs division brooklyn': 1, 'nyc parking violations': 1, 'nyc water board': 1, 'nys department of tax': 1, 'nys workers': 1, 'board c': 1, 'ocwen loan servicing llc': 1, 'office of the us': 1, 'oxford health plans  1697': 1, 'pat sementa plumbing po': 1, 'pierpont mechanical 5833': 1, 'precision testing  balancing 1785': 1, 'pride equipment corp': 1, 'pro safety services': 1, 'mineola blvd mineola': 1, 'rp machine': 1, 'd7t radio active': 1, 'kinderkamack road': 1, 'security exchange': 1, 'shetal metal workers 8403': 1, 'smwia local union': 2, 'education fund mineola': 1, 'sovereign mechanical corp': 1, 'howarddl katz': 1, 'sprint next': 1, 'staples  9020 des moines': 1, 'q sunoco oil co': 1, 'tssm inc': 1, 'tyco integreated security llc po': 1, 'uneeda bolt  screw co': 1, 'capitol drive moonachie': 1, 'charles popoli': 1, 'unum insurance 99': 1, 'business equipment finance grp': 1, 'bank vendor services': 1, 'verizon  3037': 1, 'wachovia bank': 1, 'wachovia bank po': 1, 'wasserman jurista  stolz': 1, 'leonardcl walczyk millburn': 1, 'donnlan weingarten wise  wiederkehr': 1, 'dblo donnlan weingarten wise  wiederkehr': 2}
# PPL: {'filing fee': 2, 'michael checchi': 18, 'albert weiss': 1, 'avran schreiver': 1, 'byrne compressed air': 1, 'john p dillman po': 1, 'joseph dejianne': 1, 'john grando': 1, 'nancy isaacson': 1, 'ste  roseland': 1, 'sherry lowe johnson': 1, 'adams st': 1, 'mitch konca': 1, 'on cttt': 1, 'jeffrey s dubin': 1, 'farrell flanni': 1, 'william penn': 1, 'william roth berg': 1, 'dawn kirby': 4}
#
#
# 6869597
# ORGS: {'spizz  johns': 3, 'attorneys for rock  republic enterprises inc': 3, 'triple r inc': 3, 'rock  republic enterprises inc': 1, 'triple r': 3, 'spring realty llc': 1, 'new pacific rodeo': 1, 'spring realty': 1, 'new pacifics': 1, 'official committee of unsecured creditors': 1, 'gr acquisition': 3, 'adphia commcns corp': 2, 'mclean indus': 1, 'dow corning corp': 1, 'express one intl inc': 1, 'united press intl inc': 1, 'lehman brothers holdings inc': 1, 'steve  barrys': 1, 'lexington precision corp': 1, 'iridium operating llc': 1, 'new pacific': 1, 'spizz joh': 1, 'further extending exclusive periods': 1}
# PPL: {'alex spizz': 4, 'arthur goldstein': 4, 'jill makower': 4, 'arthur j gonzalez': 1, 'ed mich': 1, 'ed tex': 1, 'mclean indus': 1, 'semcrude lp et al': 1, 'd del': 1, 'b good faith': 1, 'richard c morrissey': 3, 'schuyler carroll': 3, 'james sullivan': 3, 'jordana renert': 2, 'slarthur j gonzalez': 1}
#
#
# 11074048
# ORGS: {'jones day morrison  f oerster llp': 1, 'mf global finance usa inc': 1, 's bruce': 1}
# PPL: {'bruce bennett brett h miller': 2, 'bennett l spiegel melissa a hager': 2, 'lori sinanyan craig a damast': 2, 'rarlzpf qarvinoa r r': 1, 'brett h miller': 1}
#
#
# 6864616
# ORGS: {'richards kibbe': 1, 'world financial center': 2, 'morgan stanley senior funding inc': 1, 'morgan stanley  c0': 2, 'morgan stanley': 3, 'morgan stanley  co': 1, 'committee of unsecured creditors of verified identity pass': 1, 'morgan stanley senior funding': 1, 'administrative agent': 1, 'syndication agent and lender': 1, 'veried identity pass inc': 1, 'credit parties': 1, 'administrative agent and syndication agent': 1, 'richards kibbe  orbe llp one': 1, 'fox llp': 1}
# PPL: {'michael friedman': 1, 'keith n sambur': 1, 'michael friedman keith n sambur': 1}
#
#
# 6871102
# ORGS: {'jmk construction group ltd': 4, 'd health care business': 1, 'cl single asset real estate': 1, 'main proceeding h corporation': 1, ' commodity broker e clearing bank': 1, 'itlncomplete einif': 1, 'taxexempt entity': 1, 'exhibit c': 1, 'tenant of residential property': 1, 'ci pursuant': 1, 'pick  zabicki': 2, 'manhattan division': 1, 'statement regarding authority': 1, 'new york corporation': 1, 'lexington avenue': 1, 'j mk construction group ltd': 1, 'air china limited': 1, 'air china': 1}
# PPL: {'ihree mani': 1, 'certied copies': 1, 'douglas j pick bar': 1, 'finn name': 1, 'jacob k': 1, 'jacob kopf': 5, 'douglas j pick': 1, 'jacob ko': 1, 'j pick': 1, 'eric c zabicki': 2, 'nelson l': 1, 'notary public': 1}
# 6919902
# ORGS: {' commodity broker  clearing bank': 1, ' other taxexempt entity': 1, 'exhibit c': 1, 'tenant of residential property': 1, 'x s ste': 1, 'starr  starr': 2, 'pllc firm name': 1, 'authorized individual': 1, 'minoa blvd mineola': 1}
# PPL: {'filing fee': 2, 'michael gibson': 4, 'r bankr': 2, 'john doe': 1, 'david m namm': 1, 'starr date stephen': 1}
#
#
# 25113438
# ORGS: {'kasen  kasen': 2, 'buddy warren': 1, 'warren inc': 1, 'new york state department of labor': 2, 'bowling green': 1, 'kasen  kasen rc': 1}
# PPL: {'michael j kasen': 2, 'sean h lane': 1, 'michael kasen': 1, 'j kasen': 1}
#
#
# 6869599
# ORGS: {'fox llp': 1, 'official committee of unsecured creditors': 1, 'k  republic enterprises inc': 1}
# PPL: {'robert m hirsh': 1, 'jordana l renert': 1, 'arthur j gonzalez': 1}
#
#
# 6937853
# ORGS: {}
# PPL: {'e ortiz': 1, 'norrna e ortiz': 1}
#
#
# 6886399
# ORGS: {'olshan grundman frome rosenzweig  wolosky llp park avenue tower': 1, 'marriott international inc': 1, 'rosenberg calica  birney llp': 1, 'gladstone as comanaging': 3, 'hot associates': 5, 'percentage interests': 1, 'rosenberg calica  bimey llp': 1, 'gladstone and': 1, 'hot association': 1, 'jkn ys': 1, 'new york supreme': 1, 'savills llc': 1, 'olshan grundman frome rosenzweig  wolosky llp': 1, 'rivkin radler llp': 1}
# PPL: {'adam h friedman': 1, 'eric goldberg': 1, 'fredrick j levy': 1, 'robert gladstone': 3, 'lucille gladstone': 2, 'john lesher': 2, 'andrew harris': 2, 'appointment of a': 2, 'l gladstone': 1, 'louis taic': 1, 'adam friedman adam h friedman eric goldberg fredrick j': 1}
#
#
# 6881148
# ORGS: {'mosdos chofetz chaim inc': 11, 'bank of america': 1, 'chestnut ridge rd': 1, 'd  creditors holding secured': 1, 'ci contributions': 1, 'ci certain': 1, 'comptroller of the currency': 1, 'board of governors': 1, 'internal revenue service': 1, 'nys dept': 1, 'finance bankerisp': 1, 'schedule e report': 1, 'chofetz chaim inc': 2, 'golard drive monsey': 1, 'moti ectric inc': 1, 'marcus drive monsey': 1, 'cloverdale lane monsey': 1, 'bakertown road monroe': 1, 'orange and rockland utilities inc': 1, 'restrianed 390 w rte': 1, 'bank account': 1, 'koznitz dr': 1, 'silverman foundation': 1, 'ii 1200000': 1, 'schedule of creditors subtotal': 1, 'wldone insulation 7': 1, 'y and y kitchens': 1, 'schedule g  executory contracts and unexpired leases': 1, 'ci check': 1, 'berkowitz rental lease kiryas radin drive': 1, 'mosdos chofeiz chaim inc': 1}
# PPL: {'cl extensions': 1, 'ezra beyman': 1, 'gershon alexander': 1, 'mark blisko': 1, 'michael leibov': 1, 'aryeh zaks': 1, 'holding unsecured nonpriority claims': 2, 'abe waldman': 1}
#
#
# 42951907
# ORGS: {'wls fargo bank': 1, 'bank mutual': 5, 'rue pare': 1, 'that bank mutual': 1}
# PPL: {'dou sman': 1, 'joseph rewolinski': 1, 'sharon rewolinski': 1, 'rue pare': 2, 'maria s lazar': 1}
#
#
# 18851930
# ORGS: {'prospect realty service corp': 3, 'prospect avenue': 3, 'mtag services': 1, 'nyc department of housing preservation 85 devopment mortgage services': 1, 'nyc department of finance': 1, 'office of legal affairs': 1, 'nyc water board': 1, 's albert h barkey': 1, 'phillips lyte llp': 1}
# PPL: {'jose e suarez': 4, 'maria lopez perez': 1, 'daniel torres': 1, 'albert h barkey': 1}
#
#
# 6937865
# ORGS: {'ortiz  ortiz': 1, 'brian masumoto office': 1}
# PPL: {'martin glenn': 2}
#
#
# 6938011
# ORGS: {'co prductions inc': 1, 'nys dept of labor nys dept of labor workers compensation workers compensation board board': 1, 'internal revenue service': 1, 'nyc dept': 2, 'buildings nyc dept': 1, 'finance nyc dept': 1, 'nyc health department': 1, 'nys dept of labor nys dept of labor 7690180': 1, 'unemployment insurance unit': 1, 'nys dept of labor nys dept of labor 2377586': 1, 'nys dept': 1, 'taxation nys dept': 1, 'taxation collections': 1, 'pls financial services inc pls financial services': 1, 'flatbush ave 84 flatbush ave': 1, 'oak drive': 1, 'oak drive syosset': 1}
# PPL: {'r bankr': 2, 'john doe': 1, ' brookl n': 1}
#
#
# 101896381
# ORGS: {'cox padmore skolnik  shakarchy llp': 1, 'avalon hot partners': 2, 'east end devopment': 2, 'hw food mart': 2, 'moon livestock co': 2, 'sterling mining co': 1, '2 statutes  rules': 1, 'pasta bar': 1, 'torkian dec m': 1, 'az ectronics': 1, 'quadc funding llc': 1, 'new york limited liability company law': 1, 'ny limited liability company law': 1, '750 food': 1, 'shakarchy llp': 1}
# PPL: {'scotto ii': 2, 'stefan b kalina': 2, 'john scotto': 1, 'torkian dec': 2, 'mainr deeisinns': 1, 'cox padmore': 1}
#
#
# 101896386
# ORGS: {'cox padmore skolnik  shakarchy llp': 1, '750 food llc': 1}
# PPL: {'scotto ii': 1}
#
#
# 22258564
# ORGS: {'green tree servicing llc': 1, 'anschutz  schneid': 2, 'pl authorized agent for secured creditor': 2, 'new york bar no': 2, 'mamaroneck avenue harrison': 1, 'federal office building': 1}
# PPL: {'patricia kaplan': 1, 'patricia mcguire': 2, 'robert d drain': 1, 'r bankr': 2, 'miriam j rosenblatt': 3, 'j rosenblatt': 1, 'h bruce bronson': 1}
#
#
# 22258597
# ORGS: {'bronson law offices': 3, 'chan orgill': 2, 'business operations': 1, 'case administration': 1, 'stautuory authority for rief': 1, 'georgia highway express': 1}
# PPL: {'pc h bruce bronson': 1, 'bronson law offices pc': 1, 'patricia kaplan': 1, 'h bruce bronson': 1, 'carl nelson': 1, 'audrey parma': 2, 'b h bruce bronson': 1, 'carl nelson esq': 1, 'h bruce bronson  mamaroneck ave': 1}
#
#
# 6869333
# ORGS: {'fti consulting': 2, 'triple r inc': 1, 'bowling green': 1, 'f ti retention application': 1, 'fti consulting inc': 2, 'check remit': 1, 'wire transfer remit': 1, 'fti restructuring aba': 1, 'bank of america': 1, 'account 003939577164 tax id': 1, 'rock  republic enterprises inc': 3, 'by professional': 1, 'kristina consultant': 1, 'marili associate': 1, 'analysis of sofas  soals': 1, 'ucc  ucc': 1, '1778150 23 firm retention': 1, 'micha 02 research': 1, 'micha 07 review': 3, 'kathryn 12 review': 1, 'micha 05 review': 4, 't0 mai31': 1, 'micha 06 review': 2, 'micha 07': 1, 'nntsnnaf w': 1, 'micha 11 l': 1, 'review atlas': 1, 'c rock  republic enterprises inc': 1, 'ma for committee': 1, 'ia arnroni': 1, 'review triple r sofaschedules': 1, 'lloyd brian 03': 1, 'micha 10': 2, 'micha 05 m': 1, 'rock  republic': 1, 't0 may3i': 1, 'lerprlses inc': 1, 'creditor committee': 1, 'committee couns': 1, 'micha 05 participate': 2, 'micha 07 prepare': 1, 'micha 03 coordinate committee': 1, 'scan 09 participate': 1, 'marili 16 prepare': 1, 'marili 29 continue': 1, 'sean 13 review': 1, 'micha 04': 1, 'general couns': 1, 'micha 04 review': 1, 'steven 03 review': 1, 'sean 08 review': 1, 'marili 06 review rock  republic': 1, 'marili 06 review': 1, 'expense category expense total': 1, 'ground transportation': 1, 'lodging 000 business meals 000 other  research': 1}
# PPL: {'arthur j gonzalez': 1, 'steven simms': 1, 'w eisenband': 1, 'michael h participate': 1, 'michael  participate': 9, 'steven  participate': 9, 'cordascot michael': 1, 'review roth': 1, 'review atlas': 2, 'inciinn fnr': 1, 'steven  attend': 2, 'michael  review': 1, 'steven  review': 1, 'michael  m': 1, 'm task': 1}
#
#
# 6869625
# ORGS: {'rock  republic enterprises': 1, 'triple r inc': 1, 'bankmptcy code': 1, 'hahn  hessen llp couns': 1, 'sp1 zz  johns': 1, 'fox llp couns to committee': 1, 'le 352': 1, 'inventoy finished goods 5529 5': 1, 'inventory avauabmty u u u u u u u u u 0 u 0 u 0 0': 1, '339 ml q9': 1, 'openea l u u u u u u': 1, 'lidebt tl': 1}
# PPL: {'geoffrey lurie': 1, 'rosanne thomas matzal': 1, 'rosanne thomas matzat': 1, 'goldsteirz arthur goldstein': 1, 'arthur j gonzalez': 1}
#
#
# 25358524
# ORGS: {'madison square tavern inc': 1, 'total weekly sales': 2, 'restaurant personn': 7, 'management personn': 1, 'adjusted gross sales': 1, 'books and records': 1, 'any warranties of fitness for particular purposes or': 1}
# PPL: {'law ofce': 1, 'elana f sinensky': 1, 'goldberg weprin': 1, 'kevin j nash': 1}
#
#
# 6870150
# ORGS: {'rdd management corp': 1, 'mount vernon monetary management corp': 2, 'n saw mill': 1, 'american armored car ltd': 1, 'annex corp': 1, 'armored money services': 1, 'atm management': 1, 'barron atm corp': 1, 'crystal public communications inc': 1, 'district central station alarm corp': 1, 'district central alarm service corp': 1, 'district security services': 1, 'ezki realty corp': 1, 'ezri realty corp': 1, 'gnc payroll plus inc': 1, 'gt public services': 1, 'public access networks services inc': 1, 'michle corp': 1, 'money kiosk corp': 1, 'montgomery check cashing corp': 1, 'mount vernon money center corp': 1, 'mvmc service station inc': 1, 'mvmc holding corp': 1, 'mvmc service inc': 1, 'mvmm corp': 1, 'nowcash ltd': 1, 'bid procedures and auction': 1, 's robert': 1}
# PPL: {'allen d applbaum': 2, 'greenberg traurig': 1, 'r bankr': 1}
#
#
# 6946980
# ORGS: {'ybrant media acquisition inc': 2, 'holdings corp brian': 2, 'mla colony': 1, 'banjara hills hyderabad': 1, 'tangana 500034 india': 1, 'lycos inc loans': 1, 'kaye  fox': 1}
# PPL: {}
# 6869472
# ORGS: {'marvin traub associates inc': 5, 'merchandising consultant': 10, 'rock  republic enterprises inc': 6, 'triple r': 4, 'marvin traub associates': 10, 'spizz  johns': 3, 'pc proposed couns': 1, 'triple r inc': 2, 'associates inc': 1, 't0 rock  republic': 1, 'rock  republic enterprises': 7, 'fox llp': 1, 'official committee of unsecured creditors': 1, 'bowling green': 3, 'via email': 3, 'spizz  johns rc': 2, 'rook  republic enterprises': 1, 'marvin trade associates inc': 1, 'marvin traub retail review': 1, 'rnr coo meeting': 1, 'bowling green new york': 1, 'marvin traub rock  republic': 1, 'retail review': 1, 'marvin trade assdbiates': 1, 'ny 100195820': 1, 'triple rinc': 1}
# PPL: {'marvin traub': 10, 'mortimer singer': 3, 'kelsey scroggins': 5, 'arthur j gonzalez': 2, 'i introduction a': 1, 'alex spizz': 4, 'arthur goldsteln': 1, 'jill makower': 1, 'richarci morrissev': 1, 'schuyler g carroll': 4, 'richard morrissey': 4, 'james m sullivan': 4, 'alex splzz': 1}
#
#
# 11071228
# ORGS: {'mf global holdings ltd': 2, 'total real estate costs technology and other costs': 1, 'forecast m': 4, 'mf global finance usa inc': 1, 'mf global holdings usa inc': 2, 'mf global capital llc': 1, 'mf global fx clear llc': 1, 'global market services llc': 1, ' bank for mf global finance usa inc': 1, 'jp morgan mf global holdings usa inc': 1}
# PPL: {}
#
#
# 6886415
# ORGS: {'suozzi english  klein rc': 2, 'employ rsr consulting': 1, 'llc as': 1, 'rsr consulting': 1, 'support of examiners': 1, 'llc bankruptcy meyer': 1, 'wolosky llp': 1}
# PPL: {'thomas r slome': 2, 'm bernstein': 1, 'appointment of a': 1, 'goldberg weprin': 1, 'finkel goldstein': 1, 'olshan grundman frome rosenzweig': 1, 'robert rosenfeld': 4}
#
#
# 11088746
# ORGS: {'ortiz  ortiz': 3, 'llp hearing': 1, 'nyctl 2015a trust': 3, 'water board': 1, 'nyctl 2015a': 1, 'ameribuild const': 1, 'bh s  b holdings': 1, 'lexis 1024': 1, 'saint anns ave tax class': 1, 'trans ex av 0 0': 1, 'taxablebillable assessed value': 1, 'nycprogerty proposed order': 1}
# PPL: {'norma e ortiz': 3, 'martha j de jesus counsel': 1, 'martin glenn': 4, 'martha j de jesus': 2, 'e ortiz': 1}
#
#
# 6884918
# ORGS: {'chrysler building': 1, 'waterscape resort llc': 1, 'bank national association': 1, 'usb capital resources': 1, 'usb capital': 2, 'acquisition loan mortgage': 1, 'mezzanine loan mortgage': 1, 'bank assignment': 1, 'affidavit of service': 4, 'an affidavit of service': 2, 'revenue service': 1, 'eastern time': 4, 'pavarini mcgovern llc': 1, 'honorable stuart m bernstein': 1, 'seyfarth shaw llp': 1, 'schiff hardin llp': 1, 'fifth avenue': 1, 's stuart m bernstein': 1, 'stuart m bernstein': 1, 'troutman sanders llp': 2}
# PPL: {'lee w stremba': 2, 'brett goodman': 1, 'brett d goodman': 1, 'greg r yates': 1, 'louis t delucia': 1, 'richard morrissey': 1}
#
#
# 6932445
# ORGS: {'suite 2220 0': 1, 'bowling green new york': 1, 'flip services': 1, 'dba bounce': 1}
# PPL: {'martin glenn': 1, 'rachel s blumenzld': 1}
#
#
# 6924188
# ORGS: {'donnlan weingarten wise  wiederkehr': 1, 'affairs afloat inc': 1, 'affairs aoat inc': 1, 'us coast guard': 1, 'hsbc bank usa': 1, 'national association': 1, 'small business administration': 1, 'aoat nyc inc': 1, 'affairs afloat': 1, 'nys sale tax processing 4145100': 1, 'east ltd': 1, 'east ltd 3579850': 1, 'sandra greer': 2, 'place nw': 1, 'billybey ferry company': 2, 'nys department of tax nys department of tax finance 7': 1, 'nys sale tax processing': 1, 'fifth avenue': 1, 'fifth avenue internal revenue service internal revenue service 1232600  7346': 1, 'metrotech center': 1, 'bettes ave 234 bettes ave': 1, 'stonewall solutions stonewall solutions llc 600000': 1, 'box 551': 1, 'fino fino 542000': 1, 'metro new york inc metro new york inc': 1, 'kenny stearns kenny stearns zonghetti llc 455610': 1, 'zonghetti llc': 1, ' 2698 po': 1, 'perju ry': 1, 'we 1018': 1, 'rent  office  repairs': 1, 'accrual basis prot': 1, 'rent  office 3675 repairs': 1, 'aiiaikd ailuai ind': 1, 'rent  office repairs': 1, 'hsbc total cash': 1}
# PPL: {'jonathan s pasternak': 1, 'erica feynman aisner': 1, 'peter lerner': 5, 'steven salsberg': 1, 'r bankr': 2, 'john doe': 1, 'gregory c soumas': 2, 'anthony mazza': 1, 'jonathan figueroa jonathan figueroa weehawken': 1, 'joshua e abraham': 2, 'cummulative deficit': 1, 'kb al luai': 1, 'mainti tony': 1}
#
#
# 6928919
# ORGS: {'cch restaurant manaement inc': 1, 'main proceeding corporation': 1, 'busv iillmjl ul': 1, 'tenant of residential property': 1, 's david carlebach': 1, 'law offices of david carlebac': 1, 'firm name': 1, 'restaruant mangement': 1, 'law offices': 1, 'east 34th st': 1, 'chase bank usa': 1, 'emerson construction corp': 1, 'gold star farm inc': 1, 'new york state dept': 1, 'tony yi trading inc': 1}
# PPL: {'filing fee': 3, 'iz iii iii e e iii iii iii e': 1, 'frank hau': 2, 'printed name': 1, 'david carlebach': 3, 'eliot j cherson': 1, 'joe banda': 1, 'nobito hirukou': 1}
#
#
# 31997522
# ORGS: {'administrativy consolidated': 1, 'kaye scholer llp': 1, 'sedgwick llc 9322': 1, 'briarwood crossing lawrence': 1, 'wholesale supply': 1, 'alba fu corp': 2, 'harborview south lawrence': 2, 'colonial management group': 1, 'hollyhock trail boca raton': 1, 'eisenberg family foundation 1483': 1, 'combustion consulting services': 1, 'max builders supply co': 1, 'castle oil corporation': 1, 'mamaroneck avenue harrison': 1, 'box 3 13 1': 1, 'east 4th brooklyn': 1, 'new york nyc law department': 1, 'mohan wding  boiler repair corp': 1, 'new start management 11 corp': 1, 'gc realty advisors llc 2255': 1, 'internal revenue service po': 1, 'koss  schonfd llp': 1, 'roman gutgart': 1, 'battery investors llc': 1, 'peshi  associates llc': 1, 'sempre fj management 11': 1, 'tannor partners credit fund': 8, 'lubl reisman star supplies  maintenance': 1, 'ny affordable housing associates llc state': 1, 'generals office': 1, 'thiva contracting corp': 1, ' associates corp': 1, 'ny affordable housing epvi llc': 1, 'colonial management': 2, 'surf avenue': 1, 'nyc environmental control board': 1, 'nys dept': 2, 'labor ultimate boiler treatments unemployment ins': 1, 'tax  finance': 1, 'wagner reporting': 1, 'chestnut holdings': 1, 'advantage plastics': 1, 'castle oil corp': 1, 'county oil company inc': 1, 'y  e appliance': 1, 'honigs appliance center llc': 1, 'suite 401': 3, 'securities and exchange commission': 2, 'world financial center': 1, 'office of general couns': 1, 'housing stanhope associates': 1, 'backenroth frank  krinsky': 1, 'llc po': 1, 'jack jaffa associates corp': 1, 'lp tannor partners credit fund': 1, 'ny affordable housing assoc': 1, 'nyc dep nyc water board': 1, 'bureau of customer services po': 1, 'davidoff wolfe mandker  kass van cortlandt village llc 51': 1, 'dlr  co llc new york': 1, 'legget avenue con llc': 1, 'woodycredt con llc': 1, 'ocean construction con llc': 1, 'american honda finance corporation po': 1, 'phillips nizer llp': 1, 'james macron phillips nizer llp': 1}
# PPL: {'erica weitz': 2, 'donna baker': 1, 'abraham wolf': 1, 'david selengut': 1, 'yossi gross': 1, 'avi naumberg': 1, ' david gottlieb': 1, 'howard r vargas esq': 1, 'albert sontag': 1, 'ellise ginsberg': 2, 'zev cohen': 2, 'aron j': 1, 'cheryl cohen': 1, 'bertram herman': 2, 'chayim kirschenbaum po': 1, 'chaya selengut': 1, 'mar gottlieb': 1, 'malka singer': 1, 'ave apt': 1, 'neil d rischall': 1, 'glades rd': 1, 'mark j schwartz po': 1, 'ramona goodman': 1, 'thomas weiss jack j': 1, 'joseph gutgarts': 1, 'jeffrey shore': 1, 'john st': 1, 'w averll': 1, 'niel kirschenbaum po': 1, 'richard a klass': 2, 'jeffrey a reich': 1, 'reich reich': 2, 'lawrence r reich': 1, 'webster ave': 1, 'serene nakano': 1, 'mark frankel': 1, 'lisa luciano': 2, 'simon pantierer': 1, 'david ginsberg': 1, 'anshel kaplan': 1, 'samuel singer': 1, 'matthew c kesten': 1}
#
#
# 6868975
# ORGS: {'third avenue food service inc': 2, 'sterling llp': 1, 'nys dept': 1, 'central assignment  collection': 1, 'yincheng corp usa': 1, 'forsyth st new york': 1, 'superior restaurant supply co inc': 1, 'harrison st': 1, 'water waste prevention co inc': 1, 'ahl supply inc vendor': 1, 'tc leed distributors inc vendor': 1, 'imperial seafood corp vendor': 1, 'mott st new york': 1, 'third avenue food service': 2, 'beine beverage inc vendot': 1, 'ocean frost corporation vendor': 1, 'muiberry st': 1, 'box 9329': 1, 'hai thanh seafood co inc vendor': 1, 'daughters co inc vendor': 1, 'north shore linen vendor': 1, 'ta tong': 1, 'southern wine  spirits of ny vendor': 1, 'pur pac inc': 1}
# PPL: {'gui ming li et': 1, 'brian g burke': 1, 'tsu yue wang': 2}
# 6870142
# ORGS: {'southern district of new york': 1, 'mount vernon monetary management corp all other names': 1, 'sole corporate': 6, 'fti consulting': 1, 'llp partnership': 1, 'health care business': 1, 'railroad stockbroker': 1, 'commodity broker': 1, 'clearing bank': 1, 'single asset real estate': 1, 'ultqulcu ul eve': 1, 'exhibit c': 1, 'tenant of residential property': 1, 'mount vernon monetary management corp': 6, 'firm name': 1, 'n saw mill': 1, 'american armored car ltd': 2, 'annex corp': 3, '7 armored money services llc': 1, 'atm management': 2, 'barron atm corp': 3, 'crystal public communications inc': 3, 'district central station alarm corp': 3, 'district central alarm service corp 13': 1, 'district security services': 3, 'ezki realty corp': 3, 'ezri realty corp': 4, 'gnc payroll plus inc': 3, 'gt public services': 3, 'public access networks services inc': 3, 'manhattan money branchcom inc': 2, 'michle corp': 3, 'money kiosk corp': 3, 'montgomery check cashing corp': 3, 'mount vernon money center corp': 3, 'mvmc corp': 2, 'mvmc service station inc': 3, 'mvmc holding corp': 3, 'mvmc service inc': 3, 'mvmm corp': 3, 'nowcash ltd': 3, 'time square payment center inc': 2, 'atm corp': 3, 'zipes equities': 1, 'armored money services': 1, 'district central alarm service corp': 2, 'zipes equities ltd': 2, 'fti consulting inc': 2, 'greenberg traurig llp': 2, 'greenberg traurig': 2, 'management corp': 2, 'huguenot llc': 1, 'american armored car': 1, 'armored money services llc atm management': 1, 'mount vernon monetary management corp 24': 1, 'department of creditor bank loan': 1, 'boa transfer 1255 corporate drive': 1, 'tarrytown road funding bank or contingent': 1, 'merrick avenue funding bank or contingent': 1, 'domestic bank': 1, '815 reservoir avenue funding bank or contingent': 1, 'jpm chase': 1, 'suite 300 funding bank or contingent': 1, 'omnex group': 1, 'sylvan ave armored car contingent': 1, 'department of creditor': 2, 'bank loan': 2, 'name of creditor': 1, 'atm access inc': 1, 'sect a branch': 1, 'carver savings bank': 1, 'west boa ct transfer account': 1, 'fam capital': 1, 'atm systemscorp': 1, 'first avenue': 1, 'funding bank': 11, 'atm operator': 12, 'atm transaction processor funding bank': 1, 'value of securit': 2, 'dta community credit': 1, 'b  h check cashing': 1, 'sterling national bank': 1, 'federal credit': 1, 'mahopac national bank': 1, 'stanson automated': 1, 'granite cc service': 1, 'united check cashing': 1, 'seneca avenue ridgewood': 1, 'morris ave': 1, 'north division st peekskill': 1, 'financial englewood cliffs': 1, 'nj 7632 customer': 1}
# PPL: {'allen d applbaum': 8, 'filing fee': 3, 'e e iii el': 1, 'allen g kadish': 2, 'greenberg traurig': 1, 'llp allen g kadish': 2, 'burke a dunphy': 2, 'robert egan': 2, 'iris egan': 1, 'setoff value': 1, 'securit elan': 1, 'ron white': 3, 'alex southwell': 1, 'nathan enzminger tel': 1, 'kevin j kaufman': 1, 'rick dubois': 1, 'yokasta baksh sr': 1, 'daniel m gitner': 1, 'irene sabes': 1, 'colleen juiliano': 1, 'rosemarie mclaughlin tel no': 1, 'james carver': 1, 'sid sarkar': 1, 'eddie elkin': 1, 'lindsay gray': 1, 'susan h tinch': 1, 'chris danvers tel': 1, 'ron barberan': 1, 'paula cappello': 1, 'david rosenfeld': 1, 'juliet j': 1, 'joel iskowitz': 1, 'jim lieto': 1, 'daniel colasuonno tel': 1, 'bruce balonick': 1, 'allen d applbaurn': 2}
#
#
# 29373132
# ORGS: {'thompson  knight llp stuart': 1, 'thompson  knight llp': 2, 'new york thompson  knight llp': 1, 'attorneys for citibank na': 1}
# PPL: {'j glick': 1, 'r sklar': 1, 'shelley c chapman': 1, 'thompson knight': 3, 'stuart j glick': 2}
#
#
# 12170954
# ORGS: {'individuals filing for bankruptcy': 1, 'health care business': 1, 'single asset real estate': 1, 'schedule c': 1, 'bankruptcyresourcesapprovedcredit anddethounsorsaspx': 1, 'grand pacific finance': 1, 'nissan motor acceptance  371447 pittsburgh': 1, 'seterus  1077': 1}
# PPL: {'elfnlfaifotieour bobker': 1, 's benny boruch bobker': 1, 'benny boruch bobker': 5, 'anne penachio': 2, 'penachio malara': 1}
#
#
# 6886406
# ORGS: {'states trustee': 1, 's stuart m bernstein stuart m bernstein': 1, 'goldberg weprin finkel goldstein llp': 1}
# PPL: {'olshan grundman frome rosenzweig  wolosky': 1}
#
#
# 12072149
# ORGS: {'suozzi english  klein rc': 1, 'proposed couns': 1, 'espresso management holding inc': 2, 'espresso stores inc': 1, 'afl llc': 1, 'f6 chsea inc': 1, 'espresso dreams llc': 3, 'levis schedules': 1, 'statement of financial affairs': 1, 'zecchini usa corps': 1, 'gruppo industriale filicori': 1, 'lola 8 west ltd': 4, 'suozzi english  klein': 1, 's jil mazermarino': 1, 'pbdllsew 40230435sr lavauiaasxm': 1, 'miauh 5114': 1, 'w15w 7': 1, 'isl scott s markowitz': 1, 'tarter krinsky  drogin llp': 1, 'division of corporations': 1, 'dos id': 1, 'current entity status active': 1, 'dos homepage': 1}
# PPL: {'jil mazermarino': 3, 'shlomo levi': 3, 'michael e wiles': 1, 'jil mazer': 1, 'sharon turjman': 4, 'moshe mamon': 1, 'specically levi': 1, 'moshe maman': 1, 'lola  west': 1, 'sharon turj': 1, 'scott s markowitz': 1, 'sharon turjman  west th': 1}
#
#
# 16798909
# ORGS: {'daum global holdings corp': 1, 'ybrant media acquisition': 3, 'ybrant digital limited': 2, 'ybrant digital': 7, 'ybrant digitals': 2, 'commercial division': 1, 'daum global holdings': 1, 'ybrant media acquisition inc': 1, 'lycos internet ltd': 1, 'new york': 1}
# PPL: {'william j': 2, 'alison j nathan': 1, 'jeffrey k oing': 1}
#
#
# 6884995
# ORGS: {'via ectronic filing': 1, 'honorable stuart m bernstein': 1, 'bowling green new york': 1, 'v waterscape resort llc': 1, 'waterscape resort': 1, 'bank national association': 1, 'usb capital resources': 1}
# PPL: {'pavarini mcgovern': 1, 'lee w stremba': 1, 'eric w sleeper': 1}
#
#
# 6883511
# ORGS: {'ango  maxies': 1, 'b an official committee of unsecured creditors': 1, 'silvermanacampora llp': 1, 'capital one': 10, 'north fork bank': 1, 'secured lenders': 1, 'h based': 1, 'secured lender': 7, 'a termination event': 1, 'professional claims': 1, 'adequate protection obligations': 1}
# PPL: {'r bankr': 1, 'karry goldstein': 1, 'reed goldstein': 1, 'alan kay': 1, 'marcia kay': 1, 'jeffrey lehmann': 1, 'jeffrey lehmanns': 1, 'k based': 1, 'the lehmann lien': 1, 'ordered this th day of april': 1, 'shelley c chapman': 2}
#
#
# 6870144
# ORGS: {'greenberg traurig': 2, 'mount vernon monetary management corp': 18, 'management corp': 6, 'n saw mill': 5, 'annex corp': 6, 'armored money services': 4, 'atm management': 6, 'barron atm corp': 6, 'crystal public communications inc': 6, 'district central station alarm corp': 6, 'district central alarm service corp': 6, 'district security services': 6, 'ezki realty corp': 5, 'ezri realty corp': 4, 'gnc payroll plus inc': 4, 'gt public services': 6, 'public access networks services inc': 6, 'money kiosk corp': 5, 'montgomery check cashing corp': 5, 'mount vernon money center corp': 6, 'mvmc service station inc': 4, 'mvmc holding corp': 5, 'mvmc service inc': 5, 'mvmm corp': 5, 'nowcash ltd': 4, 'time square payment center inc': 4, 'atm corp': 4, 'zipes equities': 3, 'schedules of assets and liabilities and schedules of executory contracts and unexpired leases': 1, 'mount vernon monetary attn': 1, 'mount vernon monetary': 1, 'processing center': 2, 'potential trust claim': 4, 'potential trust claims': 1, 'bar date order': 1, 'internal revenue': 2, 'exhibit c': 1, 'bar date': 2, 'ci domestic': 1, 'cl wages': 1, 'cl real estate cl motor vehicle cl equipment cl other usc': 1, 'annual interest': 1, 'frbp 3001c': 1, 'frbp 3001e': 1, 'american armored car ltd': 4, 'ezrl realty corp': 2, 'manhattan money branchcom inc': 4, 'michle corp': 2, 'mvmc corp': 2, 'processing center po': 1, 'claims processing center': 1, 'new york by order': 1, 'huguenot llc': 1, 'money services llc': 1, 'payroll plus inc': 1, 'kiosk corp': 1, 'mvmc service station': 2, 'holding corp 10': 1, 'zipes equities ltd': 1, 'gannett co inc': 1, 'usa today': 1, 'claims ohio': 1, 'eastern time': 1}
# PPL: {'llp allen g kadish': 1, 'burke a dunphy': 1, 'michelle corp': 4, 'allen d applbaam': 1, 'relief reguested': 1, 'lla ja l': 1, 'c proof': 1, 'e notice of the bar date order': 1, 's allen g kadish allen g kadish burke a dunphy': 1, 'admjnistrative clallvis': 1, 'loon i': 1, 'llp allen g kadish burke a dunphy': 1, 'time sanare': 1}
# 11073769
# ORGS: {'morrison  foerster llp': 3, 'pepper hamilton llp': 1, 'freeh group international solutions': 1, 'mesa air group inc': 1, 'keene corp': 3, 'ames dept': 1, 'stores inc': 1, 'see keene corp': 1, 'houlihan lokey howard  zukin capital v': 1, '205 br': 1, 'mesa air group': 1, 'cct comm': 2, 'mf global inc': 4, 'mf global uk ltd': 1, 'report of investigation': 1, 'mf global': 1, 'smith v edwards  hale': 1, 'worldwide direct inc': 1, 'wd mich 2009': 1, 'private placement lp': 1, 'professional services': 1, 'of town couns': 1, 'peppers application': 1, 'pepper and the trustee': 1, 'lj preparation for creditors': 1, 'fc attend creditors': 1, 'razzano committee': 1, 'committee scc': 1, '162012 trav expense  frank razzano  1034': 1, '10232012 trav': 1, 'pepper hamilton llp morrison  foerster llp': 1, 'ny 101040050': 1, 'special couns for the chapter': 1, 'lazard freres  co': 1, 'agenda continued': 2, 'lipton rosen  katz': 1, 'buttner hammock': 1, 'pa as litigation consultants': 1, 'barclays capital inc': 1, 'avenue capital': 2, 'kpmg llp': 1, 'ambac financial group': 13, 'blackstone advisory partners': 1, 'morrison  foerster': 4, 'lazard freres': 2, 'shearman  sterling': 1, 'corporate department': 1, 'us trustee': 1, 'barclays capital': 1, 'amended sec': 1, 'tmc souther communication': 6, 'ao aguayo working': 1, 'tmc souther communications': 1, 'tmc souther meeting': 1, 'b191 general 101012 litigation b261 investigations': 1, 'jc snodgrass review': 3, 'a toy ohta review': 1, 'b191 general': 4, 'tmc souther preparation': 2, 't souther': 1, 'aguayo team': 1, 'case administration': 2, 'litigation b261 investigations': 3, 'b261 investigations': 1, 'tmc souther tephone': 1, 'lj freeh tephone': 1, 'md foster finalize': 1, 'lj freeh preparation': 1, '459000 committee': 1, 'fc razzano': 1, 't souther communication': 1, 'chuff review': 1, 'rowe update': 1}
# PPL: {'louis j freeh': 1, 'ames dep': 1, 'blackwood assocs': 1, 'louis j f': 1, 'amhnr finnnrinl': 1, 'st sess': 1, 'wd okla': 1, 'st ritas': 1, 'matthew foster': 1, 'frank piantidosi': 1, 's david m fournier': 1, 's brett h miller': 1, 'david b stratton': 1, 'brett h miller': 1, 'david m fournier': 1, 'melissa a hager evelyn j meltzer': 1, 'craig a damast': 1, 'allison h weiss': 1, 'aaron klein': 3, 'brian s masumoto': 1, 'carina h schoenberger': 1, 'bruce arnold': 1, 'whyte hirschboeck': 4, 'timothy bass': 1, 'michael b cunningham': 1, 'luke kwiatkowski': 1, 'allison weiss': 1, 'hogan lovells': 1, 'wachtell lipton': 1, 'barbara mendelson': 1, 'carina schoenberger': 1, 'rochelle v grant': 1, 'ao aguayo': 3, 'f razzano': 3, 't melvin': 3, 'katten muchen': 1, 'tmc souther': 3, 'ao aguayo working': 1, 'm hager': 1, 'f piantidosi': 3, 't souther': 1, 'a halboth': 9, 'm singh': 3, 'b rosenthal': 1, 'matt foster': 1, 'jc snodgrass': 1, 'ib knauer': 1, 'j gruehn': 2, 'c b chuff': 1, 'cb chuff meet': 1, 'jcsnodgrass reviewinterviewnotes': 1, 'h jaffe': 4, 'a aguayo': 1, 'fc razzano': 1, 'm foster': 2, 'm choi': 3, 'j snodgrass': 1, 'c lano': 1, 'hughes hubbard': 1, 'jcsnodgrass reviewinterviewoutlines': 1, 'fc razzano meeting': 1, 'h hubbard': 1, 'md foster edit': 1, 'm custer': 2}
#
#
# 6864603
# ORGS: {'hanify  king': 2, 'professional corporation 1359': 1, 'support of application': 1, 'professional corporation': 2, 'professional corporation as couns as couns': 1, 'veried identity pass inc': 1}
# PPL: {'paul r niehaus ofcoansel': 1, 'charles r bennett': 3, 'r bankr': 2, 'd mass': 1, 's charles r bennett charles r bennett hanify  king': 1}
#
#
# 6932795
# ORGS: {'wise  wiederkehr': 1, 'llp hearing time': 1, 'weingarten wise  wiederkehr': 1, 'reich brothers': 1, 'atlas fire door': 1, 'webster avenue management': 2, 'large pittsburg g l6ga': 1, 'pittsburg price for new': 1, 'chicago brake price': 1, 'dblo donnlan weingarten wise  wiederkehr': 1, 'woodscape ltd': 1, 'wlman inc': 1, 'dta air lines inc': 1, 'ango  maxie s': 1, 'continental airlines': 1, 'lion corp': 1, 'chann one communications inc': 1, 'ionosphere clubs inc': 1, 'baldwin united corp': 1, 'ionosphere clubs': 1, 'wl 188127': 1, 'daware  hudson ry co': 1, 'general bearing corp': 1, 'ames dept': 1, 'stores inc': 1, 'integrated resources inc': 1, 'bildisco  bildisco': 1, 'chateaugay corp': 1, 'bank na': 1, 'metro communications inc': 1, 'mlon bank na': 1, 'oficial comm': 1, 'sale price': 1, 'bank of america': 2, 's jonathan s pasternak jonathan s pasternak': 1}
# PPL: {'jonathan s pasternak': 1, 'julie cvek curley': 1, 'martin glenn': 1, 'durodyne pinspotter': 1, 'penn mut': 1, 'stephen indus': 1, 'betty owens schools': 1, 'wd tex': 1, 'delb ello donnellan': 1}
#
#
# 6933223
# ORGS: {'supplemental background': 1, 'first supplement': 1, 'merrick d holdings inc': 1, 'matco ectronics': 1, 'group inc': 1, 'granite partners': 1, 'wiley brown  assoc': 1, 'big mac marine inc': 1, 'boltonemerson inc': 1, 'us federal office': 1, 'varick st': 1, 'leslie fay cos inc': 1}
# PPL: {'cecelia g morris': 1, 'william k harrington': 1, 'david carlebach': 1, 'stephen kates': 2, 'steven kates': 1, 'the lar dan': 1, 'lar dan': 1, 'r bankr': 2, 'ed tex': 1, 'bonneville pac': 1, 'd utah': 1, 'b analysis': 1, 'leslie fay': 1, 'serene k nakano serene k nakano trial': 1}
#
#
# 22258584
# ORGS: {'green tree servicing llc': 1}
# PPL: {'patricia kaplan': 1, 'patricia mcguire': 1}
#
#
# 6938837
# ...
# PPL: {'schuyler g carroll': 1, 'james m sullivan': 6, 'jordana l renert': 1, 'harold rivera': 1, 'jeffrey whitaker': 1, 'yolanda cruz': 4, 'angelich jr renert jr': 1, 's carroll': 10, 'j sullivan': 27, 'j renert': 37, 'l indelicato': 2, 'jr renert': 1, 'james m sullivan george p angelich jordana renert': 1, 'constantino constantino sullivan': 1, 'nova a constantino': 1, 'm  ball': 1, 'm cordasco': 5, 'schuyler carroll': 4, 'james sullivan': 19, 'kozlowski outline': 1, 'v durrer': 6, 'd kozlowski': 4, 'david kozlowski': 2, 'carroll carroll': 1, 'vanacore collins': 1, 'george angelich': 2, 'jordana renert': 17, 'j vanacore': 1, 'james m sullivan jeffrey': 1, 'vanacore david j kozlowski': 1, 'allan g collins': 1, 'alex spizz': 1, 'a goldstein': 3, 'velasco velasco': 1, 'jsullivan via e': 1, 'jordana renertregarding': 1, 'r hart': 1, 's berger': 1, 'steve simms': 6, 'a rosenstein': 1, 'r toms': 2, 'j sullivans': 2, 'g lurie': 1, 'koral distribution': 1, 'david j kozlowski': 1, 'noel velasco': 1, 'sheila smith': 2, 'mike eisenband': 1, 'jim fox': 3, 'jim atkinsonjames': 1, 'nova constantino': 1, 'james jordana renertregarding': 1, 'jordana rener': 2, 'r morrissey': 3, 'g angelich': 1, 'marvin traub': 10, 'j makower': 1, 'constantino constantino': 1, 'efile objection to atlas retention': 1, 'marvin traub retention': 1, 'review revisions': 1, 'jordana  renert': 1, 'michael cordasco': 1, 's simms': 1, 'george p angelich': 2, 'lisa indelicato': 2, 'jm sullivan': 1, 'd kozlowksi': 1, 'r matzat': 6, 'jr renertr': 1, 'schuyler carroll james m sullivan': 1, 'm diaz': 1, 'james m': 1, 'mqa mm mm': 1}
#
#
# 6864607
# ORGS: {'b  personal property': 1, 'c  property claimed as exempt': 1, 'g  executory contracts': 1}
# PPL: {}
#
#
# 6933218
# ORGS: {'west 119m realty llc': 1, 'chase na': 1, 'soto 119 realty': 1, 'merrick d holdings inc': 1, 'merrick d holdings': 1, 'boardwalk inc et al': 1, 's steven kates': 1}
# PPL: {'v soto': 1, 'jose tatis': 1, 'adam doe': 1, 'lorenzo deluca': 1}
#
#
# 6932791
# ORGS: {'donnlan weingarten wise  wiederkehr': 1, 'sheet metal workers union': 1, 'national pension funds': 1, 'local 28': 1, 'sheet metal workers national pension fund': 1}
# PPL: {'jonathan s pasternak': 1, 'dawn kirby': 1, 'michael checchi pursuant to': 1, 'michael checchi': 5}
#
#
# 6864600
# ORGS: {'verieds history and operations': 1, 'morgan stanley services fund inc': 1, 'morgan stanley': 2, 'credit parties': 1, 'morgan stanley senior funding inc': 2, 'administrative agent and syndication agent': 2, 'morgan stanley  co incorporated': 1, 'dorman  fawcett': 1, 'widepoint corporation': 1, 'henry incorporated': 2, 'll identity solutions': 2, 'customer data': 2, 'dta terminal a 1': 1, 'washington national airport 1 aviation circle': 1, 'indianapolis airport authority': 1, 'international air terminal llc terminal': 1, 'mineta san jose international airport': 1, 'gomez construction company': 1, 'jackson ave': 1, 'meridian worldwide db': 1}
# PPL: {'james e maroney': 1, 'james e moroney': 3, 'steven brill': 3, 'ciistnmer data': 1, 'john f kennedy': 1, 'ronald regan': 1, 'h weir cook memorial drive': 1, 'paul schwartz': 1}
#
#
# 6883494
# ORGS: {'mamaroneck avenue harrison': 1, 'ango  maxies': 8, 'am acguisition': 1, 'new york co': 1, 'largest unsecured creditors see attached': 1, 'ango  maxiesi': 1, '0rda management corp': 1, 'buckhead beef company': 2, 'mslavin  sons': 1, 'center drive unit': 1, 'sysco food service': 2, 'nys dept of tax  finance': 1, 'hanson place': 2, 'sarntl  son': 1, 'bruces bakery': 2, 'dept of tax  finance': 1, 'sam tl  son inc': 1, 'american express': 1, ' 1270 po': 1, 'swede farm': 1, 'borax paper products inc': 1, 'hper paper  supplies': 1, 'halper paper  supplies': 1, 'mivila foods': 2, 'schedule d  creditors holding secured claims': 1, 'azwozhzoo umqbo': 1, 'division of capital one': 1}
# PPL: {'robert l rattet': 1, 'dawn kirby arnold': 1, 'reed goldstein': 3, 'i am the managing': 1, 'sreed goldstein': 1, 'r bankr': 3, 'john doe': 2, 'jerse ci': 2, 'brookl n ny': 1, 'theodore conrad drive': 1, 'center driiie': 1, 'petersen nj': 1, 'underhill blvd': 2}
#
#
# 6818181
# ORGS: {'advanced contact solutions inc': 1, 'cash management system': 2, 'bank accounts': 3, 'bank name': 5, 'bank of america': 6, 'operating account for payroll': 1, 'direct deposit': 1, 'adp payroll withholding taxes': 1, 'misclaneous manual checks': 1, 'temarketing inc': 5, 'bank of new york mlon': 9, 'access direct': 3, 'controlled disbursements': 1, 'escrow account': 3, 'use and excise taxes corporate trust': 1, 'llc prc b2b': 1, 'wachovia bank': 2, 'north magnolia avenue orlando': 3, 'account type': 1, 'employee benefits corporate trust': 1, 'operating account': 1, 'payroll account': 2, 'cafeteria 125 account': 1, 'access direct temarketing inc': 1, 'employee expense reports business premium market rate account': 1, 'bank of new york': 1, 'sweep temarketing': 1, 'cash funding': 1, 'bzb payroll funding  2': 1, 'sony adt payroll': 1, 'ovia fargo account': 1, 'bony sweep account': 1, 'payroll checks': 1, 'premium market rate 4': 1}
# PPL: {'peters road': 1, 'dan butler': 5, 'linda p taylor': 5, 'account number': 1, 'brian stern': 6, 'ingrid king': 6, 'account type': 4, 'lock box': 2, 'steve giurlando': 3, 'matthew louis': 3, 'jennifer ford': 3, 'marilinda martinez': 3, 'spencer kennedy': 4, 'eileen mork': 4, 'wan h': 1}
#
#
# 6869581
# ORGS: {'spizz  johns': 1, 'pc couns': 1, 'rock  republic enterprises inc': 1, 'triple r inc': 1, 'eastern time': 2}
# PPL: {'alex spizz': 2, 'arthur goldstein': 3, 'jill makower': 2, 'arthur j gonzalez': 2}
#
#
# 6864631
# ORGS: {'akin gump strauss hauer  fd llp': 2, 'couns for alclear': 1, 'henry inc': 1}
# PPL: {'phil dublin': 1, 'dionisia kaloudis': 1, 'estela diaz': 1}
# 6944571
# ORGS: {'va presto': 1, 'health care business single asset real estate': 1, 'llp partnership': 1, 'clearing bank other': 1, 'tenant of residential property': 1, 'firm name': 1, 'hvattii hq': 1, 'pasta bar': 2, 'ross riedman ference llp': 1, 'sichenzia ross friedman ference llp': 2}
# PPL: {'pasta bar': 1, 'filing fee': 3, 'official form': 1, 'nonmain proceeding': 1, 'ie iii iii iii iii': 1, 'ralph preite': 2, 'ralph e preite': 1, 'john scotto': 5, 'printed name': 1, 'scotto ii': 4}
#
#
# 6934898
# ORGS: {'proposed couns': 2, 'binder  binder': 26, 'ssdi holdings inc': 1, 'national veterans disability advocates llc': 2, 'us bank national association': 1, 'stlus capital investment corporation': 1, 'moore  van allen pllc': 1, 'lowenstein sandler llp': 1, 'ssdi holdings': 1, '8 binder  binder': 1, 'katten muchin rosenman llp': 1}
# PPL: {'lowenstein sandler llp kenneth a rosen': 1, 'nicholas b vislocky': 2, 'joseph lubertazzi': 1, 'kenneth j ottaviano': 1, 'stephen e gruendel': 1, 'kenneth a rosen': 2}
#
#
# 53052587
# ORGS: {}
# PPL: {'mylene liggett': 3}
#
#
# 11079383
# ORGS: {'mf global holdings ltd': 3, 'plan administrator': 2, 'sapere cta fund': 3, 'global holdings ltd': 1, 'global finance usa inc': 1, 'mf global capital llc': 2, 'global market services llc': 2, 'mf global holdings usa inc': 2, 'mf global': 1, 'assigned assets llc': 1, 'mf global finance usa inc': 1, 'mf global fx clear llc': 1, 'di 1382': 1, 'individual defendants': 1, 'coo of mfgh': 1, 'coo of holdings': 1, 'board of directors': 1, 'mf global inc': 2, 'sipa trustee': 1, 'trustee of the mf global litigation trust': 1, 'term sheet': 3, 'litigation trustee': 2, 'cftc corzine reserve': 1, 'cftc obrien reserve': 1, 'identied dissenters policies': 1, 'customer class couns': 1, 'defendants and settling plaintiffs': 1, 'insurers and defendants': 1, 'mfg plaintiffs': 1, 'litigation trust action': 1, 'eo policies': 2, 's erikm': 1, 'securities lead plaintiffs': 1}
# PPL: {'michael schneidereit': 1, 'bruce bennett': 1, 'jane rue wittstein': 1, 'erik m graber': 2, 'nader tavakoli': 3, 'j rue wittstein': 1, 'victor marrero': 1, 'hayes decl': 2, 'fn hanm n': 1, 'jon s corzine': 1, 'bradley abelow': 1, 'henri steenkamp': 1, 'david dunne': 1, 'vinay mahaj': 1, 'nonnnfnnn flnnf': 1, 'cofflomonf a nroomonf': 1, 'releases of the released insurer parties': 1, 'salvatore j graziano': 1, 'javier bleichmar': 1, 'lead plaintis': 1}
#
#
# 6944578
# ORGS: {'pasta bar': 1, 'va presto 61 broadway 32nd': 1, 'federal office building': 1, 'cox padmore skolnik  shakarchy llp': 1, 'bowling green new york': 1, 'shakarchy llp': 1}
# PPL: {'scotto ii': 2, 'ralph e preite': 1, 'sichenzia ross friedman ference': 1, 'myron i altschuler': 1, 'martin glenn': 1, 'cox padmore': 1, 'stefan b kalina': 1}
#
#
# 6883495
# ORGS: {'rattet pasternak llp': 2, 'mamaroneck avenue harrison': 2, 'chapter 11 ango  maxies': 1, 'capital one': 8, 'north fork bank': 1, 'uccl financing statements': 1, 'swedand devopment group inc': 1, 'dunes casino hot 69 br': 1, 'coors of the cumberland 19 br': 1, 'nice 355 br': 1, 'snowshoe co': 1, 'moslo 195 br': 1, 'beker industries corp': 1, 'usc section': 1, 'capital ones': 2, 'rattet pasternak': 1}
# PPL: {'robert l rattet': 3, 'dawn kirby arnold': 1, 'shelley c chapman': 1}
#
#
# 11088684
# ORGS: {'federal tax ld': 1, 'bzgblo drwszom': 1, 'disbursenient s': 1, 'ayroll taxes': 1, 'utilities water  sewer expense': 1, 'ofce supplies': 1, 'taxes icenses': 1, 'usc section': 1, 'reorganization items  interest earned on accumulated cash': 1, 'other postetition': 1, 'liabilities loan': 1, 'secured debtadequate protection pa': 1, 'leases payable and adequate protection': 1, 'e bank': 1, 'gofng forward': 1, 'busin essmaram': 1, 'eectmnic payments  post': 1, 'tee heavenly higeway': 1, 'batanc e sum mar': 1}
# PPL: {'chariots of the heaven': 1, 'attached attached': 1, 'chariots of the': 5, 'chariots of the heavenly highwax case no': 1, 'mmee seol': 1, 'pettn receva': 1, 'ietor e': 1, 'awmge cotieqred': 1, 'paid kn': 1, 'n dane': 1}
#
#
# 12664862
# ORGS: {'trade prosperity inc': 5, '2 corporation': 1, 'limited liability company': 1, 'limited liability partnership': 1, ' health care business': 1, 'ci clearing bank': 1, 'ci investment': 1, 'north american industry classification system': 1, '15 estmated': 1, 'togut segal  segal llp': 2, 'marine management': 1, 'management bulk services': 1, 'brokerage and management corporation': 1, 'a new york corporation': 1, 'annex ii': 1, 'sky inc': 1, 'industrial devopment corporation 9united': 1, 'trade will': 2, 'united leadership inc 12united seas': 1, 'unity inc': 1, 'horizon inc 24trade': 1, 'transport inc': 1, 'togut firm': 1, 'scura paley and company': 1, 'companys directors': 1, 'dnb bank asa': 1, 'ec3 8hy': 1, 'attn shipping offshore  logistics fax': 1, 'united kalavryta': 1, 'united leadershiptrade vision': 1, 'united ideal': 1, 'toisa limited': 28, 'united courage inc': 4, 'trade vision': 1, 'ing bank': 1, 'transportation finance': 2, 'global credit restructuring': 1, 'citibank international plc': 1, 'citigroup centre': 1, 'european loans agency': 1, 'trade unity': 1, 'trade prosperity trade resource': 1, 'toisa sonata  warrior': 1, 'toisa an': 1, 'toisa wave': 1, 'bnp paribas sa': 1, 'toisa paladin': 1, 'value preservation group': 2, 'trade vision inc': 3, 'united journey inc': 3, 'united kalavryta inc': 3, 'trade sky inc': 2, 'trade industrial devopment corporation': 3, 'united honor inc': 3, 'trade will inc': 3, 'united leadership inc': 3, 'united seas inc': 3, 'united dynamic inc': 3, 'united emblem inc': 3, 'united ideal inc': 3, 'trade unity inc': 3, 'trade quest inc': 3, 'sealion shipping': 1, 'marine management services': 1, 'marine management bulker services': 1, 'iiangdu china shipping industry': 1, 'iiangsu co ltd river cityjiangsu provice': 1, 'chris price forbes  partners ltd': 1, 'sealion insurance': 1, 'bunkersfus athens': 1, 'american bureau of shipping': 1, 'stockbridge shipbrokers limited': 1, 'carlson wagonlit trav': 1, 'lloyds register': 1, 'mms  mmbs': 5, 'linikes radioypiresies ae': 1, 'nordic maritime services': 1, 'marine and industrial supplies inc': 1, 'royce marine benux bv': 1, 'johns port authority': 1, 'kongsberg maritime do av rio branco': 1, 'brasil sa rio de ianeiro': 1, 'quai de afritramp paris dion': 1, 'paris sealion 1758190 alga godefroy ouanda': 1, 'pontchartrain drive usg services': 1, 'wilhmsen ships service': 1, 'lysaker norway': 1, 'aktienslschaft germany sealion 1285712': 1, 'pf collins customs broker t': 1, 'ltd po': 1, 'canada sealion vendor 800078': 1, 'ocala enterprises inc': 1, 'edgewater offshore shipping ltd': 1, 'trade and transport inc': 18, 'toisa horizon inc': 1, 'united ambassador inc': 1, 'united banner inc': 1, 'inn trade resource': 1, 'trade sky': 1, 'trade spirit inc': 1, 'trade resource inc': 1}
# PPL: {'akti miaouli': 1, 'c naics': 1, 'richard w baldwin': 6, 'dd yyyy': 1, 'albert togut': 1, 'robert charles hennebry': 1, 'lygeri peirounaki': 2, 'henrik soogard': 1, 'toisa daring': 1, 'toisa defiant': 1, 'toisa dauntless': 1, 'j taiala': 1, 'bernadette smailes': 1, 'adam byrne': 1, 'david grant': 1, 'joeri van de moosdijk': 1, 'neil shah': 1, 'jonathan medcalf': 1, 'toisa serenade': 1, 'toisa envoy': 1, 'toisa explorer': 1, 'toisa pegasus': 1, 'pierre ceyssens': 1, 'karin odenthal': 1, 'inez edcewater offshore shihhino': 1, 'yingzhou rd': 1, 'taylor graham': 1, 'poseidonos av': 1, 'greek repr': 1, 'navarinou kallithea': 1, 'enquiriesseainscm ann langham': 1, 'dimitris parikidis': 1, 'david gaham': 1, 'skouze  str': 1, 'george christou': 1, 'mrs maria orfanidou': 1, 'vadims bazenovs': 1, 'mrs kladia': 1, 'marcos silva': 1, 'allen guthrie': 1, 'dennis foster': 1, 'inez iinited ambassador': 1, 'inez edcewater offshore shinnino': 1}
#
#
# 6864606
# ORGS: {'henry inc': 1, 'official committee of unsecured creditors': 1, 'hanify  king': 1, 'any committee': 1, 'bid for the': 1, 's stuart m bernstein': 1}
# PPL: {'stuart m bernstein': 1}

# %%
print_top_3(file_to_orgs["6871731"])
# Out:
# 9 boston generating
# 6 general couns
# 6 ebg holdings

# %%
agg_dict(file_to_orgs["6871731"])
# Out:
# {'boston generating': 7, 'sithe boston generating': 1, 'exon boston generating': 1, 'fifth avenue': 2, ' single asset real estate': 1, 'llp  railroad': 1, ' clearing bank': 1, 'tenant of residential preperty': 1, 'boston generatin llc': 1, 'latham  watkins llp d': 1, 'states code': 1, 'ebg holdings llc': 5, 'fore river devopment': 1, 'mystic devopment': 1, 'bg new england power services': 1, 'bg boston services': 1, 'llc action by': 1, 'a daware limited liability company': 1, 'constlation holdings inc': 2, 'constlation energy group inc': 1, 'retention of professionals': 1, 'latham  watkins llp': 3, 'jp morgan securities': 1, 'perla weinberg partners': 1, 'brown rudnick llp': 1, 'fti consulting': 1, 'anderson kill  olick': 1, 'authorized representative of the company': 1, 'joint administration requested': 2, 'department of creditor': 5, 'agency loan operations': 1, 'credit suisse': 1, 'administrative agent for the lenders': 1, 'lipton rosen  katz': 1, 'harold olsen stroock  stroock  lavan llp': 1, 'distrigas of massachusetts': 1, 'stroock  stroock  lavan llp': 1, 'commerce road': 2, 'trade debt': 2, 'mitsubishi power systems inc': 1, 'spectra energy': 1, 'pension benet guaranty corporation': 1, 'national grid': 1, 'exxon mobile': 1, 'borden  remington corporation': 1, 'integrated it solutions': 1, 'agent or department of creditor familiar with claim': 1, 'city clerk': 1, 'general couns': 5, 'overland road waltham': 1, 'ma 024511729': 1, 'solutions center': 1, 'new england controls inc': 1, 'clean harbors': 1, 'avenida empresa': 1, 'control components inc': 1, 'dept 2544': 1, 'chalmers  kubeck north air industrial park': 1, 'atlantic contracting  special': 1, 'general couns 55': 1, 'standard  poors': 1, 'mechanical dynamics  analysis': 1, 'american blvd': 1, 'adams valves inc': 1, 'stallion companies': 1, 'mitchl services inc': 1, 'capco crane  hoist inc': 1, 'keystone engineering corp': 1, 'joint administration': 2, 'ebg holdings': 1, 'eguityholder percent ownership': 2, 'new astoria generating company holdings': 1, 'us power generating company us': 1, 'madison dearborn capital partners iv': 1, 'ownership of new astoria generating company holdin': 1}
# sithe boston generating -> boston generating
# exon boston generating -> boston generating
# latham  watkins llp d -> latham  watkins llp
# ebg holdings llc -> ebg holdings
# general couns 55 -> general couns
# {'boston generating': 9, 'fifth avenue': 2, ' single asset real estate': 1, 'llp  railroad': 1, ' clearing bank': 1, 'tenant of residential preperty': 1, 'boston generatin llc': 1, 'states code': 1, 'fore river devopment': 1, 'mystic devopment': 1, 'bg new england power services': 1, 'bg boston services': 1, 'llc action by': 1, 'a daware limited liability company': 1, 'constlation holdings inc': 2, 'constlation energy group inc': 1, 'retention of professionals': 1, 'latham  watkins llp': 4, 'jp morgan securities': 1, 'perla weinberg partners': 1, 'brown rudnick llp': 1, 'fti consulting': 1, 'anderson kill  olick': 1, 'authorized representative of the company': 1, 'joint administration requested': 2, 'department of creditor': 5, 'agency loan operations': 1, 'credit suisse': 1, 'administrative agent for the lenders': 1, 'lipton rosen  katz': 1, 'harold olsen stroock  stroock  lavan llp': 1, 'distrigas of massachusetts': 1, 'stroock  stroock  lavan llp': 1, 'commerce road': 2, 'trade debt': 2, 'mitsubishi power systems inc': 1, 'spectra energy': 1, 'pension benet guaranty corporation': 1, 'national grid': 1, 'exxon mobile': 1, 'borden  remington corporation': 1, 'integrated it solutions': 1, 'agent or department of creditor familiar with claim': 1, 'city clerk': 1, 'general couns': 6, 'overland road waltham': 1, 'ma 024511729': 1, 'solutions center': 1, 'new england controls inc': 1, 'clean harbors': 1, 'avenida empresa': 1, 'control components inc': 1, 'dept 2544': 1, 'chalmers  kubeck north air industrial park': 1, 'atlantic contracting  special': 1, 'standard  poors': 1, 'mechanical dynamics  analysis': 1, 'american blvd': 1, 'adams valves inc': 1, 'stallion companies': 1, 'mitchl services inc': 1, 'capco crane  hoist inc': 1, 'keystone engineering corp': 1, 'joint administration': 2, 'ebg holdings': 6, 'eguityholder percent ownership': 2, 'new astoria generating company holdings': 1, 'us power generating company us': 1, 'madison dearborn capital partners iv': 1, 'ownership of new astoria generating company holdin': 1}
# {'boston generating': 9,
#  'fifth avenue': 2,
#  ' single asset real estate': 1,
#  'llp  railroad': 1,
#  ' clearing bank': 1,
#  'tenant of residential preperty': 1,
#  'boston generatin llc': 1,
#  'states code': 1,
#  'fore river devopment': 1,
#  'mystic devopment': 1,
#  'bg new england power services': 1,
#  'bg boston services': 1,
#  'llc action by': 1,
#  'a daware limited liability company': 1,
#  'constlation holdings inc': 2,
#  'constlation energy group inc': 1,
#  'retention of professionals': 1,
#  'latham  watkins llp': 4,
#  'jp morgan securities': 1,
#  'perla weinberg partners': 1,
#  'brown rudnick llp': 1,
#  'fti consulting': 1,
#  'anderson kill  olick': 1,
#  'authorized representative of the company': 1,
#  'joint administration requested': 2,
#  'department of creditor': 5,
#  'agency loan operations': 1,
#  'credit suisse': 1,
#  'administrative agent for the lenders': 1,
#  'lipton rosen  katz': 1,
#  'harold olsen stroock  stroock  lavan llp': 1,
#  'distrigas of massachusetts': 1,
#  'stroock  stroock  lavan llp': 1,
#  'commerce road': 2,
#  'trade debt': 2,
#  'mitsubishi power systems inc': 1,
#  'spectra energy': 1,
#  'pension benet guaranty corporation': 1,
#  'national grid': 1,
#  'exxon mobile': 1,
#  'borden  remington corporation': 1,
#  'integrated it solutions': 1,
#  'agent or department of creditor familiar with claim': 1,
#  'city clerk': 1,
#  'general couns': 6,
#  'overland road waltham': 1,
#  'ma 024511729': 1,
#  'solutions center': 1,
#  'new england controls inc': 1,
#  'clean harbors': 1,
#  'avenida empresa': 1,
#  'control components inc': 1,
#  'dept 2544': 1,
#  'chalmers  kubeck north air industrial park': 1,
#  'atlantic contracting  special': 1,
#  'standard  poors': 1,
#  'mechanical dynamics  analysis': 1,
#  'american blvd': 1,
#  'adams valves inc': 1,
#  'stallion companies': 1,
#  'mitchl services inc': 1,
#  'capco crane  hoist inc': 1,
#  'keystone engineering corp': 1,
#  'joint administration': 2,
#  'ebg holdings': 6,
#  'eguityholder percent ownership': 2,
#  'new astoria generating company holdings': 1,
#  'us power generating company us': 1,
#  'madison dearborn capital partners iv': 1,
#  'ownership of new astoria generating company holdin': 1}

# %%
# returns a map of people+counts for multiple files
# parameter: array of strings of file names
def mult_files_ppl(files):
    if len(files) == 0 or files[0] not in file_to_ppl: 
        return None
    starting_set = file_to_ppl[files[0]]
    for index in range(1,len(files)):
        curr_ppl = file_to_ppl[files[index]]
        # add this files' items to starting_set
        for name, count in curr_ppl.items():
            if name in starting_set:
                starting_set[name] = starting_set[name] + count
            else:
                starting_set[name] = count
    return starting_set
