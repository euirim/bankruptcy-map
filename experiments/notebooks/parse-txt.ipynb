# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
txt = open("../txt-files/pgb38llc.txt").read()

# %%
# Read in entire document
doc = nlp(txt)
print(doc.text)
# Out:
#              17-12211-smb             Doc 1        Filed 08/09/17           Entered 08/09/17 15:59:37                   Main Document
#                                                                            Pg 1 of 13
# Fill in this information to identify your case:
#
# United States Bankruptcy Court for the:
#
# SOUTHERN DISTRICT OF NEW YORK
#
# Case number (if known)                                                      Chapter      11
#                                                                                                                               Check if this an
#                                                                                                                               amended filing
#
#
#
#
# Official Form 201
# Voluntary Petition for Non-Individuals Filing for Bankruptcy                                                                                           4/16
# If more space is needed, attach a separate sheet to this form. On the top of any additional pages, write the debtor's name and case number (if known).
# For more information, a separate document, Instructions for Bankruptcy Forms for Non-Individuals, is available.
#
#
# 1.   Debtor's name                PGB 38 LLC
#
# 2.   All other names debtor
#      used in the last 8 years
#      Include any assumed
#      names, trade names and
#      doing business as names
#
# 3.   Debtor's federal
#      Employer Identification      XX-XXXXXXX
#      Number (EIN)
#
#
# 4.   Debtor's address             Principal place of business                                     Mailing address, if different from principal place of
#                                                                                                   business
#
#                                   1572 2nd Avenue
#                                   New York, NY 10028
#                                   Number, Street, City, State & ZIP Code                          P.O. Box, Number, Street, City, State & ZIP Code
#
#                                   New York                                                        Location of principal assets, if different from principal
#                                   County                                                          place of business
#
#                                                                                                   Number, Street, City, State & ZIP Code
#
#
# 5.   Debtor's website (URL)
#
#
# 6.   Type of debtor                   Corporation (including Limited Liability Company (LLC) and Limited Liability Partnership (LLP))
#                                       Partnership (excluding LLP)
#                                       Other. Specify:
#
#
#
#
# Official Form 201                          Voluntary Petition for Non-Individuals Filing for Bankruptcy                                              page 1
#              17-12211-smb               Doc 1           Filed 08/09/17         Entered 08/09/17 15:59:37                          Main Document
#                                                                               Pg 2 of 13
# Debtor    PGB 38 LLC                                                                                   Case number (if known)
#           Name
#
#
#
# 7.   Describe debtor's business        A. Check one:
#                                           Health Care Business (as defined in 11 U.S.C. § 101(27A))
#                                           Single Asset Real Estate (as defined in 11 U.S.C. § 101(51B))
#                                           Railroad (as defined in 11 U.S.C. § 101(44))
#                                           Stockbroker (as defined in 11 U.S.C. § 101(53A))
#                                           Commodity Broker (as defined in 11 U.S.C. § 101(6))
#                                           Clearing Bank (as defined in 11 U.S.C. § 781(3))
#
#                                           None of the above
#
#                                        B. Check all that apply
#                                           Tax-exempt entity (as described in 26 U.S.C. §501)
#                                           Investment company, including hedge fund or pooled investment vehicle (as defined in 15 U.S.C. §80a-3)
#                                           Investment advisor (as defined in 15 U.S.C. §80b-2(a)(11))
#
#                                        C. NAICS (North American Industry Classification System) 4-digit code that best describes debtor.
#                                           See http://www.uscourts.gov/four-digit-national-association-naics-codes.
#
#
#
# 8.   Under which chapter of the        Check one:
#      Bankruptcy Code is the
#                                           Chapter 7
#      debtor filing?
#                                           Chapter 9
#
#                                           Chapter 11. Check all that apply:
#                                                                  Debtor's aggregate noncontingent liquidated debts (excluding debts owed to insiders or affiliates)
#                                                                  are less than $2,566,050 (amount subject to adjustment on 4/01/19 and every 3 years after that).
#                                                                  The debtor is a small business debtor as defined in 11 U.S.C. § 101(51D). If the debtor is a small
#                                                                  business debtor, attach the most recent balance sheet, statement of operations, cash-flow
#                                                                  statement, and federal income tax return or if all of these documents do not exist, follow the
#                                                                  procedure in 11 U.S.C. § 1116(1)(B).
#                                                                  A plan is being filed with this petition.
#                                                                  Acceptances of the plan were solicited prepetition from one or more classes of creditors, in
#                                                                  accordance with 11 U.S.C. § 1126(b).
#                                                                  The debtor is required to file periodic reports (for example, 10K and 10Q) with the Securities and
#                                                                  Exchange Commission according to § 13 or 15(d) of the Securities Exchange Act of 1934. File the
#                                                                  attachment to Voluntary Petition for Non-Individuals Filing for Bankruptcy under Chapter 11
#                                                                  (Official Form 201A) with this form.
#                                                                  The debtor is a shell company as defined in the Securities Exchange Act of 1934 Rule 12b-2.
#                                           Chapter 12
#
#
#
# 9.   Were prior bankruptcy                No.
#      cases filed by or against
#      the debtor within the last 8         Yes.
#      years?
#      If more than 2 cases, attach a
#      separate list.                               District                                When                                  Case number
#                                                   District                                When                                  Case number
#
#
# 10. Are any bankruptcy cases              No
#     pending or being filed by a
#     business partner or an                Yes.
#     affiliate of the debtor?
#      List all cases. If more than 1,
#      attach a separate list                       Debtor                                                                    Relationship
#                                                   District                                When                              Case number, if known
#
#
#
#
# Official Form 201                               Voluntary Petition for Non-Individuals Filing for Bankruptcy                                              page 2
#             17-12211-smb             Doc 1           Filed 08/09/17         Entered 08/09/17 15:59:37                        Main Document
#                                                                            Pg 3 of 13
# Debtor   PGB 38 LLC                                                                                Case number (if known)
#          Name
#
#
#
# 11. Why is the case filed in    Check all that apply:
#     this district?
#                                          Debtor has had its domicile, principal place of business, or principal assets in this district for 180 days immediately
#                                          preceding the date of this petition or for a longer part of such 180 days than in any other district.
#                                          A bankruptcy case concerning debtor's affiliate, general partner, or partnership is pending in this district.
#
# 12. Does the debtor own or          No
#     have possession of any
#     real property or personal                Answer below for each property that needs immediate attention. Attach additional sheets if needed.
#                                     Yes.
#     property that needs
#     immediate attention?                     Why does the property need immediate attention? (Check all that apply.)
#                                                 It poses or is alleged to pose a threat of imminent and identifiable hazard to public health or safety.
#                                                What is the hazard?
#                                                 It needs to be physically secured or protected from the weather.
#                                                 It includes perishable goods or assets that could quickly deteriorate or lose value without attention (for example,
#                                                livestock, seasonal goods, meat, dairy, produce, or securities-related assets or other options).
#                                                 Other
#                                              Where is the property?
#                                                                               Number, Street, City, State & ZIP Code
#                                              Is the property insured?
#                                                 No
#                                                 Yes.    Insurance agency
#                                                         Contact name
#                                                         Phone
#
#
#
#          Statistical and administrative information
#
# 13. Debtor's estimation of      .         Check one:
#     available funds
#                                              Funds will be available for distribution to unsecured creditors.
#                                              After any administrative expenses are paid, no funds will be available to unsecured creditors.
#
# 14. Estimated number of             1-49                                             1,000-5,000                                 25,001-50,000
#     creditors                                                                        5001-10,000                                 50,001-100,000
#                                     50-99
#                                     100-199                                          10,001-25,000                               More than100,000
#                                     200-999
#
# 15. Estimated Assets                $0 - $50,000                                     $1,000,001 - $10 million                    $500,000,001 - $1 billion
#                                     $50,001 - $100,000                               $10,000,001 - $50 million                   $1,000,000,001 - $10 billion
#                                     $100,001 - $500,000                              $50,000,001 - $100 million                  $10,000,000,001 - $50 billion
#                                     $500,001 - $1 million                            $100,000,001 - $500 million                 More than $50 billion
#
#
# 16. Estimated liabilities           $0 - $50,000                                     $1,000,001 - $10 million                    $500,000,001 - $1 billion
#                                     $50,001 - $100,000                               $10,000,001 - $50 million                   $1,000,000,001 - $10 billion
#                                     $100,001 - $500,000                              $50,000,001 - $100 million                  $10,000,000,001 - $50 billion
#                                     $500,001 - $1 million                            $100,000,001 - $500 million                 More than $50 billion
#
#
#
#
# Official Form 201                           Voluntary Petition for Non-Individuals Filing for Bankruptcy                                                   page 3
#             17-12211-smb                 Doc 1     Filed 08/09/17          Entered 08/09/17 15:59:37                        Main Document
#                                                                           Pg 4 of 13
# Debtor    PGB 38 LLC                                                                               Case number (if known)
#           Name
#
#
#
#           Request for Relief, Declaration, and Signatures
#
# WARNING -- Bankruptcy fraud is a serious crime. Making a false statement in connection with a bankruptcy case can result in fines up to $500,000 or
#            imprisonment for up to 20 years, or both. 18 U.S.C. §§ 152, 1341, 1519, and 3571.
#
# 17. Declaration and signature
#     of authorized                The debtor requests relief in accordance with the chapter of title 11, United States Code, specified in this petition.
#     representative of debtor
#                                  I have been authorized to file this petition on behalf of the debtor.
#
#                                  I have examined the information in this petition and have a reasonable belief that the information is trued and correct.
#
#                                  I declare under penalty of perjury that the foregoing is true and correct.
#
#                                  Executed on      August 8, 2017
#                                                   MM / DD / YYYY
#
#
#                              X   /s/ Philip Menegis                                                       Philip Menegis
#                                  Signature of authorized representative of debtor                         Printed name
#
#                                  Title    Managing Member
#
#
#
#
# 18. Signature of attorney    X   /s/ Gregory M. Messer                                                     Date August 8, 2017
#                                  Signature of attorney for debtor                                               MM / DD / YYYY
#
#                                  Gregory M. Messer
#                                  Printed name
#
#                                  Law Office of Gregory Messer
#                                  Firm name
#
#                                  Law Office of Gregory Messer
#                                  26 Court Street, Suite 2400
#                                  Brooklyn, NY 11242
#                                  Number, Street, City, State & ZIP Code
#
#
#                                  Contact phone     718-858-1474                  Email address      gremesser@aol.com
#
#                                  1388339
#                                  Bar number and State
#
#
#
#
# Official Form 201                          Voluntary Petition for Non-Individuals Filing for Bankruptcy                                                   page 4
#           17-12211-smb                    Doc 1          Filed 08/09/17             Entered 08/09/17 15:59:37                Main Document
#                                                                                    Pg 5 of 13
#
#
#
#
#  Fill in this information to identify the case:
#
#  Debtor name         PGB 38 LLC
#
#  United States Bankruptcy Court for the:            SOUTHERN DISTRICT OF NEW YORK
#
#  Case number (if known)
#                                                                                                                                   Check if this is an
#                                                                                                                                   amended filing
#
#
#
# Official Form 202
# Declaration Under Penalty of Perjury for Non-Individual Debtors                                                                                         12/15
#
# An individual who is authorized to act on behalf of a non-individual debtor, such as a corporation or partnership, must sign and submit this
# form for the schedules of assets and liabilities, any other document that requires a declaration that is not included in the document, and any
# amendments of those documents. This form must state the individual’s position or relationship to the debtor, the identity of the document,
# and the date. Bankruptcy Rules 1008 and 9011.
#
# WARNING -- Bankruptcy fraud is a serious crime. Making a false statement, concealing property, or obtaining money or property by fraud in
# connection with a bankruptcy case can result in fines up to $500,000 or imprisonment for up to 20 years, or both. 18 U.S.C. §§ 152, 1341,
# 1519, and 3571.
#
#
#
#                 Declaration and signature
#
#
#        I am the president, another officer, or an authorized agent of the corporation; a member or an authorized agent of the partnership; or another
#        individual serving as a representative of the debtor in this case.
#
#        I have examined the information in the documents checked below and I have a reasonable belief that the information is true and correct:
#
#                   Schedule A/B: Assets–Real and Personal Property (Official Form 206A/B)
#                   Schedule D: Creditors Who Have Claims Secured by Property (Official Form 206D)
#                   Schedule E/F: Creditors Who Have Unsecured Claims (Official Form 206E/F)
#                   Schedule G: Executory Contracts and Unexpired Leases (Official Form 206G)
#                   Schedule H: Codebtors (Official Form 206H)
#                   Summary of Assets and Liabilities for Non-Individuals (Official Form 206Sum)
#                   Amended Schedule
#                   Chapter 11 or Chapter 9 Cases: List of Creditors Who Have the 20 Largest Unsecured Claims and Are Not Insiders (Official Form 204)
#                   Other document that requires a declaration
#
#        I declare under penalty of perjury that the foregoing is true and correct.
#
#         Executed on          August 8, 2017                          X /s/ Philip Menegis
#                                                                        Signature of individual signing on behalf of debtor
#
#                                                                        Philip Menegis
#                                                                        Printed name
#
#                                                                        Managing Member
#                                                                        Position or relationship to debtor
#
#
#
#
# Official Form 202                                             Declaration Under Penalty of Perjury for Non-Individual Debtors
# Software Copyright (c) 1996-2017 Best Case, LLC - www.bestcase.com                                                                         Best Case Bankruptcy
#                17-12211-smb                    Doc 1          Filed 08/09/17         Entered 08/09/17 15:59:37                             Main Document
#                                                                                     Pg 6 of 13
#
#  Fill in this information to identify the case:
#  Debtor name PGB 38 LLC
#  United States Bankruptcy Court for the: SOUTHERN DISTRICT OF NEW                                                                                     Check if this is an
#                                                 YORK
#  Case number (if known):                                                                                                                              amended filing
#
#
#
#
# Official Form 204
# Chapter 11 or Chapter 9 Cases: List of Creditors Who Have the 20 Largest Unsecured Claims and
# Are Not Insiders                                                                           12/15
#
# A list of creditors holding the 20 largest unsecured claims must be filed in a Chapter 11 or Chapter 9 case. Include claims which the
# debtor disputes. Do not include claims by any person or entity who is an insider, as defined in 11 U.S.C. § 101(31). Also, do not
# include claims by secured creditors, unless the unsecured claim resulting from inadequate collateral value places the creditor
# among the holders of the 20 largest unsecured claims.
#
#  Name of creditor and      Name, telephone number Nature of claim                        Indicate if claim   Amount of claim
#  complete mailing address, and email address of   (for example, trade                     is contingent,     If the claim is fully unsecured, fill in only unsecured claim amount. If
#  including zip code        creditor contact       debts, bank loans,                     unliquidated, or    claim is partially secured, fill in total claim amount and deduction for
#                                                   professional services,                     disputed        value of collateral or setoff to calculate unsecured claim.
#                                                   and government                                             Total claim, if            Deduction for value        Unsecured claim
#                                                   contracts)                                                 partially secured          of collateral or setoff
#  Con Edison                                                                             Unliquidated                                                                      $21,943.21
#  Cooper Station                                                                         Disputed
#  P.O. Box 138
#  New York, NY
#  10276-0138
#  Internal Revenue                                                                                                                                                                 $0.00
#  Service
#  Department of the
#  Treasury
#  Holtsville, NY
#  11742-0480
#  Kimco 1572 Corp                                                 Commercial Lease Unliquidated                                                                          $116,485.16
#  1265 15TH ST., #1M                                              1572 2 Avenue, St Disputed
#  Fort Lee, NJ 07024                                              1
#                                                                  New York, NY
#                                                                  10028
#  New York State Dept                                                                                                                                                              $0.00
#  of
#  Taxation & Finance
#  WA Harriman
#  Campus
#  Albany, NY
#  12227-0001
#  NYC Department of                                                                                                                                                                $0.00
#  Finance
#  P.O. Box 3671
#  New York, NY
#  10008-3671
#
#
#
#
# Official form 204                                Chapter 11 or Chapter 9 Cases: List of Creditors Who Have the 20 Largest Unsecured claims                                 page 1
#
# Software Copyright (c) 1996-2017 Best Case, LLC - www.bestcase.com                                                                                            Best Case Bankruptcy
#             17-12211-smb                  Doc 1          Filed 08/09/17         Entered 08/09/17 15:59:37                 Main Document
#                                                                                Pg 7 of 13
# B2030 (Form 2030) (12/15)
#                                                                United States Bankruptcy Court
#                                                                      Southern District of New York
#  In re       PGB 38 LLC                                                                                        Case No.
#                                                                                       Debtor(s)                Chapter      11
#
#                           DISCLOSURE OF COMPENSATION OF ATTORNEY FOR DEBTOR(S)
# 1.     Pursuant to 11 U .S.C. § 329(a) and Fed. Bankr. P. 2016(b), I certify that I am the attorney for the above named debtor(s) and that
#        compensation paid to me within one year before the filing of the petition in bankruptcy, or agreed to be paid to me, for services rendered or to
#        be rendered on behalf of the debtor(s) in contemplation of or in connection with the bankruptcy case is as follows:
#              For legal services, I have agreed to accept                                                   $                20,000.00
#              Prior to the filing of this statement I have received                                         $                20,000.00
#              Balance Due                                                                                   $                      0.00
#
# 2.     The source of the compensation paid to me was:
#
#                   Debtor                  Other (specify):           Philip Menegis
#
# 3.     The source of compensation to be paid to me is:
#
#                   Debtor                  Other (specify):
#
# 4.          I have not agreed to share the above-disclosed compensation with any other person unless they are members and associates of my law firm.
#
#             I have agreed to share the above-disclosed compensation with a person or persons who are not members or associates of my law firm. A
#             copy of the agreement, together with a list of the names of the people sharing in the compensation is attached.
#
# 5.       In return for the above-disclosed fee, I have agreed to render legal service for all aspects of the bankruptcy case, including:
#
#        a.   Analysis of the debtor's financial situation, and rendering advice to the debtor in determining whether to file a petition in bankruptcy;
#        b.   Preparation and filing of any petition, schedules, statement of affairs and plan which may be required;
#        c.   Representation of the debtor at the meeting of creditors and confirmation hearing, and any adjourned hearings thereof;
#        d.   [Other provisions as needed]
#                  Negotiations with secured creditors to reduce to market value; exemption planning; preparation and filing of
#                  reaffirmation agreements and applications as needed; preparation and filing of motions pursuant to 11 USC
#                  522(f)(2)(A) for avoidance of liens on household goods.
#
# 6.     By agreement with the debtor(s), the above-disclosed fee does not include the following service:
#                Representation of the debtors in any dischargeability actions, judicial lien avoidances, relief from stay actions or
#                any other adversary proceeding.
#                                                                             CERTIFICATION
#        I certify that the foregoing is a complete statement of any agreement or arrangement for payment to me for representation of the debtor(s) in
#  this bankruptcy proceeding.
#
#      August 8, 2017                                                                   /s/ Gregory M. Messer
#      Date                                                                             Gregory M. Messer
#                                                                                       Signature of Attorney
#                                                                                       Law Office of Gregory Messer
#                                                                                       Law Office of Gregory Messer
#                                                                                       26 Court Street, Suite 2400
#                                                                                       Brooklyn, NY 11242
#                                                                                       718-858-1474 Fax: 718-797-5360
#                                                                                       gremesser@aol.com
#                                                                                       Name of law firm
#
#
#
#
# Software Copyright (c) 1996-2017 Best Case, LLC - www.bestcase.com                                                                         Best Case Bankruptcy
#           17-12211-smb                    Doc 1          Filed 08/09/17        Entered 08/09/17 15:59:37                         Main Document
#                                                                               Pg 8 of 13
#                                                                United States Bankruptcy Court
#                                                                      Southern District of New York
#  In re      PGB 38 LLC                                                                                                Case No.
#                                                                                     Debtor(s)                         Chapter        11
#
#                                                          LIST OF EQUITY SECURITY HOLDERS
# Following is the list of the Debtor's equity security holders which is prepared in accordance with rule 1007(a)(3) for filing in this Chapter 11 Case
#
#  Name and last known address or place of                             Security Class Number of Securities                         Kind of Interest
#  business of holder
#  Joseph Allaham                                                                                                                  Member
#  424 Madison Ave
#  New York, NY 10017
#
#  Philip Menegis                                                                                                                  Managing Member
#  1170 Ocean Pkwy
#  Brooklyn, NY 11230
#
#
# DECLARATION UNDER PENALTY OF PERJURY ON BEHALF OF CORPORATION OR PARTNERSHIP
#
#         I, the Managing Member of the corporation named as the debtor in this case, declare under penalty of perjury that I
# have read the foregoing List of Equity Security Holders and that it is true and correct to the best of my information and
# belief.
#
#
#
#  Date August 8, 2017                                                         Signature /s/ Philip Menegis
#                                                                                             Philip Menegis
#
#                        Penalty for making a false statement of concealing property: Fine of up to $500,000 or imprisonment for up to 5 years or both.
#                                                                         18 U.S.C. §§ 152 and 3571.
#
#
#
#
# Sheet 1 of 1 in List of Equity Security Holders
# Software Copyright (c) 1996-2017 Best Case, LLC - www.bestcase.com                                                                                      Best Case Bankruptcy
#           17-12211-smb                    Doc 1          Filed 08/09/17        Entered 08/09/17 15:59:37            Main Document
#                                                                               Pg 9 of 13
#
#
#
#
#                                                                United States Bankruptcy Court
#                                                                      Southern District of New York
#  In re      PGB 38 LLC                                                                                   Case No.
#                                                                                    Debtor(s)             Chapter     11
#
#
#
#
#                                                VERIFICATION OF CREDITOR MATRIX
#
#
# I, the Managing Member of the corporation named as the debtor in this case, hereby verify that the attached list of creditors is true and
#
# correct to the best of my knowledge.
#
#
#
#
#  Date:       August 8, 2017                                             /s/ Philip Menegis
#                                                                         Philip Menegis/Managing Member
#                                                                         Signer/Title
#
#
#
#
# Software Copyright (c) 1996-2017 Best Case, LLC - www.bestcase.com                                                            Best Case Bankruptcy
#     17-12211-smb   Doc 1   Filed 08/09/17 Entered 08/09/17 15:59:37   Main Document
#                                          Pg 10 of 13
#
# }
# b
# k
# 1
# {
# C
# r
# e
# d
# i
# t
# o
# A
# s
# M
# a
# x
#
#
#
#
#                            CON EDISON
#                            COOPER STATION
#                            P.O. BOX 138
#                            NEW YORK, NY 10276-0138
#
#
#                            EMMANUELLI & PILOTTI, ESQS
#                            1188-A GRAND CONCOURSE
#                            BRONX, NY 10456
#
#
#                            INTERNAL REVENUE SERVICE
#                            DEPARTMENT OF THE TREASURY
#                            HOLTSVILLE, NY 11742-0480
#
#
#                            KIMCO 1572 CORP
#                            1265 15TH ST., #1M
#                            FORT LEE, NJ 07024
#
#
#                            NEW YORK STATE DEPT OF
#                            TAXATION & FINANCE
#                            WA HARRIMAN CAMPUS
#                            ALBANY, NY 12227-0001
#
#
#                            NYC DEPARTMENT OF FINANCE
#                            P.O. BOX 3671
#                            NEW YORK, NY 10008-3671
#
#
#                            TLE ASSOCIATES, INC.
#                            PO BOX 126 RIVERDALE STATION
#                            BRONX, NY 10471-0126
#           17-12211-smb                    Doc 1          Filed 08/09/17 Entered 08/09/17 15:59:37                    Main Document
#                                                                        Pg 11 of 13
#
#
#
#                                                                United States Bankruptcy Court
#                                                                      Southern District of New York
#  In re      PGB 38 LLC                                                                                    Case No.
#                                                                                   Debtor(s)               Chapter     11
#
#
#
#
#                                            CORPORATE OWNERSHIP STATEMENT (RULE 7007.1)
#
# Pursuant to Federal Rule of Bankruptcy Procedure 7007.1 and to enable the Judges to evaluate possible disqualification or
# recusal, the undersigned counsel for PGB 38 LLC in the above captioned action, certifies that the following is a (are)
# corporation(s), other than the debtor or a governmental unit, that directly or indirectly own(s) 10% or more of any class of
# the corporation's(s') equity interests, or states that there are no entities to report under FRBP 7007.1:
#
#
#
#     None [Check if applicable]
#
#
#
#
#  August 8, 2017                                                       /s/ Gregory M. Messer
#  Date                                                                 Gregory M. Messer
#                                                                       Signature of Attorney or Litigant
#                                                                       Counsel for PGB 38 LLC
#                                                                       Law Office of Gregory Messer
#                                                                       Law Office of Gregory Messer
#                                                                       26 Court Street, Suite 2400
#                                                                       Brooklyn, NY 11242
#                                                                       718-858-1474 Fax:718-797-5360
#                                                                       gremesser@aol.com
#
#
#
#
# Software Copyright (c) 1996-2017 Best Case, LLC - www.bestcase.com                                                             Best Case Bankruptcy
#           17-12211-smb                    Doc 1          Filed 08/09/17 Entered 08/09/17 15:59:37                    Main Document
#                                                                        Pg 12 of 13
#
#                                                                United States Bankruptcy Court
#                                                                      Southern District of New York
#  In re      PGB 38 LLC                                                                                    Case No.
#                                                                                   Debtor(s)               Chapter     11
#
#
#
#            STATEMENT REGARDING AUTHORITY TO SIGN AND FILE PETITION
#         I, Philip Menegis, declare under penalty of perjury that I am the Managing Member of PGB 38 LLC, and that
# the following is a true and correct copy of the resolutions adopted by the Board of Directors of said corporation
# at a special meeting duly called and held on the 7th day of August , 20 17 .
#
#       "Whereas, it is in the best interest of this corporation to file a voluntary petition in the United States
# Bankruptcy Court pursuant to Chapter 11 of Title 11 of the United States Code;
#
#         Be It Therefore Resolved, that Philip Menegis, Managing Member of this Corporation, is authorized and
# directed to execute and deliver all documents necessary to perfect the filing of a chapter 11 voluntary
# bankruptcy case on behalf of the corporation; and
#
#          Be It Further Resolved, that Philip Menegis, Managing Member of this Corporation is authorized and
# directed to appear in all bankruptcy proceedings on behalf of the corporation, and to otherwise do and perform
# all acts and deeds and to execute and deliver all necessary documents on behalf of the corporation in connection
# with such bankruptcy case, and
#
#         Be It Further Resolved, that Philip Menegis, Managing Member of this Corporation is authorized and
# directed to employ Gregory M. Messer, attorney and the law firm of Law Office of Gregory Messer to represent the
# corporation in such bankruptcy case."
#
#  Date 8 August 2017                                                             Signed s/ Philip Menegis
#                                                                                          Philip Menegis
#
#
#
#
# Software Copyright (c) 1996-2017 Best Case, LLC - www.bestcase.com                                                             Best Case Bankruptcy
#           17-12211-smb                    Doc 1          Filed 08/09/17 Entered 08/09/17 15:59:37               Main Document
#                                                                        Pg 13 of 13
#
#                                                                      Resolution of Board of Directors
#                                                                                     of
#                                                                                PGB 38 LLC
#
#
#
#
#       Whereas, it is in the best interest of this corporation to file a voluntary petition in the the United States
# Bankruptcy Court pursuant to Chapter 11 of Title 11 of the United States Code;
#
#         Be It Therefore Resolved, that Philip Menegis, Managing Member of this Corporation, is authorized and
# directed to execute and deliver all documents necessary to perfect the filing of a chapter 11 voluntary
# bankruptcy case on behalf of the corporation; and
#
#          Be It Further Resolved, that Philip Menegis, Managing Member of this Corporation is authorized and
# directed to appear in all bankruptcy proceedings on behalf of the corporation, and to otherwise do and perform
# all acts and deeds and to execute and deliver all necessary documents on behalf of the corporation in connection
# with such bankruptcy case, and
#
#         Be It Further Resolved, that Philip Menegis, Managing Member of this Corporation is authorized and
# directed to employ Gregory M. Messer, attorney and the law firm of Law Office of Gregory Messer to represent the
# corporation in such bankruptcy case.
#
#  Date 8 August 2017                                                              Signed     s/ Philip Menegis
#                                                                                             Philip Menegis
#
#
#  Date                                                                            Signed
#
#
#
#
# Software Copyright (c) 1996-2017 Best Case, LLC - www.bestcase.com                                                        Best Case Bankruptcy

# %%
# EXTRACT CHAPTER
# for token in doc:
#     print(token.text, token.pos_, token.dep_)
for i, token in enumerate(doc):
    if token.text.lower() == "chapter" and doc[i+1].pos_ == "SPACE" and doc[i+2].pos_ == "NUM":
            print(doc[i], doc[i+2])
# Out:
#               SPACE
# 17 NUM ROOT
# - SYM punct
# 12211-smb NUM prep
#              SPACE
# Doc PROPN nsubj
# 1 NUM nummod
#         SPACE
# Filed VERB compound
# 08/09/17 PROPN punct
#            SPACE
# Entered VERB compound
# 08/09/17 ADP punct
# 15:59:37 NUM case
#                    SPACE
# Main PROPN compound
# Document PROPN ROOT
#
#                                                                             SPACE
# Pg PROPN npadvmod
# 1 NUM nummod
# of ADP prep
# 13 NUM nummod
#
#  SPACE
# Fill PROPN pobj
# in ADP prep
# this DET det
# information NOUN pobj
# to PART aux
# identify VERB advcl
# your PRON poss
# case NOUN dobj
# : PUNCT punct
#
#
#  SPACE
# United PROPN compound
# States PROPN compound
# Bankruptcy PROPN compound
# Court PROPN appos
# for ADP prep
# the DET det
# : PUNCT punct
#
#
#  SPACE
# SOUTHERN PROPN compound
# DISTRICT NOUN pobj
# OF ADP prep
# NEW PROPN compound
# YORK PROPN nmod
#
#
#  SPACE
# Case PROPN compound
# number NOUN pobj
# ( PUNCT punct
# if SCONJ mark
# known VERB appos
# ) PUNCT punct
#                                                       SPACE
# Chapter PROPN appos
#       SPACE
# 11 NUM nummod
#
#                                                                                                                                SPACE
# Check VERB appos
# if SCONJ mark
# this DET nsubj
# an DET det
#
#                                                                                                                                SPACE
# amended VERB amod
# filing NOUN nmod
#
#
#
#
#
#  SPACE
# Official PROPN amod
# Form NOUN npadvmod
# 201 NUM nummod
#
#  SPACE
# Voluntary PROPN compound
# Petition PROPN appos
# for ADP prep
# Non NOUN dep
# - NOUN dep
# Individuals NOUN amod
# Filing VERB pobj
# for ADP prep
# Bankruptcy PROPN pobj
#                                                                                            SPACE
# 4/16 NUM nummod
#
#  SPACE
# If SCONJ mark
# more ADJ amod
# space NOUN nsubjpass
# is AUX auxpass
# needed VERB advcl
# , PUNCT punct
# attach VERB ROOT
# a DET det
# separate ADJ amod
# sheet NOUN dobj
# to ADP prep
# this DET det
# form NOUN pobj
# . PUNCT punct
# On ADP prep
# the DET det
# top NOUN pobj
# of ADP prep
# any DET det
# additional ADJ amod
# pages NOUN pobj
# , PUNCT punct
# write VERB ROOT
# the DET det
# debtor NOUN poss
# 's PART case
# name NOUN nmod
# and CCONJ cc
# case NOUN conj
# number NOUN dobj
# ( PUNCT punct
# if SCONJ mark
# known VERB parataxis
# ) PUNCT punct
# . PUNCT punct
#
#  SPACE
# For ADP prep
# more ADJ amod
# information NOUN pobj
# , PUNCT punct
# a DET det
# separate ADJ amod
# document NOUN nsubj
# , PUNCT punct
# Instructions PROPN nsubj
# for ADP prep
# Bankruptcy PROPN compound
# Forms PROPN pobj
# for ADP prep
# Non PROPN dep
# - NOUN dep
# Individuals NOUN pobj
# , PUNCT punct
# is AUX ROOT
# available ADJ acomp
# . PUNCT punct
#
#
#
#  SPACE
# 1 NUM ROOT
# . PUNCT punct
#    SPACE
# Debtor PROPN poss
# 's PART case
# name NOUN ROOT
#                 SPACE
# PGB PROPN appos
# 38 NUM nummod
# LLC PROPN ROOT
#
#
#  SPACE
# 2 NUM nummod
# . PUNCT punct
#    SPACE
# All DET det
# other ADJ amod
# names NOUN compound
# debtor NOUN dep
#
#       SPACE
# used VERB ROOT
# in ADP prep
# the DET det
# last ADJ amod
# 8 NUM nummod
# years NOUN pobj
#
#       SPACE
# Include VERB ROOT
# any DET det
# assumed VERB amod
#
#       SPACE
# names NOUN dobj
# , PUNCT punct
# trade NOUN compound
# names NOUN conj
# and CCONJ cc
#
#       SPACE
# doing VERB conj
# business NOUN dobj
# as SCONJ prep
# names NOUN pobj
#
#
#  SPACE
# 3 NUM npadvmod
# . PUNCT punct
#    SPACE
# Debtor PROPN poss
# 's PART case
# federal ADJ ROOT
#
#       SPACE
# Employer PROPN compound
# Identification PROPN appos
#       SPACE
# XX PROPN compound
# - PUNCT punct
# XXXXXXX PROPN appos
#
#       SPACE
# Number NOUN ROOT
# ( PUNCT punct
# EIN PROPN appos
# ) PUNCT punct
#
#
#
#  SPACE
# 4 NUM nummod
# . PUNCT punct
#    SPACE
# Debtor PROPN poss
# 's PART case
# address NOUN ROOT
#              SPACE
# Principal ADJ amod
# place NOUN appos
# of ADP prep
# business NOUN nmod
#                                      SPACE
# Mailing PROPN compound
# address NOUN pobj
# , PUNCT punct
# if SCONJ mark
# different ADJ advcl
# from ADP prep
# principal ADJ amod
# place NOUN pobj
# of ADP prep
#
#                                                                                                    SPACE
# business PROPN pobj
#
#
#                                    SPACE
# 1572 NUM nummod
# 2nd ADJ npadvmod
# Avenue PROPN appos
#
#                                    SPACE
# New PROPN compound
# York PROPN appos
# , PUNCT punct
# NY PROPN appos
# 10028 NUM nummod
#
#                                    SPACE
# Number PROPN ROOT
# , PUNCT punct
# Street PROPN npadvmod
# , PUNCT punct
# City PROPN conj
# , PUNCT punct
# State PROPN nmod
# & CCONJ cc
# ZIP PROPN conj
# Code PROPN conj
#                           SPACE
# P.O. PROPN compound
# Box PROPN ROOT
# , PUNCT punct
# Number PROPN conj
# , PUNCT punct
# Street PROPN conj
# , PUNCT punct
# City PROPN conj
# , PUNCT punct
# State PROPN nmod
# & CCONJ cc
# ZIP PROPN conj
# Code PROPN conj
#
#
#                                    SPACE
# New PROPN compound
# York PROPN appos
#                                                         SPACE
# Location PROPN appos
# of ADP prep
# principal ADJ amod
# assets NOUN pobj
# , PUNCT punct
# if SCONJ mark
# different ADJ amod
# from ADP prep
# principal ADJ pobj
#
#                                    SPACE
# County PROPN appos
#                                                           SPACE
# place NOUN appos
# of ADP prep
# business NOUN nmod
#
#
#                                                                                                    SPACE
# Number PROPN pobj
# , PUNCT punct
# Street PROPN nmod
# , PUNCT punct
# City PROPN conj
# , PUNCT punct
# State PROPN conj
# & CCONJ cc
# ZIP PROPN conj
# Code PROPN appos
#
#
#
#  SPACE
# 5 NUM pobj
# . PUNCT punct
#    SPACE
# Debtor PROPN poss
# 's PART case
# website NOUN ROOT
# ( PUNCT punct
# URL PROPN appos
# ) PUNCT punct
#
#
#
#  SPACE
# 6 NUM nummod
# . PUNCT punct
#    SPACE
# Type NOUN appos
# of ADP prep
# debtor NOUN nmod
#                    SPACE
# Corporation PROPN pobj
# ( PUNCT punct
# including VERB prep
# Limited PROPN compound
# Liability PROPN compound
# Company PROPN pobj
# ( PUNCT punct
# LLC PROPN appos
# ) PUNCT punct
# and CCONJ cc
# Limited PROPN compound
# Liability PROPN compound
# Partnership PROPN conj
# ( PUNCT punct
# LLP PROPN appos
# ) PUNCT punct
# ) PUNCT punct
#
#                                        SPACE
# Partnership PROPN ROOT
# ( PUNCT punct
# excluding VERB acl
# LLP PROPN dobj
# ) PUNCT punct
#
#                                        SPACE
# Other ADJ ROOT
# . PUNCT punct
# Specify NOUN ROOT
# : PUNCT punct
#
#
#
#
#
#  SPACE
# Official PROPN amod
# Form PROPN npadvmod
# 201 NUM nummod
#                           SPACE
# Voluntary PROPN compound
# Petition PROPN appos
# for ADP prep
# Non NOUN dep
# - NOUN dep
# Individuals NOUN amod
# Filing VERB pobj
# for ADP prep
# Bankruptcy PROPN pobj
#                                               SPACE
# page NOUN dobj
# 1 NUM nummod
#
#               SPACE
# 17 NUM nummod
# - SYM punct
# 12211-smb PROPN prep
#                SPACE
# Doc PROPN npadvmod
# 1 NUM nummod
#            SPACE
# Filed VERB punct
# 08/09/17 PUNCT punct
#          SPACE
# Entered VERB compound
# 08/09/17 PROPN dobj
# 15:59:37 NUM nummod
#                           SPACE
# Main PROPN compound
# Document PROPN appos
#
#                                                                                SPACE
# Pg PROPN nmod
# 2 NUM nummod
# of ADP prep
# 13 NUM nummod
#
#  SPACE
# Debtor PROPN pobj
#     SPACE
# PGB PROPN nmod
# 38 NUM nummod
# LLC PROPN nmod
#                                                                                    SPACE
# Case PROPN compound
# number NOUN ROOT
# ( PUNCT punct
# if SCONJ mark
# known VERB advcl
# ) PUNCT punct
#
#            SPACE
# Name NOUN ROOT
#
#
#
#
#  SPACE
# 7 NUM nummod
# . PUNCT punct
#    SPACE
# Describe PROPN compound
# debtor NOUN poss
# 's PART case
# business NOUN dobj
#         SPACE
# A. NOUN compound
# Check PROPN appos
# one NUM nummod
# : PUNCT punct
#
#                                            SPACE
# Health PROPN compound
# Care PROPN compound
# Business PROPN appos
# ( PUNCT punct
# as SCONJ mark
# defined VERB relcl
# in ADP prep
# 11 NUM pobj
# U.S.C. PROPN compound
# § NOUN compound
# 101(27A PROPN npadvmod
# ) PUNCT punct
# ) PUNCT punct
#
#                                            SPACE
# Single PROPN compound
# Asset PROPN compound
# Real PROPN compound
# Estate PROPN ROOT
# ( PUNCT punct
# as SCONJ mark
# defined VERB relcl
# in ADP prep
# 11 NUM pobj
# U.S.C. PROPN compound
# § NOUN compound
# 101(51B PROPN pobj
# ) PUNCT punct
# ) PUNCT punct
#
#                                            SPACE
# Railroad PROPN appos
# ( PUNCT punct
# as SCONJ mark
# defined VERB advcl
# in ADP prep
# 11 NUM pobj
# U.S.C. PROPN compound
# § NOUN appos
# 101(44 NUM nummod
# ) PUNCT punct
# ) PUNCT punct
#
#                                            SPACE
# Stockbroker PROPN appos
# ( PUNCT punct
# as SCONJ mark
# defined VERB relcl
# in ADP prep
# 11 NUM pobj
# U.S.C. PROPN compound
# § NOUN compound
# 101(53A NUM npadvmod
# ) PUNCT punct
# ) PUNCT punct
#
#                                            SPACE
# Commodity PROPN compound
# Broker PROPN appos
# ( PUNCT punct
# as SCONJ mark
# defined VERB parataxis
# in ADP prep
# 11 NUM pobj
# U.S.C. PROPN compound
# § NOUN compound
# 101(6 NOUN pobj
# ) PUNCT punct
# ) PUNCT punct
#
#                                            SPACE
# Clearing PROPN compound
# Bank PROPN appos
# ( PUNCT punct
# as SCONJ mark
# defined VERB parataxis
# in ADP prep
# 11 NUM nummod
# U.S.C. PROPN compound
# § NOUN compound
# 781(3 PROPN pobj
# ) PUNCT punct
# ) PUNCT punct
#
#
#                                            SPACE
# None NOUN nmod
# of ADP prep
# the DET det
# above ADJ amod
#
#
#                                         SPACE
# B. PROPN compound
# Check PROPN pobj
# all DET appos
# that PRON nsubj
# apply VERB relcl
#
#                                            SPACE
# Tax NOUN npadvmod
# - PUNCT punct
# exempt ADJ amod
# entity NOUN dobj
# ( PUNCT punct
# as SCONJ mark
# described VERB advcl
# in ADP prep
# 26 NUM pobj
# U.S.C. PROPN compound
# § NOUN nmod
# 501 NUM nummod
# ) PUNCT punct
#
#                                            SPACE
# Investment PROPN compound
# company NOUN ROOT
# , PUNCT punct
# including VERB prep
# hedge NOUN compound
# fund NOUN pobj
# or CCONJ cc
# pooled VERB amod
# investment NOUN compound
# vehicle NOUN conj
# ( PUNCT punct
# as SCONJ mark
# defined VERB relcl
# in ADP prep
# 15 NUM pobj
# U.S.C. PROPN compound
# § NOUN compound
# 80a-3 NOUN agent
# ) PUNCT punct
#
#                                            SPACE
# Investment PROPN compound
# advisor NOUN appos
# ( PUNCT punct
# as SCONJ mark
# defined VERB relcl
# in ADP prep
# 15 NUM nummod
# U.S.C. PROPN compound
# § NOUN compound
# 80b-2(a)(11 NOUN pobj
# ) PUNCT punct
# ) PUNCT punct
#
#
#                                         SPACE
# C. PROPN compound
# NAICS PROPN ROOT
# ( PUNCT punct
# North PROPN amod
# American PROPN compound
# Industry PROPN compound
# Classification PROPN compound
# System PROPN appos
# ) PUNCT punct
# 4-digit NUM dep
# code NOUN appos
# that PRON nsubj
# best ADJ advmod
# describes VERB relcl
# debtor NOUN dobj
# . PUNCT punct
#
#                                            SPACE
# See PROPN compound
# http://www.uscourts.gov/four-digit-national-association-naics-codes PROPN ROOT
# . PUNCT punct
#
#
#
#
#  SPACE
# 8 NUM ROOT
# . PUNCT punct
#    SPACE
# Under ADP prep
# which PRON det
# chapter NOUN pcomp
# of ADP prep
# the DET det
#         SPACE
# Check PROPN pobj
# one NUM nummod
# : PUNCT punct
#
#       SPACE
# Bankruptcy PROPN compound
# Code PROPN nsubj
# is AUX ROOT
# the DET attr
#
#                                            SPACE
# Chapter NOUN nmod
# 7 NUM nummod
#
#       SPACE
# debtor NOUN compound
# filing NOUN attr
# ? PUNCT punct
#
#                                            SPACE
# Chapter NOUN ROOT
# 9 NUM nummod
#
#
#                                            SPACE
# Chapter NOUN appos
# 11 NUM nummod
# . PUNCT punct
# Check VERB advcl
# all DET dobj
# that PRON nsubj
# apply VERB relcl
# : PUNCT punct
#
#                                                                   SPACE
# Debtor PROPN poss
# 's PART case
# aggregate ADJ amod
# noncontingent NOUN amod
# liquidated VERB amod
# debts NOUN nsubj
# ( PUNCT punct
# excluding VERB prep
# debts NOUN pobj
# owed VERB acl
# to ADP dative
# insiders NOUN pobj
# or CCONJ cc
# affiliates NOUN conj
# ) PUNCT punct
#
#                                                                   SPACE
# are AUX ROOT
# less ADJ amod
# than SCONJ quantmod
# $ SYM quantmod
# 2,566,050 NUM attr
# ( PUNCT punct
# amount NOUN attr
# subject ADJ amod
# to ADP prep
# adjustment NOUN pobj
# on ADP prep
# 4/01/19 NUM dep
# and CCONJ cc
# every DET det
# 3 NUM nummod
# years NOUN npadvmod
# after ADP prep
# that DET pobj
# ) PUNCT punct
# . PUNCT punct
#
#                                                                   SPACE
# The DET det
# debtor NOUN nsubj
# is AUX ROOT
# a DET det
# small ADJ amod
# business NOUN compound
# debtor NOUN attr
# as SCONJ advmod
# defined VERB advcl
# in ADP prep
# 11 NUM nummod
# U.S.C. PROPN compound
# § NOUN compound
# 101(51D NUM pobj
# ) PUNCT punct
# . PUNCT punct
# If SCONJ mark
# the DET det
# debtor NOUN nsubj
# is AUX advcl
# a DET det
# small ADJ amod
#
#                                                                   SPACE
# business NOUN compound
# debtor NOUN attr
# , PUNCT punct
# attach VERB ROOT
# the DET det
# most ADV advmod
# recent ADJ amod
# balance NOUN compound
# sheet NOUN dobj
# , PUNCT punct
# statement NOUN appos
# of ADP prep
# operations NOUN pobj
# , PUNCT punct
# cash NOUN compound
# - PUNCT punct
# flow NOUN nmod
#
#                                                                   SPACE
# statement NOUN conj
# , PUNCT punct
# and CCONJ cc
# federal ADJ amod
# income NOUN compound
# tax NOUN compound
# return NOUN conj
# or CCONJ cc
# if SCONJ mark
# all DET nsubj
# of ADP prep
# these DET det
# documents NOUN pobj
# do AUX aux
# not PART neg
# exist VERB conj
# , PUNCT punct
# follow VERB conj
# the DET det
#
#                                                                   SPACE
# procedure NOUN dobj
# in ADP prep
# 11 NUM nummod
# U.S.C. PROPN compound
# § NOUN compound
# 1116(1)(B NOUN pobj
# ) PUNCT punct
# . PUNCT punct
#
#                                                                   SPACE
# A DET det
# plan NOUN nsubjpass
# is AUX aux
# being AUX auxpass
# filed VERB ROOT
# with ADP prep
# this DET det
# petition NOUN pobj
# . PUNCT punct
#
#                                                                   SPACE
# Acceptances PROPN nsubjpass
# of ADP prep
# the DET det
# plan NOUN pobj
# were AUX auxpass
# solicited VERB amod
# prepetition NOUN ROOT
# from ADP prep
# one NUM nummod
# or CCONJ cc
# more ADJ conj
# classes NOUN pobj
# of ADP prep
# creditors NOUN pobj
# , PUNCT punct
# in ADP prep
#
#                                                                   SPACE
# accordance NOUN pobj
# with ADP prep
# 11 NUM nummod
# U.S.C. PROPN compound
# § NOUN pobj
# 1126(b NUM nummod
# ) PUNCT punct
# . PUNCT punct
#
#                                                                   SPACE
# The DET det
# debtor NOUN nsubjpass
# is AUX auxpass
# required VERB ROOT
# to PART aux
# file VERB xcomp
# periodic ADJ amod
# reports NOUN dobj
# ( PUNCT punct
# for ADP prep
# example NOUN pobj
# , PUNCT punct
# 10 NUM nummod
# K NOUN appos
# and CCONJ cc
# 10Q NUM conj
# ) PUNCT punct
# with ADP prep
# the DET det
# Securities PROPN pobj
# and CCONJ cc
#
#                                                                   SPACE
# Exchange PROPN compound
# Commission PROPN conj
# according VERB prep
# to ADP prep
# § PROPN pobj
# 13 NUM nummod
# or CCONJ cc
# 15(d NUM conj
# ) PUNCT punct
# of ADP prep
# the DET det
# Securities PROPN compound
# Exchange PROPN compound
# Act PROPN pobj
# of ADP prep
# 1934 NUM pobj
# . PUNCT punct
# File VERB ROOT
# the DET det
#
#                                                                   SPACE
# attachment NOUN dobj
# to ADP prep
# Voluntary PROPN compound
# Petition PROPN pobj
# for ADP prep
# Non NOUN dep
# - NOUN dep
# Individuals NOUN amod
# Filing VERB pobj
# for ADP prep
# Bankruptcy PROPN pobj
# under ADP prep
# Chapter NOUN pobj
# 11 NUM nummod
#
#                                                                   SPACE
# ( PUNCT punct
# Official ADJ compound
# Form NOUN compound
# 201A NUM ROOT
# ) PUNCT punct
# with ADP prep
# this DET det
# form NOUN pobj
# . PUNCT punct
#
#                                                                   SPACE
# The DET det
# debtor NOUN nsubj
# is AUX ROOT
# a DET det
# shell ADJ compound
# company NOUN attr
# as SCONJ mark
# defined VERB relcl
# in ADP prep
# the DET det
# Securities PROPN compound
# Exchange PROPN compound
# Act PROPN pobj
# of ADP prep
# 1934 NUM pobj
# Rule PROPN compound
# 12b-2 NUM dep
# . PUNCT punct
#
#                                            SPACE
# Chapter PROPN nsubj
# 12 NUM nummod
#
#
#
#
#  SPACE
# 9 NUM nummod
# . PUNCT punct
#    SPACE
# Were AUX ROOT
# prior ADJ amod
# bankruptcy NOUN attr
#                 SPACE
# No NOUN dep
# . NOUN nmod
#
#       SPACE
# cases NOUN ROOT
# filed VERB acl
# by ADP prep
# or CCONJ cc
# against ADP conj
#
#       SPACE
# the DET det
# debtor NOUN appos
# within ADP prep
# the DET det
# last ADJ amod
# 8 NUM nummod
#          SPACE
# Yes INTJ intj
# . PUNCT punct
#
#       SPACE
# years NOUN pobj
# ? PUNCT punct
#
#       SPACE
# If SCONJ mark
# more ADJ amod
# than SCONJ quantmod
# 2 NUM nummod
# cases NOUN advcl
# , PUNCT punct
# attach VERB ROOT
# a DET det
#
#       SPACE
# separate ADJ amod
# list NOUN dobj
# . PUNCT punct
#                                SPACE
# District PROPN ROOT
#                                 SPACE
# When ADV advmod
#                                   SPACE
# Case PROPN compound
# number NOUN ROOT
#
#                                                    SPACE
# District PROPN appos
#                                 SPACE
# When ADV ROOT
#                                   SPACE
# Case NOUN compound
# number NOUN pobj
#
#
#
#  SPACE
# 10 NUM nummod
# . PUNCT punct
# Are AUX ROOT
# any DET det
# bankruptcy NOUN compound
# cases NOUN nsubj
#               SPACE
# No DET punct
#
#      SPACE
# pending VERB acomp
# or CCONJ cc
# being AUX auxpass
# filed VERB conj
# by ADP agent
# a DET det
#
#      SPACE
# business NOUN compound
# partner NOUN pobj
# or CCONJ cc
# an DET det
#                 SPACE
# Yes INTJ intj
# . PUNCT punct
#
#      SPACE
# affiliate NOUN conj
# of ADP prep
# the DET det
# debtor NOUN pobj
# ? PUNCT punct
#
#       SPACE
# List VERB ROOT
# all DET det
# cases NOUN dobj
# . PUNCT punct
# If SCONJ mark
# more ADJ amod
# than SCONJ quantmod
# 1 NUM advcl
# , PUNCT punct
#
#       SPACE
# attach VERB ROOT
# a DET det
# separate ADJ amod
# list NOUN dobj
#                        SPACE
# Debtor NOUN nmod
#                                                                     SPACE
# Relationship PROPN appos
#
#                                                    SPACE
# District PROPN dep
#                                 SPACE
# When ADV advmod
#                               SPACE
# Case PROPN compound
# number NOUN ROOT
# , PUNCT punct
# if SCONJ prep
# known VERB amod
#
#
#
#
#
#  SPACE
# Official PROPN amod
# Form PROPN pobj
# 201 NUM punct
#                                SPACE
# Voluntary PROPN compound
# Petition PROPN conj
# for ADP prep
# Non NOUN dep
# - NOUN dep
# Individuals NOUN amod
# Filing VERB pobj
# for ADP prep
# Bankruptcy PROPN pobj
#                                               SPACE
# page NOUN punct
# 2 NUM nummod
#
#              SPACE
# 17 NUM nummod
# - SYM punct
# 12211-smb PROPN appos
#              SPACE
# Doc PROPN ROOT
# 1 NUM nummod
#            SPACE
# Filed VERB compound
# 08/09/17 PUNCT ROOT
#          SPACE
# Entered VERB compound
# 08/09/17 PROPN ROOT
# 15:59:37 NUM nummod
#                         SPACE
# Main PROPN compound
# Document PROPN appos
#
#                                                                             SPACE
# Pg PROPN nmod
# 3 NUM nummod
# of ADP prep
# 13 NUM nummod
#
#  SPACE
# Debtor PROPN nmod
#    SPACE
# PGB PROPN pobj
# 38 NUM nummod
# LLC PROPN appos
#                                                                                 SPACE
# Case PROPN compound
# number NOUN ROOT
# ( PUNCT punct
# if SCONJ mark
# known VERB parataxis
# ) PUNCT punct
#
#           SPACE
# Name PROPN ROOT
#
#
#
#
#  SPACE
# 11 NUM appos
# . PUNCT punct
# Why ADV advmod
# is AUX aux
# the DET det
# case NOUN nsubj
# filed VERB acl
# in ADP prep
#     SPACE
# Check VERB ROOT
# all DET dobj
# that PRON nsubj
# apply VERB relcl
# : PUNCT punct
#
#      SPACE
# this DET det
# district NOUN ROOT
# ? PUNCT punct
#
#                                           SPACE
# Debtor PROPN nsubj
# has AUX aux
# had VERB ROOT
# its PRON poss
# domicile NOUN amod
# , PUNCT punct
# principal ADJ amod
# place NOUN dobj
# of ADP prep
# business NOUN pobj
# , PUNCT punct
# or CCONJ cc
# principal ADJ amod
# assets NOUN conj
# in ADP prep
# this DET det
# district NOUN pobj
# for ADP prep
# 180 NUM nummod
# days NOUN pobj
# immediately ADV advmod
#
#                                           SPACE
# preceding VERB advcl
# the DET det
# date NOUN dobj
# of ADP prep
# this DET det
# petition NOUN pobj
# or CCONJ cc
# for ADP conj
# a DET det
# longer ADJ amod
# part NOUN pobj
# of ADP prep
# such ADJ amod
# 180 NUM nummod
# days NOUN pobj
# than SCONJ prep
# in ADP prep
# any DET det
# other ADJ amod
# district NOUN pobj
# . PUNCT punct
#
#                                           SPACE
# A DET det
# bankruptcy NOUN compound
# case NOUN nsubj
# concerning VERB prep
# debtor NOUN poss
# 's PART case
# affiliate NOUN pobj
# , PUNCT punct
# general ADJ amod
# partner NOUN conj
# , PUNCT punct
# or CCONJ cc
# partnership NOUN conj
# is AUX ROOT
# pending VERB acomp
# in ADP prep
# this DET det
# district NOUN pobj
# . PUNCT punct
#
#
#  SPACE
# 12 NUM ROOT
# . PUNCT punct
# Does AUX aux
# the DET det
# debtor NOUN nsubj
# own ADJ ROOT
# or CCONJ cc
#           SPACE
# No DET dep
#
#      SPACE
# have AUX conj
# possession NOUN dobj
# of ADP prep
# any DET det
#
#      SPACE
# real ADJ amod
# property NOUN pobj
# or CCONJ cc
# personal ADJ conj
#                 SPACE
# Answer PROPN conj
# below ADV prep
# for ADP prep
# each DET det
# property NOUN pobj
# that PRON nsubj
# needs VERB relcl
# immediate ADJ amod
# attention NOUN dobj
# . PUNCT punct
# Attach VERB ROOT
# additional ADJ amod
# sheets NOUN dobj
# if SCONJ mark
# needed VERB advcl
# . PUNCT punct
#
#                                      SPACE
# Yes INTJ intj
# . PUNCT punct
#
#      SPACE
# property NOUN ROOT
# that PRON nsubj
# needs VERB relcl
#
#      SPACE
# immediate ADJ amod
# attention NOUN dobj
# ? PUNCT punct
#                      SPACE
# Why ADV advmod
# does AUX aux
# the DET det
# property NOUN nsubj
# need VERB ROOT
# immediate ADJ amod
# attention NOUN dobj
# ? PUNCT punct
# ( PUNCT punct
# Check VERB ROOT
# all DET dobj
# that PRON nsubj
# apply VERB relcl
# . PUNCT punct
# ) PUNCT punct
#
#                                                  SPACE
# It PRON nsubj
# poses VERB ROOT
# or CCONJ cc
# is AUX auxpass
# alleged VERB conj
# to PART aux
# pose VERB xcomp
# a DET det
# threat NOUN dobj
# of ADP prep
# imminent ADJ amod
# and CCONJ cc
# identifiable ADJ conj
# hazard NOUN pobj
# to ADP prep
# public ADJ amod
# health NOUN pobj
# or CCONJ cc
# safety NOUN conj
# . PUNCT punct
#
#                                                 SPACE
# What PRON attr
# is AUX ROOT
# the DET det
# hazard NOUN nsubj
# ? PUNCT punct
#
#                                                  SPACE
# It PRON nsubj
# needs VERB ROOT
# to PART aux
# be AUX xcomp
# physically ADV advmod
# secured VERB acomp
# or CCONJ cc
# protected VERB conj
# from ADP prep
# the DET det
# weather NOUN pobj
# . PUNCT punct
#
#                                                  SPACE
# It PRON nsubj
# includes VERB ROOT
# perishable ADJ amod
# goods NOUN dobj
# or CCONJ cc
# assets NOUN conj
# that PRON nsubj
# could AUX aux
# quickly ADV advmod
# deteriorate VERB relcl
# or CCONJ cc
# lose VERB conj
# value NOUN dobj
# without ADP prep
# attention NOUN pobj
# ( PUNCT punct
# for ADP prep
# example NOUN pobj
# , PUNCT punct
#
#                                                 SPACE
# livestock NOUN conj
# , PUNCT punct
# seasonal ADJ amod
# goods NOUN conj
# , PUNCT punct
# meat NOUN conj
# , PUNCT punct
# dairy NOUN conj
# , PUNCT punct
# produce VERB conj
# , PUNCT punct
# or CCONJ cc
# securities NOUN npadvmod
# - PUNCT punct
# related VERB amod
# assets NOUN conj
# or CCONJ cc
# other ADJ amod
# options NOUN conj
# ) PUNCT punct
# . PUNCT punct
#
#                                                  SPACE
# Other ADJ ROOT
#
#                                               SPACE
# Where ADV advmod
# is AUX relcl
# the DET det
# property NOUN nsubj
# ? PUNCT punct
#
#                                                                                SPACE
# Number PROPN nsubj
# , PUNCT punct
# Street PROPN npadvmod
# , PUNCT punct
# City PROPN conj
# , PUNCT punct
# State PROPN conj
# & CCONJ cc
# ZIP PROPN conj
# Code PROPN appos
#
#                                               SPACE
# Is AUX ROOT
# the DET det
# property NOUN attr
# insured VERB acl
# ? PUNCT punct
#
#                                                  SPACE
# No INTJ ROOT
#
#                                                  SPACE
# Yes INTJ intj
# . PUNCT punct
#     SPACE
# Insurance NOUN compound
# agency NOUN nmod
#
#                                                          SPACE
# Contact PROPN compound
# name NOUN ROOT
#
#                                                          SPACE
# Phone PROPN nmod
#
#
#
#
#           SPACE
# Statistical ADJ amod
# and CCONJ cc
# administrative ADJ conj
# information NOUN dobj
#
#
#  SPACE
# 13 NUM nummod
# . PUNCT punct
# Debtor PROPN poss
# 's PART case
# estimation NOUN ROOT
# of ADP prep
#       SPACE
# . PUNCT punct
#          SPACE
# Check PROPN ROOT
# one NUM nummod
# : PUNCT punct
#
#      SPACE
# available ADJ amod
# funds NOUN appos
#
#                                               SPACE
# Funds NOUN nsubj
# will AUX aux
# be AUX ROOT
# available ADJ acomp
# for ADP prep
# distribution NOUN pobj
# to ADP prep
# unsecured ADJ amod
# creditors NOUN pobj
# . PUNCT punct
#
#                                               SPACE
# After ADP mark
# any DET det
# administrative ADJ amod
# expenses NOUN nsubjpass
# are AUX auxpass
# paid VERB advcl
# , PUNCT punct
# no DET det
# funds NOUN nsubj
# will AUX aux
# be AUX ROOT
# available ADJ acomp
# to ADP prep
# unsecured ADJ amod
# creditors NOUN pobj
# . PUNCT punct
#
#
#  SPACE
# 14 NUM ROOT
# . PUNCT punct
# Estimated VERB amod
# number NOUN ROOT
# of ADP prep
#              SPACE
# 1 NUM nummod
# - SYM punct
# 49 NUM prep
#                                              SPACE
# 1,000 NUM npadvmod
# - SYM punct
# 5,000 NUM prep
#                                  SPACE
# 25,001 NUM npadvmod
# - SYM punct
# 50,000 NUM prep
#
#      SPACE
# creditors NOUN pobj
#                                                                         SPACE
# 5001 NUM amod
# - SYM punct
# 10,000 NUM prep
#                                  SPACE
# 50,001 NUM nummod
# - SYM punct
# 100,000 NUM appos
#
#                                      SPACE
# 50 NUM nummod
# - SYM punct
# 99 NUM npadvmod
#
#                                      SPACE
# 100 NUM npadvmod
# - SYM punct
# 199 NUM prep
#                                           SPACE
# 10,001 NUM npadvmod
# - SYM punct
# 25,000 NUM prep
#                                SPACE
# More ADJ amod
# than100,000 NUM ROOT
#
#                                      SPACE
# 200 NUM npadvmod
# - SYM punct
# 999 NUM nummod
#
#
#  SPACE
# 15 NUM appos
# . PUNCT punct
# Estimated VERB amod
# Assets NOUN ROOT
#                 SPACE
# $ SYM nmod
# 0 NUM dep
# - SYM punct
# $ SYM nmod
# 50,000 NUM appos
#                                      SPACE
# $ SYM nmod
# 1,000,001 NUM npadvmod
# - SYM punct
# $ SYM quantmod
# 10 NUM compound
# million NUM nummod
#                     SPACE
# $ SYM quantmod
# 500,000,001 NUM quantmod
# - PUNCT punct
# $ SYM quantmod
# 1 NUM compound
# billion NUM nummod
#
#                                      SPACE
# $ SYM nmod
# 50,001 NUM appos
# - PUNCT punct
# $ SYM nmod
# 100,000 NUM appos
#                                SPACE
# $ SYM nmod
# 10,000,001 NUM npadvmod
# - PUNCT punct
# $ SYM quantmod
# 50 NUM compound
# million NUM npadvmod
#                    SPACE
# $ SYM nmod
# 1,000,000,001 NUM npadvmod
# - PUNCT punct
# $ SYM quantmod
# 10 NUM compound
# billion NUM appos
#
#                                      SPACE
# $ SYM quantmod
# 100,001 NUM quantmod
# - SYM punct
# $ SYM nmod
# 500,000 NUM appos
#                               SPACE
# $ SYM nmod
# 50,000,001 NUM quantmod
# - PUNCT punct
# $ SYM quantmod
# 100 NUM compound
# million NUM nummod
#                   SPACE
# $ SYM quantmod
# 10,000,000,001 NUM dep
# - PUNCT punct
# $ SYM quantmod
# 50 NUM compound
# billion NUM nummod
#
#                                      SPACE
# $ SYM quantmod
# 500,001 NUM quantmod
# - PUNCT punct
# $ SYM quantmod
# 1 NUM compound
# million NUM quantmod
#                             SPACE
# $ SYM nmod
# 100,000,001 NUM npadvmod
# - PUNCT punct
# $ SYM quantmod
# 500 NUM compound
# million NUM appos
#                  SPACE
# More ADJ amod
# than SCONJ quantmod
# $ SYM quantmod
# 50 NUM compound
# billion NUM nummod
#
#
#
#  SPACE
# 16 NUM appos
# . PUNCT punct
# Estimated VERB amod
# liabilities NOUN ROOT
#            SPACE
# $ SYM nmod
# 0 NUM appos
# - SYM punct
# $ SYM nmod
# 50,000 NUM nummod
#                                      SPACE
# $ SYM nmod
# 1,000,001 NUM npadvmod
# - SYM punct
# $ SYM quantmod
# 10 NUM compound
# million NUM nummod
#                     SPACE
# $ SYM quantmod
# 500,000,001 NUM quantmod
# - PUNCT punct
# $ SYM quantmod
# 1 NUM compound
# billion NUM nummod
#
#                                      SPACE
# $ SYM nmod
# 50,001 NUM nummod
# - PUNCT punct
# $ SYM nmod
# 100,000 NUM appos
#                                SPACE
# $ SYM nmod
# 10,000,001 NUM nummod
# - PUNCT punct
# $ SYM quantmod
# 50 NUM compound
# million NUM npadvmod
#                    SPACE
# $ SYM nmod
# 1,000,000,001 NUM npadvmod
# - PUNCT punct
# $ SYM quantmod
# 10 NUM compound
# billion NUM appos
#
#                                      SPACE
# $ SYM quantmod
# 100,001 NUM quantmod
# - SYM punct
# $ SYM nmod
# 500,000 NUM appos
#                               SPACE
# $ SYM nmod
# 50,000,001 NUM quantmod
# - PUNCT punct
# $ SYM quantmod
# 100 NUM compound
# million NUM nummod
#                   SPACE
# $ SYM quantmod
# 10,000,000,001 NUM dep
# - PUNCT punct
# $ SYM quantmod
# 50 NUM compound
# billion NUM nummod
#
#                                      SPACE
# $ SYM quantmod
# 500,001 NUM quantmod
# - PUNCT punct
# $ SYM quantmod
# 1 NUM compound
# million NUM quantmod
#                             SPACE
# $ SYM nmod
# 100,000,001 NUM npadvmod
# - PUNCT punct
# $ SYM quantmod
# 500 NUM compound
# million NUM nummod
#                  SPACE
# More ADJ amod
# than SCONJ quantmod
# $ SYM quantmod
# 50 NUM compound
# billion NUM nummod
#
#
#
#
#
#  SPACE
# Official ADJ amod
# Form NOUN nmod
# 201 NUM nummod
#                            SPACE
# Voluntary PROPN compound
# Petition PROPN appos
# for ADP prep
# Non NOUN dep
# - NOUN dep
# Individuals NOUN amod
# Filing VERB pobj
# for ADP prep
# Bankruptcy PROPN pobj
#                                                    SPACE
# page NOUN appos
# 3 NUM nummod
#
#              SPACE
# 17 NUM nummod
# - SYM punct
# 12211-smb PROPN ROOT
#                  SPACE
# Doc PROPN ROOT
# 1 NUM nummod
#      SPACE
# Filed VERB dep
# 08/09/17 PROPN ROOT
#           SPACE
# Entered PROPN compound
# 08/09/17 PROPN ROOT
# 15:59:37 NUM nummod
#                         SPACE
# Main PROPN compound
# Document PROPN appos
#
#                                                                            SPACE
# Pg PROPN nmod
# 4 NUM nummod
# of ADP prep
# 13 NUM nummod
#
#  SPACE
# Debtor PROPN nmod
#     SPACE
# PGB PROPN nmod
# 38 NUM nummod
# LLC PROPN appos
#                                                                                SPACE
# Case PROPN compound
# number NOUN ROOT
# ( PUNCT punct
# if SCONJ mark
# known VERB advcl
# ) PUNCT punct
#
#            SPACE
# Name NOUN compound
#
#
#
#
#            SPACE
# Request NOUN ROOT
# for ADP prep
# Relief PROPN pobj
# , PUNCT punct
# Declaration PROPN conj
# , PUNCT punct
# and CCONJ cc
# Signatures NOUN conj
#
#
#  SPACE
# WARNING NOUN conj
# -- PUNCT punct
# Bankruptcy NOUN compound
# fraud NOUN nsubj
# is AUX ROOT
# a DET det
# serious ADJ amod
# crime NOUN attr
# . PUNCT punct
# Making VERB csubj
# a DET det
# false ADJ amod
# statement NOUN dobj
# in ADP prep
# connection NOUN pobj
# with ADP prep
# a DET det
# bankruptcy NOUN compound
# case NOUN pobj
# can AUX aux
# result VERB ROOT
# in ADP prep
# fines NOUN pobj
# up ADP quantmod
# to PART quantmod
# $ SYM quantmod
# 500,000 NUM nummod
# or CCONJ cc
#
#             SPACE
# imprisonment NOUN dobj
# for ADP prep
# up ADP quantmod
# to PART quantmod
# 20 NUM nummod
# years NOUN pobj
# , PUNCT punct
# or CCONJ cc
# both DET conj
# . PUNCT punct
# 18 NUM nummod
# U.S.C. PROPN compound
# § NOUN compound
# § NOUN ROOT
# 152 NUM nummod
# , PUNCT punct
# 1341 NUM npadvmod
# , PUNCT punct
# 1519 NUM conj
# , PUNCT punct
# and CCONJ cc
# 3571 NUM conj
# . PUNCT punct
#
#
#  SPACE
# 17 NUM ROOT
# . PUNCT punct
# Declaration NOUN ROOT
# and CCONJ cc
# signature NOUN conj
#
#      SPACE
# of ADP prep
# authorized VERB pcomp
#                 SPACE
# The DET det
# debtor NOUN compound
# requests VERB compound
# relief NOUN nsubj
# in ADP prep
# accordance NOUN pobj
# with ADP prep
# the DET det
# chapter NOUN pobj
# of ADP prep
# title NOUN pobj
# 11 NUM nummod
# , PUNCT punct
# United PROPN compound
# States PROPN compound
# Code PROPN appos
# , PUNCT punct
# specified VERB ROOT
# in ADP prep
# this DET det
# petition NOUN pobj
# . PUNCT punct
#
#      SPACE
# representative NOUN ROOT
# of ADP prep
# debtor NOUN pobj
#
#                                   SPACE
# I PRON nsubjpass
# have AUX aux
# been AUX auxpass
# authorized VERB ROOT
# to PART aux
# file VERB xcomp
# this DET det
# petition NOUN dobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# the DET det
# debtor NOUN pobj
# . PUNCT punct
#
#
#                                   SPACE
# I PRON nsubj
# have AUX aux
# examined VERB ROOT
# the DET det
# information NOUN dobj
# in ADP prep
# this DET det
# petition NOUN pobj
# and CCONJ cc
# have AUX conj
# a DET det
# reasonable ADJ amod
# belief NOUN dobj
# that SCONJ mark
# the DET det
# information NOUN nsubjpass
# is AUX auxpass
# trued ADJ acl
# and CCONJ cc
# correct ADJ conj
# . PUNCT punct
#
#
#                                   SPACE
# I PRON nsubj
# declare VERB ROOT
# under ADP prep
# penalty NOUN pobj
# of ADP prep
# perjury NOUN pobj
# that SCONJ mark
# the DET det
# foregoing NOUN nsubj
# is AUX ccomp
# true ADJ acomp
# and CCONJ cc
# correct ADJ conj
# . PUNCT punct
#
#
#                                   SPACE
# Executed VERB ROOT
# on ADP prep
#       SPACE
# August PROPN npadvmod
# 8 NUM nummod
# , PUNCT punct
# 2017 NUM appos
#
#                                                    SPACE
# MM PROPN nmod
# / SYM punct
# DD PROPN nmod
# / SYM punct
# YYYY PROPN appos
#
#
#
#                               SPACE
# X NOUN ROOT
#    SPACE
# /s/ PUNCT ROOT
# Philip PROPN compound
# Menegis PROPN ROOT
#                                                        SPACE
# Philip PROPN compound
# Menegis PROPN appos
#
#                                   SPACE
# Signature PROPN nsubj
# of ADP prep
# authorized VERB amod
# representative NOUN pobj
# of ADP prep
# debtor NOUN pobj
#                          SPACE
# Printed VERB amod
# name NOUN ROOT
#
#
#                                   SPACE
# Title PROPN ROOT
#     SPACE
# Managing VERB compound
# Member PROPN appos
#
#
#
#
#
#  SPACE
# 18 NUM nummod
# . PUNCT punct
# Signature NOUN ROOT
# of ADP prep
# attorney NOUN pobj
#     SPACE
# X NOUN nmod
#    SPACE
# /s/ PUNCT punct
# Gregory PROPN compound
# M. PROPN compound
# Messer PROPN ROOT
#                                                      SPACE
# Date PROPN compound
# August PROPN npadvmod
# 8 NUM nummod
# , PUNCT punct
# 2017 NUM appos
#
#                                   SPACE
# Signature PROPN ROOT
# of ADP prep
# attorney NOUN pobj
# for ADP prep
# debtor NOUN nmod
#                                                SPACE
# MM PROPN nmod
# / SYM punct
# DD PROPN nmod
# / SYM punct
# YYYY PROPN pobj
#
#
#                                   SPACE
# Gregory PROPN compound
# M. PROPN compound
# Messer PROPN appos
#
#                                   SPACE
# Printed PROPN amod
# name NOUN nmod
#
#
#                                   SPACE
# Law PROPN compound
# Office PROPN ROOT
# of ADP prep
# Gregory PROPN compound
# Messer PROPN pobj
#
#                                   SPACE
# Firm ADJ compound
# name NOUN nmod
#
#
#                                   SPACE
# Law PROPN compound
# Office PROPN ROOT
# of ADP prep
# Gregory PROPN compound
# Messer PROPN pobj
#
#                                   SPACE
# 26 NUM nummod
# Court PROPN compound
# Street PROPN appos
# , PUNCT punct
# Suite PROPN npadvmod
# 2400 NUM nummod
#
#                                   SPACE
# Brooklyn PROPN ROOT
# , PUNCT punct
# NY PROPN appos
# 11242 NUM nummod
#
#                                   SPACE
# Number PROPN ROOT
# , PUNCT punct
# Street PROPN npadvmod
# , PUNCT punct
# City PROPN conj
# , PUNCT punct
# State PROPN conj
# & CCONJ cc
# ZIP PROPN compound
# Code PROPN conj
#
#
#
#                                   SPACE
# Contact NOUN compound
# phone NOUN ROOT
#      SPACE
# 718 NUM nummod
# - PUNCT punct
# 858 NUM nummod
# - PUNCT punct
# 1474 NUM nummod
#                   SPACE
# Email PROPN compound
# address NOUN ROOT
#       SPACE
# gremesser@aol.com SYM ROOT
#
#
#                                   SPACE
# 1388339 NUM npadvmod
#
#                                   SPACE
# Bar PROPN compound
# number NOUN nmod
# and CCONJ cc
# State NOUN conj
#
#
#
#
#
#  SPACE
# Official PROPN amod
# Form PROPN nmod
# 201 NUM nummod
#                           SPACE
# Voluntary PROPN compound
# Petition PROPN ROOT
# for ADP prep
# Non NOUN dep
# - NOUN dep
# Individuals NOUN amod
# Filing VERB pobj
# for ADP prep
# Bankruptcy PROPN pobj
#                                                    SPACE
# page NOUN npadvmod
# 4 NUM nummod
#
#            SPACE
# 17 NUM nummod
# - SYM punct
# 12211-smb PROPN nmod
#                     SPACE
# Doc NOUN nsubj
# 1 NUM nummod
#           SPACE
# Filed VERB ROOT
# 08/09/17 PROPN punct
#              SPACE
# Entered PROPN compound
# 08/09/17 PROPN ROOT
# 15:59:37 NUM nummod
#                 SPACE
# Main PROPN compound
# Document PROPN dobj
#
#                                                                                     SPACE
# Pg PROPN ROOT
# 5 NUM nummod
# of ADP prep
# 13 NUM pobj
#
#
#
#
#
#   SPACE
# Fill PROPN ROOT
# in ADP prep
# this DET det
# information NOUN pobj
# to PART aux
# identify VERB advcl
# the DET det
# case NOUN dobj
# : PUNCT punct
#
#
#   SPACE
# Debtor PROPN compound
# name NOUN appos
#          SPACE
# PGB PROPN nmod
# 38 NUM nummod
# LLC PROPN nmod
#
#
#   SPACE
# United PROPN compound
# States PROPN compound
# Bankruptcy PROPN compound
# Court PROPN ROOT
# for ADP prep
# the DET det
# : PUNCT punct
#             SPACE
# SOUTHERN PROPN compound
# DISTRICT PROPN pobj
# OF ADP prep
# NEW PROPN compound
# YORK PROPN nmod
#
#
#   SPACE
# Case NOUN compound
# number NOUN pobj
# ( PUNCT punct
# if SCONJ mark
# known VERB amod
# ) PUNCT punct
#
#                                                                                                                                    SPACE
# Check NOUN appos
# if SCONJ mark
# this DET nsubj
# is AUX advcl
# an DET det
#
#                                                                                                                                    SPACE
# amended VERB amod
# filing NOUN nmod
#
#
#
#
#  SPACE
# Official ADJ nmod
# Form PROPN nmod
# 202 NUM nummod
#
#  SPACE
# Declaration PROPN attr
# Under ADP prep
# Penalty PROPN pobj
# of ADP prep
# Perjury PROPN pobj
# for ADP prep
# Non ADJ dep
# - ADJ dep
# Individual ADJ amod
# Debtors NOUN pobj
#                                                                                          SPACE
# 12/15 NUM nummod
#
#
#  SPACE
# An DET det
# individual NOUN nsubj
# who PRON nsubjpass
# is AUX auxpass
# authorized VERB relcl
# to PART aux
# act VERB xcomp
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# a DET det
# non ADJ dep
# - ADJ dep
# individual ADJ amod
# debtor NOUN pobj
# , PUNCT punct
# such ADJ amod
# as SCONJ prep
# a DET det
# corporation NOUN pobj
# or CCONJ cc
# partnership NOUN conj
# , PUNCT punct
# must AUX aux
# sign VERB ROOT
# and CCONJ cc
# submit VERB conj
# this DET det
#
#  SPACE
# form NOUN dobj
# for ADP prep
# the DET det
# schedules NOUN pobj
# of ADP prep
# assets NOUN pobj
# and CCONJ cc
# liabilities NOUN conj
# , PUNCT punct
# any DET det
# other ADJ amod
# document NOUN appos
# that PRON nsubj
# requires VERB relcl
# a DET det
# declaration NOUN dobj
# that PRON nsubjpass
# is AUX auxpass
# not PART neg
# included VERB relcl
# in ADP prep
# the DET det
# document NOUN pobj
# , PUNCT punct
# and CCONJ cc
# any DET det
#
#  SPACE
# amendments NOUN conj
# of ADP prep
# those DET det
# documents NOUN pobj
# . PUNCT punct
# This DET det
# form NOUN nsubj
# must AUX aux
# state VERB ROOT
# the DET det
# individual ADJ amod
# ’s PROPN compound
# position NOUN dobj
# or CCONJ cc
# relationship NOUN conj
# to ADP prep
# the DET det
# debtor NOUN pobj
# , PUNCT punct
# the DET det
# identity NOUN appos
# of ADP prep
# the DET det
# document NOUN pobj
# , PUNCT punct
#
#  SPACE
# and CCONJ cc
# the DET det
# date NOUN conj
# . PUNCT punct
# Bankruptcy NOUN compound
# Rules PROPN ROOT
# 1008 NUM nummod
# and CCONJ cc
# 9011 NUM conj
# . PUNCT punct
#
#
#  SPACE
# WARNING NOUN ROOT
# -- PUNCT punct
# Bankruptcy NOUN compound
# fraud NOUN nsubj
# is AUX ROOT
# a DET det
# serious ADJ amod
# crime NOUN attr
# . PUNCT punct
# Making VERB csubj
# a DET det
# false ADJ amod
# statement NOUN dobj
# , PUNCT punct
# concealing VERB advcl
# property NOUN dobj
# , PUNCT punct
# or CCONJ cc
# obtaining VERB conj
# money NOUN dobj
# or CCONJ cc
# property NOUN conj
# by ADP prep
# fraud NOUN pobj
# in ADP prep
#
#  SPACE
# connection NOUN pobj
# with ADP prep
# a DET det
# bankruptcy NOUN compound
# case NOUN pobj
# can AUX aux
# result VERB ROOT
# in ADP prep
# fines NOUN pobj
# up ADP quantmod
# to PART quantmod
# $ SYM quantmod
# 500,000 NUM dobj
# or CCONJ cc
# imprisonment NOUN conj
# for ADP prep
# up ADP quantmod
# to PART quantmod
# 20 NUM nummod
# years NOUN pobj
# , PUNCT punct
# or CCONJ cc
# both DET conj
# . PUNCT punct
# 18 NUM nummod
# U.S.C. PROPN compound
# § NOUN compound
# § NOUN ROOT
# 152 NUM nummod
# , PUNCT punct
# 1341 NUM npadvmod
# , PUNCT punct
#
#  SPACE
# 1519 NUM appos
# , PUNCT punct
# and CCONJ cc
# 3571 NUM conj
# . PUNCT punct
#
#
#
#
#                  SPACE
# Declaration PROPN ROOT
# and CCONJ cc
# signature NOUN conj
#
#
#
#         SPACE
# I PRON nsubj
# am AUX ROOT
# the DET det
# president NOUN attr
# , PUNCT punct
# another DET det
# officer NOUN appos
# , PUNCT punct
# or CCONJ cc
# an DET det
# authorized ADJ amod
# agent NOUN conj
# of ADP prep
# the DET det
# corporation NOUN pobj
# ; PUNCT punct
# a DET det
# member NOUN appos
# or CCONJ cc
# an DET det
# authorized ADJ amod
# agent NOUN conj
# of ADP prep
# the DET det
# partnership NOUN pobj
# ; PUNCT punct
# or CCONJ cc
# another DET det
#
#         SPACE
# individual NOUN conj
# serving VERB acl
# as SCONJ prep
# a DET det
# representative NOUN pobj
# of ADP prep
# the DET det
# debtor NOUN pobj
# in ADP prep
# this DET det
# case NOUN pobj
# . PUNCT punct
#
#
#         SPACE
# I PRON nsubj
# have AUX aux
# examined VERB ROOT
# the DET det
# information NOUN dobj
# in ADP prep
# the DET det
# documents NOUN pobj
# checked VERB acl
# below ADV advmod
# and CCONJ cc
# I PRON nsubj
# have AUX ROOT
# a DET det
# reasonable ADJ amod
# belief NOUN dobj
# that SCONJ mark
# the DET det
# information NOUN nsubj
# is AUX acl
# true ADJ acomp
# and CCONJ cc
# correct ADJ conj
# : PUNCT punct
#
#
#                    SPACE
# Schedule PROPN nmod
# A PROPN nmod
# / SYM punct
# B NOUN dep
# : PUNCT punct
# Assets NOUN appos
# – PUNCT punct
# Real ADJ amod
# and CCONJ cc
# Personal PROPN conj
# Property PROPN appos
# ( PUNCT punct
# Official ADJ amod
# Form NOUN appos
# 206A PROPN nmod
# / SYM punct
# B PROPN appos
# ) PUNCT punct
#
#                    SPACE
# Schedule NOUN compound
# D NOUN ROOT
# : PUNCT punct
# Creditors NOUN appos
# Who PRON nsubj
# Have AUX relcl
# Claims NOUN dobj
# Secured VERB acl
# by ADP agent
# Property PROPN pobj
# ( PUNCT punct
# Official ADJ compound
# Form NOUN appos
# 206D NUM dobj
# ) PUNCT punct
#
#                    SPACE
# Schedule NOUN nmod
# E PROPN nmod
# / SYM punct
# F PROPN ROOT
# : PUNCT punct
# Creditors NOUN appos
# Who PRON nsubj
# Have AUX relcl
# Unsecured VERB amod
# Claims NOUN dobj
# ( PUNCT punct
# Official ADJ amod
# Form NOUN appos
# 206E NUM nmod
# / SYM punct
# F PROPN appos
# ) PUNCT punct
#
#                    SPACE
# Schedule NOUN compound
# G PROPN ROOT
# : PUNCT punct
# Executory NOUN amod
# Contracts NOUN ROOT
# and CCONJ cc
# Unexpired PROPN compound
# Leases PROPN conj
# ( PUNCT punct
# Official ADJ nmod
# Form NOUN appos
# 206 NUM nummod
# G NOUN appos
# ) PUNCT punct
#
#                    SPACE
# Schedule NOUN compound
# H NOUN ROOT
# : PUNCT punct
# Codebtors NOUN appos
# ( PUNCT punct
# Official ADJ compound
# Form NOUN compound
# 206H NUM appos
# ) PUNCT punct
#
#                    SPACE
# Summary PROPN appos
# of ADP prep
# Assets PROPN pobj
# and CCONJ cc
# Liabilities PROPN conj
# for ADP prep
# Non NOUN dep
# - NOUN dep
# Individuals NOUN pobj
# ( PUNCT punct
# Official ADJ compound
# Form NOUN pobj
# 206Sum NUM punct
# ) PUNCT punct
#
#                    SPACE
# Amended PROPN compound
# Schedule PROPN appos
#
#                    SPACE
# Chapter NOUN appos
# 11 NUM nummod
# or CCONJ cc
# Chapter NOUN nmod
# 9 NUM nummod
# Cases NOUN conj
# : PUNCT punct
# List NOUN appos
# of ADP prep
# Creditors NOUN pobj
# Who PRON nsubj
# Have AUX relcl
# the DET det
# 20 NUM nummod
# Largest ADJ amod
# Unsecured ADJ amod
# Claims NOUN dobj
# and CCONJ cc
# Are AUX conj
# Not PART neg
# Insiders NOUN attr
# ( PUNCT punct
# Official ADJ compound
# Form NOUN appos
# 204 NUM nummod
# ) PUNCT punct
#                    SPACE
# Other ADJ amod
# document NOUN ROOT
# that PRON nsubj
# requires VERB relcl
# a DET det
# declaration NOUN dobj
#
#
#         SPACE
# I PRON nsubj
# declare VERB relcl
# under ADP prep
# penalty NOUN pobj
# of ADP prep
# perjury NOUN pobj
# that SCONJ mark
# the DET det
# foregoing NOUN nsubj
# is AUX ccomp
# true ADJ acomp
# and CCONJ cc
# correct ADJ conj
# . PUNCT punct
#
#
#          SPACE
# Executed VERB ROOT
# on ADP prep
#           SPACE
# August PROPN pobj
# 8 NUM nummod
# , PUNCT punct
# 2017 NUM nummod
#                           SPACE
# X NOUN dep
# /s/ PUNCT compound
# Philip PROPN compound
# Menegis PROPN ROOT
#
#                                                                         SPACE
# Signature PROPN appos
# of ADP prep
# individual ADJ amod
# signing NOUN pobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# debtor NOUN nmod
#
#
#                                                                         SPACE
# Philip PROPN compound
# Menegis PROPN pobj
#
#                                                                         SPACE
# Printed VERB amod
# name NOUN ROOT
#
#
#                                                                         SPACE
# Managing VERB compound
# Member PROPN nmod
#
#                                                                         SPACE
# Position NOUN nsubj
# or CCONJ cc
# relationship NOUN conj
# to PART prep
# debtor VERB nmod
#
#
#
#
#
#  SPACE
# Official PROPN compound
# Form PROPN pobj
# 202 NUM nummod
#                                              SPACE
# Declaration NOUN ROOT
# Under ADP prep
# Penalty PROPN pobj
# of ADP prep
# Perjury PROPN pobj
# for ADP prep
# Non PROPN dep
# - ADJ dep
# Individual ADJ amod
# Debtors NOUN pobj
#
#  SPACE
# Software PROPN compound
# Copyright PROPN pobj
# ( PUNCT punct
# c NOUN appos
# ) PUNCT punct
# 1996 NUM npadvmod
# - SYM punct
# 2017 NUM nummod
# Best PROPN compound
# Case PROPN ROOT
# , PUNCT punct
# LLC PROPN compound
# - PUNCT punct
# www.bestcase.com PROPN npadvmod
#                                                                          SPACE
# Best PROPN amod
# Case PROPN compound
# Bankruptcy PROPN ROOT
#
#                 SPACE
# 17 NUM nummod
# - SYM punct
# 12211-smb PROPN nmod
#                     SPACE
# Doc NOUN nsubj
# 1 NUM nummod
#           SPACE
# Filed VERB ROOT
# 08/09/17 PROPN punct
#          SPACE
# Entered VERB compound
# 08/09/17 PROPN dobj
# 15:59:37 NUM nummod
#                              SPACE
# Main PROPN compound
# Document PROPN appos
#
#                                                                                      SPACE
# Pg PROPN ROOT
# 6 NUM nummod
# of ADP quantmod
# 13 NUM nummod
#
#
#   SPACE
# Fill PROPN ROOT
# in ADP prep
# this DET det
# information NOUN pobj
# to PART aux
# identify VERB advcl
# the DET det
# case NOUN dobj
# : PUNCT punct
#
#   SPACE
# Debtor PROPN compound
# name NOUN compound
# PGB PROPN nmod
# 38 NUM nummod
# LLC PROPN nmod
#
#   SPACE
# United PROPN compound
# States PROPN compound
# Bankruptcy PROPN compound
# Court PROPN nsubj
# for ADP prep
# the DET det
# : PUNCT punct
# SOUTHERN PROPN compound
# DISTRICT PROPN pobj
# OF ADP prep
# NEW ADJ nmod
#                                                                                      SPACE
# Check NOUN pobj
# if SCONJ mark
# this DET nsubj
# is AUX advcl
# an DET det
#
#                                                  SPACE
# YORK PROPN nmod
#
#   SPACE
# Case NOUN compound
# number NOUN attr
# ( PUNCT punct
# if SCONJ mark
# known VERB acl
# ) PUNCT punct
# : PUNCT punct
#                                                                                                                               SPACE
# amended VERB amod
# filing NOUN nmod
#
#
#
#
#
#  SPACE
# Official PROPN nmod
# Form PROPN nmod
# 204 NUM nummod
#
#  SPACE
# Chapter NOUN nmod
# 11 NUM nummod
# or CCONJ cc
# Chapter NOUN conj
# 9 NUM nummod
# Cases NOUN appos
# : PUNCT punct
# List NOUN appos
# of ADP prep
# Creditors NOUN pobj
# Who PRON nsubj
# Have AUX relcl
# the DET det
# 20 NUM nummod
# Largest ADJ amod
# Unsecured ADJ amod
# Claims PROPN dobj
# and CCONJ cc
#
#  SPACE
# Are AUX ROOT
# Not PART neg
# Insiders NOUN attr
#                                                                            SPACE
# 12/15 NUM nummod
#
#
#  SPACE
# A DET det
# list NOUN nsubjpass
# of ADP prep
# creditors NOUN pobj
# holding VERB acl
# the DET det
# 20 NUM nummod
# largest ADJ amod
# unsecured ADJ amod
# claims NOUN dobj
# must AUX aux
# be AUX auxpass
# filed VERB ccomp
# in ADP prep
# a DET det
# Chapter NOUN nmod
# 11 NUM nummod
# or CCONJ cc
# Chapter NOUN nmod
# 9 NUM nummod
# case NOUN pobj
# . PUNCT punct
# Include PROPN ROOT
# claims NOUN dobj
# which PRON dobj
# the DET det
#
#  SPACE
# debtor NOUN compound
# disputes NOUN relcl
# . PUNCT punct
# Do AUX aux
# not PART neg
# include VERB ROOT
# claims NOUN dobj
# by ADP prep
# any DET det
# person NOUN pobj
# or CCONJ cc
# entity NOUN conj
# who PRON nsubj
# is AUX relcl
# an DET det
# insider NOUN attr
# , PUNCT punct
# as SCONJ mark
# defined VERB acl
# in ADP prep
# 11 NUM pobj
# U.S.C. PROPN compound
# § NOUN dobj
# 101(31 NUM nummod
# ) PUNCT punct
# . PUNCT punct
# Also ADV advmod
# , PUNCT punct
# do AUX aux
# not PART neg
#
#  SPACE
# include VERB ROOT
# claims NOUN dobj
# by ADP prep
# secured VERB amod
# creditors NOUN pobj
# , PUNCT punct
# unless SCONJ mark
# the DET det
# unsecured ADJ amod
# ...
# Doc NOUN pobj
# 1 NUM nummod
#           SPACE
# Filed VERB ROOT
# 08/09/17 PROPN punct
# Entered VERB compound
# 08/09/17 PROPN ROOT
# 15:59:37 NUM nummod
#                     SPACE
# Main PROPN compound
# Document PROPN appos
#
#                                                                         SPACE
# Pg PROPN ROOT
# 11 NUM nummod
# of ADP prep
# 13 NUM nummod
#
#
#
#
#                                                                 SPACE
# United PROPN compound
# States PROPN compound
# Bankruptcy PROPN compound
# Court PROPN pobj
#
#                                                                       SPACE
# Southern PROPN compound
# District PROPN appos
# of ADP prep
# New PROPN compound
# York PROPN pobj
#
#   SPACE
# In ADP ROOT
# re NOUN nmod
#       SPACE
# PGB PROPN pobj
# 38 NUM nummod
# LLC PROPN appos
#                                                                                     SPACE
# Case PROPN compound
# No NOUN intj
# . PROPN punct
#
#                                                                                    SPACE
# Debtor(s PROPN ROOT
# ) PUNCT punct
#                SPACE
# Chapter NOUN nmod
#      SPACE
# 11 NUM nummod
#
#
#
#
#
#                                             SPACE
# CORPORATE PROPN amod
# OWNERSHIP PROPN compound
# STATEMENT NOUN ROOT
# ( PUNCT punct
# RULE PROPN appos
# 7007.1 NUM nummod
# ) PUNCT punct
#
#
#  SPACE
# Pursuant ADJ nsubj
# to ADP prep
# Federal PROPN compound
# Rule PROPN pobj
# of ADP prep
# Bankruptcy PROPN compound
# Procedure PROPN compound
# 7007.1 PROPN pobj
# and CCONJ cc
# to PART aux
# enable VERB conj
# the DET det
# Judges PROPN dobj
# to PART aux
# evaluate VERB xcomp
# possible ADJ amod
# disqualification NOUN dobj
# or CCONJ cc
#
#  SPACE
# recusal NOUN conj
# , PUNCT punct
# the DET det
# undersigned ADJ amod
# counsel NOUN dobj
# for ADP prep
# PGB PROPN nmod
# 38 NUM nummod
# LLC PROPN pobj
# in ADP prep
# the DET det
# above ADJ amod
# captioned VERB amod
# action NOUN pobj
# , PUNCT punct
# certifies VERB ROOT
# that SCONJ mark
# the DET det
# following VERB nsubj
# is AUX ccomp
# a DET det
# ( PUNCT punct
# are AUX parataxis
# ) PUNCT punct
#
#  SPACE
# corporation(s PROPN dep
# ) PUNCT punct
# , PUNCT punct
# other ADJ acomp
# than SCONJ prep
# the DET det
# debtor NOUN pobj
# or CCONJ cc
# a DET det
# governmental ADJ amod
# unit NOUN conj
# , PUNCT punct
# that DET attr
# directly ADV advmod
# or CCONJ cc
# indirectly ADV conj
# own(s ADV pobj
# ) PUNCT punct
# 10 NUM nummod
# % NOUN punct
# or CCONJ cc
# more ADJ nummod
# of ADP prep
# any DET det
# class NOUN pobj
# of ADP prep
#
#  SPACE
# the DET det
# corporation's(s PROPN appos
# ' PUNCT punct
# ) PUNCT punct
# equity NOUN compound
# interests NOUN conj
# , PUNCT punct
# or CCONJ cc
# states VERB conj
# that SCONJ mark
# there PRON expl
# are AUX ccomp
# no DET det
# entities NOUN attr
# to PART aux
# report VERB relcl
# under ADP prep
# FRBP PROPN pobj
# 7007.1 NUM nummod
# : PUNCT punct
#
#
#
#
#      SPACE
# None NOUN nmod
# [ PUNCT punct
# Check VERB attr
# if SCONJ mark
# applicable ADJ advcl
# ] PUNCT punct
#
#
#
#
#
#   SPACE
# August PROPN ROOT
# 8 NUM nummod
# , PUNCT punct
# 2017 NUM nummod
#                                                        SPACE
# /s/ PUNCT punct
# Gregory PROPN compound
# M. PROPN compound
# Messer PROPN nmod
#
#   SPACE
# Date PROPN appos
#                                                                  SPACE
# Gregory PROPN compound
# M. PROPN compound
# Messer PROPN appos
#
#                                                                        SPACE
# Signature PROPN nmod
# of ADP prep
# Attorney PROPN pobj
# or CCONJ cc
# Litigant PROPN conj
#
#                                                                        SPACE
# Counsel NOUN ROOT
# for ADP prep
# PGB PROPN nmod
# 38 NUM nummod
# LLC PROPN appos
#
#                                                                        SPACE
# Law PROPN compound
# Office PROPN pobj
# of ADP prep
# Gregory PROPN compound
# Messer PROPN pobj
#
#                                                                        SPACE
# Law PROPN compound
# Office PROPN ROOT
# of ADP prep
# Gregory PROPN compound
# Messer PROPN pobj
#
#                                                                        SPACE
# 26 NUM nummod
# Court PROPN compound
# Street PROPN appos
# , PUNCT punct
# Suite PROPN npadvmod
# 2400 NUM nummod
#
#                                                                        SPACE
# Brooklyn PROPN ROOT
# , PUNCT punct
# NY PROPN appos
# 11242 NUM nummod
#
#                                                                        SPACE
# 718 NUM nummod
# - PUNCT punct
# 858 NUM nummod
# - PUNCT punct
# 1474 NUM nummod
# Fax:718 PROPN nmod
# - PUNCT punct
# 797 NUM nummod
# - PUNCT punct
# 5360 NUM prep
#
#                                                                        SPACE
# gremesser@aol.com SYM nummod
#
#
#
#
#
#  SPACE
# Software PROPN compound
# Copyright PROPN nmod
# ( PUNCT punct
# c NOUN appos
# ) PUNCT punct
# 1996 NUM appos
# - SYM punct
# 2017 NUM appos
# Best PROPN compound
# Case PROPN ROOT
# , PUNCT punct
# LLC PROPN compound
# - PUNCT punct
# www.bestcase.com PROPN npadvmod
#                                                              SPACE
# Best PROPN ROOT
# Case PROPN compound
# Bankruptcy PROPN pobj
#
#            SPACE
# 17 NUM nummod
# - SYM punct
# 12211-smb PROPN nmod
#                     SPACE
# Doc NOUN nsubj
# 1 NUM nummod
#           SPACE
# Filed VERB ROOT
# 08/09/17 PROPN punct
# Entered VERB compound
# 08/09/17 PROPN ROOT
# 15:59:37 NUM nummod
#                     SPACE
# Main PROPN compound
# Document PROPN appos
#
#                                                                         SPACE
# Pg PROPN ROOT
# 12 NUM nummod
# of ADP prep
# 13 NUM nummod
#
#
#                                                                 SPACE
# United PROPN compound
# States PROPN compound
# Bankruptcy PROPN compound
# Court PROPN pobj
#
#                                                                       SPACE
# Southern PROPN compound
# District PROPN appos
# of ADP prep
# New PROPN compound
# York PROPN pobj
#
#   SPACE
# In ADP ROOT
# re NOUN nmod
#       SPACE
# PGB PROPN pobj
# 38 NUM nummod
# LLC PROPN appos
#                                                                                     SPACE
# Case PROPN compound
# No NOUN intj
# . PROPN punct
#
#                                                                                    SPACE
# Debtor(s PROPN ROOT
# ) PUNCT punct
#                SPACE
# Chapter NOUN nmod
#      SPACE
# 11 NUM nummod
#
#
#
#
#             SPACE
# STATEMENT NOUN compound
# REGARDING VERB compound
# AUTHORITY ADV ROOT
# TO PART prep
# SIGN VERB pobj
# AND CCONJ cc
# FILE PROPN compound
# PETITION NOUN conj
#
#          SPACE
# I PRON nsubj
# , PUNCT punct
# Philip PROPN compound
# Menegis PROPN appos
# , PUNCT punct
# declare VERB ROOT
# under ADP prep
# penalty NOUN pobj
# of ADP prep
# perjury NOUN pobj
# that PRON mark
# I PRON nsubj
# am AUX ccomp
# the DET det
# Managing PROPN compound
# Member PROPN attr
# of ADP prep
# PGB PROPN pobj
# 38 NUM nummod
# LLC PROPN conj
# , PUNCT punct
# and CCONJ cc
# that SCONJ mark
#
#  SPACE
# the DET det
# following NOUN nsubj
# is AUX conj
# a DET det
# true ADJ amod
# and CCONJ cc
# correct ADJ conj
# copy NOUN attr
# of ADP prep
# the DET det
# resolutions NOUN pobj
# adopted VERB acl
# by ADP agent
# the DET det
# Board PROPN pobj
# of ADP prep
# Directors PROPN pobj
# of ADP prep
# said VERB pobj
# corporation PROPN pobj
#
#  SPACE
# at ADP prep
# a DET det
# special ADJ amod
# meeting NOUN pobj
# duly ADV advmod
# called VERB acl
# and CCONJ cc
# held VERB conj
# on ADP prep
# the DET det
# 7th ADJ amod
# day NOUN pobj
# of ADP prep
# August PROPN pobj
# , PUNCT punct
# 20 NUM nummod
# 17 NUM appos
# . PUNCT punct
#
#
#        SPACE
# " PUNCT punct
# Whereas SCONJ advmod
# , PUNCT punct
# it PRON nsubj
# is AUX ROOT
# in ADP prep
# the DET det
# best ADJ amod
# interest NOUN pobj
# of ADP prep
# this DET det
# corporation NOUN pobj
# to PART aux
# file VERB xcomp
# a DET det
# voluntary ADJ amod
# petition NOUN dobj
# in ADP prep
# the DET det
# United PROPN compound
# States PROPN compound
#
#  SPACE
# Bankruptcy PROPN compound
# Court PROPN pobj
# pursuant NOUN advcl
# to ADP prep
# Chapter NOUN pobj
# 11 NUM nummod
# of ADP prep
# Title PROPN pobj
# 11 NUM nummod
# of ADP prep
# the DET det
# United PROPN compound
# States PROPN compound
# Code PROPN pobj
# ; PUNCT punct
#
#
#          SPACE
# Be AUX ROOT
# It PRON nsubj
# Therefore ADV advmod
# Resolved VERB acomp
# , PUNCT punct
# that SCONJ mark
# Philip PROPN compound
# Menegis PROPN nsubjpass
# , PUNCT punct
# Managing PROPN compound
# Member PROPN appos
# of ADP prep
# this DET det
# Corporation PROPN pobj
# , PUNCT punct
# is AUX auxpass
# authorized VERB ccomp
# and CCONJ cc
#
#  SPACE
# directed VERB conj
# to PART aux
# execute VERB xcomp
# and CCONJ cc
# deliver VERB conj
# all DET det
# documents NOUN dobj
# necessary ADJ amod
# to PART aux
# perfect VERB xcomp
# the DET det
# filing NOUN dobj
# of ADP prep
# a DET det
# chapter NOUN nmod
# 11 NUM nummod
# voluntary ADJ amod
#
#  SPACE
# bankruptcy NOUN compound
# case NOUN pobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# the DET det
# corporation NOUN pobj
# ; PUNCT punct
# and CCONJ cc
#
#
#           SPACE
# Be AUX auxpass
# It PRON attr
# Further PROPN advmod
# Resolved VERB conj
# , PUNCT punct
# that SCONJ mark
# Philip PROPN compound
# Menegis PROPN nsubjpass
# , PUNCT punct
# Managing PROPN compound
# Member PROPN appos
# of ADP prep
# this DET det
# Corporation PROPN pobj
# is AUX auxpass
# authorized VERB ccomp
# and CCONJ cc
#
#  SPACE
# directed VERB conj
# to PART aux
# appear VERB xcomp
# in ADP prep
# all DET det
# bankruptcy NOUN compound
# proceedings NOUN pobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# the DET det
# corporation NOUN pobj
# , PUNCT punct
# and CCONJ cc
# to PART aux
# otherwise ADV advmod
# do AUX conj
# and CCONJ cc
# perform VERB conj
#
#  SPACE
# all DET det
# acts NOUN dobj
# and CCONJ cc
# deeds NOUN conj
# and CCONJ cc
# to PART aux
# execute VERB conj
# and CCONJ cc
# deliver VERB conj
# all DET det
# necessary ADJ amod
# documents NOUN dobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# the DET det
# corporation NOUN pobj
# in ADP prep
# connection NOUN pobj
#
#  SPACE
# with ADP prep
# such ADJ amod
# bankruptcy NOUN compound
# case NOUN pobj
# , PUNCT punct
# and CCONJ cc
#
#
#          SPACE
# Be AUX ROOT
# It PRON nsubj
# Further PROPN advmod
# Resolved VERB acomp
# , PUNCT punct
# that SCONJ mark
# Philip PROPN compound
# Menegis PROPN nsubjpass
# , PUNCT punct
# Managing PROPN compound
# Member PROPN appos
# of ADP prep
# this DET det
# Corporation PROPN pobj
# is AUX auxpass
# authorized VERB ccomp
# and CCONJ cc
#
#  SPACE
# directed VERB conj
# to PART aux
# employ VERB xcomp
# Gregory PROPN compound
# M. PROPN compound
# Messer PROPN dobj
# , PUNCT punct
# attorney NOUN conj
# and CCONJ cc
# the DET det
# law NOUN compound
# firm NOUN conj
# of ADP prep
# Law PROPN compound
# Office PROPN pobj
# of ADP prep
# Gregory PROPN compound
# Messer PROPN pobj
# to PART aux
# represent VERB advcl
# the DET det
#
#  SPACE
# corporation NOUN dobj
# in ADP prep
# such ADJ amod
# bankruptcy NOUN compound
# case NOUN pobj
# . PUNCT punct
# " PUNCT punct
#
#
#   SPACE
# Date PROPN ROOT
# 8 NUM nummod
# August PROPN npadvmod
# 2017 NUM nummod
#                                                              SPACE
# Signed VERB compound
# s/ VERB compound
# Philip PROPN compound
# Menegis PROPN ROOT
#
#                                                                                           SPACE
# Philip PROPN nmod
# Menegis PROPN nmod
#
#
#
#
#
#  SPACE
# Software PROPN compound
# Copyright PROPN nmod
# ( PUNCT punct
# c NOUN appos
# ) PUNCT punct
# 1996 NUM appos
# - SYM punct
# 2017 NUM appos
# Best PROPN compound
# Case PROPN appos
# , PUNCT punct
# LLC PROPN compound
# - PUNCT punct
# www.bestcase.com PROPN npadvmod
#                                                              SPACE
# Best PROPN ROOT
# Case PROPN compound
# Bankruptcy PROPN pobj
#
#            SPACE
# 17 NUM nummod
# - SYM punct
# 12211-smb PROPN nmod
#                     SPACE
# Doc NOUN nsubj
# 1 NUM nummod
#           SPACE
# Filed VERB ROOT
# 08/09/17 PROPN punct
# Entered VERB ROOT
# 08/09/17 PROPN npadvmod
# 15:59:37 NUM appos
#                SPACE
# Main PROPN amod
# Document PROPN dobj
#
#                                                                         SPACE
# Pg PROPN appos
# 13 NUM nummod
# of ADP prep
# 13 NUM nummod
#
#
#                                                                       SPACE
# Resolution PROPN pobj
# of ADP prep
# Board PROPN pobj
# of ADP prep
# Directors PROPN pobj
#
#                                                                                      SPACE
# of ADP prep
#
#                                                                                 SPACE
# PGB PROPN nmod
# 38 NUM nummod
# LLC PROPN ROOT
#
#
#
#
#
#        SPACE
# Whereas SCONJ advmod
# , PUNCT punct
# it PRON nsubj
# is AUX ROOT
# in ADP prep
# the DET det
# best ADJ amod
# interest NOUN pobj
# of ADP prep
# this DET det
# corporation NOUN pobj
# to PART aux
# file VERB xcomp
# a DET det
# voluntary ADJ amod
# petition NOUN dobj
# in ADP prep
# the DET det
# the DET det
# United PROPN compound
# States PROPN compound
#
#  SPACE
# Bankruptcy PROPN compound
# Court PROPN pobj
# pursuant NOUN ROOT
# to ADP prep
# Chapter NOUN pobj
# 11 NUM nummod
# of ADP prep
# Title PROPN pobj
# 11 NUM nummod
# of ADP prep
# the DET det
# United PROPN compound
# States PROPN compound
# Code PROPN pobj
# ; PUNCT punct
#
#
#          SPACE
# Be AUX ROOT
# It PRON nsubj
# Therefore ADV advmod
# Resolved VERB acomp
# , PUNCT punct
# that SCONJ mark
# Philip PROPN compound
# Menegis PROPN nsubjpass
# , PUNCT punct
# Managing PROPN compound
# Member PROPN appos
# of ADP prep
# this DET det
# Corporation PROPN pobj
# , PUNCT punct
# is AUX auxpass
# authorized VERB ccomp
# and CCONJ cc
#
#  SPACE
# directed VERB conj
# to PART aux
# execute VERB xcomp
# and CCONJ cc
# deliver VERB conj
# all DET det
# documents NOUN dobj
# necessary ADJ amod
# to PART aux
# perfect VERB xcomp
# the DET det
# filing NOUN dobj
# of ADP prep
# a DET det
# chapter NOUN nmod
# 11 NUM nummod
# voluntary ADJ amod
#
#  SPACE
# bankruptcy NOUN compound
# case NOUN pobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# the DET det
# corporation NOUN pobj
# ; PUNCT punct
# and CCONJ cc
#
#
#           SPACE
# Be AUX auxpass
# It PRON attr
# Further PROPN advmod
# Resolved VERB conj
# , PUNCT punct
# that SCONJ mark
# Philip PROPN compound
# Menegis PROPN nsubjpass
# , PUNCT punct
# Managing PROPN compound
# Member PROPN appos
# of ADP prep
# this DET det
# Corporation PROPN pobj
# is AUX auxpass
# authorized VERB ccomp
# and CCONJ cc
#
#  SPACE
# directed VERB conj
# to PART aux
# appear VERB xcomp
# in ADP prep
# all DET det
# bankruptcy NOUN compound
# proceedings NOUN pobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# the DET det
# corporation NOUN pobj
# , PUNCT punct
# and CCONJ cc
# to PART aux
# otherwise ADV advmod
# do AUX conj
# and CCONJ cc
# perform VERB conj
#
#  SPACE
# all DET det
# acts NOUN dobj
# and CCONJ cc
# deeds NOUN conj
# and CCONJ cc
# to PART aux
# execute VERB conj
# and CCONJ cc
# deliver VERB conj
# all DET det
# necessary ADJ amod
# documents NOUN dobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# the DET det
# corporation NOUN pobj
# in ADP prep
# connection NOUN pobj
#
#  SPACE
# with ADP prep
# such ADJ amod
# bankruptcy NOUN compound
# case NOUN pobj
# , PUNCT punct
# and CCONJ cc
#
#
#          SPACE
# Be AUX ROOT
# It PRON nsubj
# Further PROPN advmod
# Resolved VERB acomp
# , PUNCT punct
# that SCONJ mark
# Philip PROPN compound
# Menegis PROPN nsubjpass
# , PUNCT punct
# Managing PROPN compound
# Member PROPN appos
# of ADP prep
# this DET det
# Corporation PROPN pobj
# is AUX auxpass
# authorized VERB ccomp
# and CCONJ cc
#
#  SPACE
# directed VERB conj
# to PART aux
# employ VERB xcomp
# Gregory PROPN compound
# M. PROPN compound
# Messer PROPN dobj
# , PUNCT punct
# attorney NOUN conj
# and CCONJ cc
# the DET det
# law NOUN compound
# firm NOUN conj
# of ADP prep
# Law PROPN compound
# Office PROPN pobj
# of ADP prep
# Gregory PROPN compound
# Messer PROPN pobj
# to PART aux
# represent VERB advcl
# the DET det
#
#  SPACE
# corporation NOUN dobj
# in ADP prep
# such ADJ amod
# bankruptcy NOUN compound
# case NOUN pobj
# . PUNCT punct
#
#
#   SPACE
# Date PROPN nsubj
# 8 NUM nummod
# August PROPN npadvmod
# 2017 NUM nummod
#                                                               SPACE
# Signed PROPN ROOT
#      SPACE
# s/ VERB compound
# Philip PROPN compound
# Menegis PROPN dobj
#
#                                                                                              SPACE
# Philip PROPN compound
# Menegis PROPN appos
#
#
#
#   SPACE
# Date PROPN conj
#                                                                             SPACE
# Signed VERB amod
#
#
#
#
#
#  SPACE
# Software PROPN compound
# Copyright PROPN nmod
# ( PUNCT punct
# c NOUN appos
# ) PUNCT punct
# 1996 NUM appos
# - SYM punct
# 2017 NUM appos
# Best PROPN compound
# Case PROPN ROOT
# , PUNCT punct
# LLC PROPN compound
# - PUNCT punct
# www.bestcase.com PROPN appos
#                                                         SPACE
# Best PROPN amod
# Case PROPN compound
# Bankruptcy PROPN ROOT
#
#  SPACE

# %%
# Chunks
for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# Doc
# 13
# Fill
# this information
# your case
# United States Bankruptcy Court
# the:
#
# SOUTHERN DISTRICT
# NEW YORK
#
# Case number
# Chapter
# 201
# Voluntary Petition
# Bankruptcy
# more space
# a separate sheet
# this form
# the top
# any additional pages
# the debtor's name and case number
# more information
# a separate document
# Instructions
# Bankruptcy Forms
# Non-Individuals
# Debtor's name
# PGB
# LLC
# the last 8 years
# any assumed
#      names
# trade names
# business
# names
# Employer Identification
# XX-XXXXXXX
# Number
# (EIN
# Debtor's address
# Principal place
# business                                     Mailing address
# principal place
# business
# Avenue
# New York
# NY
# Number
# P.O. Box
# Number
# Street
# City
# State & ZIP Code
# New York
# Location
# principal assets
# County
# place
# business
#
#                                                                                                   Number
# Street, City, State & ZIP Code
# Debtor's website
# (URL
# Type
# debtor                   Corporation
# Limited Liability Company
# LLC
# Limited Liability Partnership
# LLP
# Partnership
# LLP
# Specify
# Voluntary Petition
# Bankruptcy
# page
# Entered 08/09/17
# 15:59:37                          Main Document
# 13
# Debtor
# Name
# Describe debtor's business
# A. Check
# Health Care Business
# Single Asset Real Estate
# U.S.C. § 101(51B
# Railroad
# as defined in 11 U.S.C. §
# Stockbroker
# Commodity Broker
# U.S.C. § 101(6
# Clearing Bank
# 11 U.S.C. § 781(3
# the above
#
#                                        B. Check
# that
# Tax-exempt entity
# hedge fund
# pooled investment vehicle
# Investment advisor
# 15 U.S.C. §80b-2(a)(11
# C. NAICS
# North American Industry Classification System
# 4-digit code
# that
# debtor
# See http://www.uscourts.gov/four-digit-national-association-naics-codes
# which chapter
# the        Check
# Bankruptcy Code
# Chapter 7
#      debtor filing
# Chapter
# Chapter
# that
# Debtor's aggregate noncontingent liquidated debts
# debts
# insiders
# affiliates
# amount
# adjustment
# The debtor
# a small business debtor
# the debtor
# a small
#                                                                  business debtor
# the most recent balance sheet
# statement
# operations
# cash-flow
#                                                                  statement
# federal income tax return
# these documents
# the
#                                                                  procedure
# 11 U.S.C. § 1116(1)(B
# A plan
# this petition
# Acceptances
# the plan
# one or more classes
# creditors
# accordance
# 11 U.S.C. §
# The debtor
# periodic reports
# example
# the Securities
# Exchange Commission
# §
# the Securities Exchange Act
# the
#                                                                  attachment
# Voluntary Petition
# Bankruptcy
# Chapter
# this form
# The debtor
# a shell company
# the Securities Exchange Act
# Chapter
# prior bankruptcy
# No.
#      cases
# the debtor
# the last 8         Yes.
#      years
# a
#      separate list
# District
# When                                  Case number
# District
# Case number
# any bankruptcy cases
# a
#     business partner
# an                Yes.
#     affiliate
# the debtor
# all cases
# a separate list
# Debtor                                                                    Relationship
# When                              Case number
# known
#
#
#
#
# Official Form
# Voluntary Petition
# Bankruptcy
# 17-12211-smb
# Doc
# Entered 08/09/17
# 15:59:37                        Main Document
# 13
# Debtor   PGB
# 38 LLC
# Name
# the case
# that
# this district
# Debtor
# its domicile, principal place
# business
# principal assets
# this district
# 180 days
# the date
# this petition
# a longer part
# such 180 days
# any other district
# A bankruptcy case
# debtor's affiliate
# general partner
# partnership
# this district
# the debtor
# possession
# any
#     real property
# Answer
# each property
# that
# immediate attention
# additional sheets
# Yes.
#     property
# that
# immediate attention
# the property
# immediate attention
# that
# It
# a threat
# imminent and identifiable hazard
# public health
# safety
# What
# the hazard
# It
# the weather
# It
# perishable goods
# assets
# that
# value
# attention
# example
# livestock
# seasonal goods
# meat
# dairy
# securities-related assets
# other options
# the property
# Number
# Code
# the property
# Yes.    Insurance agency
#                                                         Contact name
# Phone
#
#
#
#          Statistical and administrative information
# Debtor's estimation
# Check
# available funds
# Funds
# distribution
# unsecured creditors
# any administrative expenses
# no funds
# unsecured creditors
# Estimated number
# 1-49                                             1,000-5,000                                 25,001-50,000
#     creditors
# Estimated Assets
# Estimated liabilities
# $50,000                                     $1,000,001 - $10 million                    $500,000,001 - $1 billion
#                                     $50,001 - $100,000                               $10,000,001 - $50 million                   $1,000,000,001 - $10 billion
#                                     $100,001 - $500,000                              $50,000,001 - $100 million                  $10,000,000,001 - $50 billion
#                                     $500,001 - $1 million                            $100,000,001 - $500 million                 More than $50 billion
#
#
#
#
# Official Form 201                           Voluntary Petition
# Bankruptcy
# page
# 17-12211-smb
# Doc
# Filed 08/09/17
# Entered 08/09/17
# 15:59:37                        Main Document
# 38 LLC
# Name
#
#
#
#           Request
# Relief
# Declaration
# Signatures
# WARNING
# Bankruptcy fraud
# a serious crime
# a false statement
# connection
# a bankruptcy case
# fines
# up to $500,000 or
#            imprisonment
# up to 20 years
# 18 U.S.C. §§
# Declaration
# signature
# The debtor requests relief
# accordance
# the chapter
# title
# United States Code
# this petition
# representative
# debtor
# I
# this petition
# behalf
# the debtor
# I
# the information
# this petition
# a reasonable belief
# the information
# I
# penalty
# perjury
# the foregoing
# MM / DD / YYYY
# X
# Philip Menegis
# Philip Menegis
# Signature
# authorized representative
# debtor
# Title
# Managing Member
# Signature
# attorney
# X   /s/ Gregory M. Messer
# Signature
# attorney
# debtor                                               MM / DD / YYYY
# Gregory M. Messer
# Printed name
#
#                                  Law Office
# Gregory Messer
# Firm name
#
#                                  Law Office
# Gregory Messer
# 26 Court Street
# Brooklyn
# NY
# Number
# Contact phone
# Email address
# Bar number and State
#
#
#
#
# Official Form 201                          Voluntary Petition
# Bankruptcy
# 17-12211-smb                    Doc
# Entered 08/09/17
# Main Document
# Pg
# Fill
# this information
# the case
# Debtor name
# PGB 38 LLC
#
#  United States Bankruptcy Court
# the:            SOUTHERN DISTRICT
# NEW YORK
#
#  Case number
# (if known)
#                                                                                                                                   Check
# an
#                                                                                                                                   amended filing
#
#
#
# Official Form 202
# Declaration
# Penalty
# Perjury
# Non-Individual Debtors
# 12/15
#
# An individual
# who
# behalf
# a non-individual debtor
# a corporation
# partnership
# this
# form
# the schedules
# assets
# liabilities
# any other document
# that
# a declaration
# that
# the document
# any
# amendments
# those documents
# This form
# the individual’s position
# relationship
# the debtor
# the identity
# the document
# the date
# Bankruptcy Rules
# WARNING
# Bankruptcy fraud
# a serious crime
# a false statement
# property
# money
# property
# fraud
# connection
# a bankruptcy case
# fines
# imprisonment
# up to 20 years
# 18 U.S.C. §§
# Declaration
# signature
# I
# the president
# another officer
# an authorized agent
# the corporation
# a member
# an authorized agent
# the partnership
# another
#        individual
# a representative
# the debtor
# this case
# I
# the information
# the documents
# I
# a reasonable belief
# the information
# Assets
# Real and Personal Property
# Official Form
# 206A/B
# Schedule D
# Creditors
# Who
# Claims
# Property
# Official Form
# Schedule E/F
# Creditors
# Who
# Unsecured Claims
# Official Form
# 206E/F
# Schedule G
# Executory Contracts
# Unexpired Leases
# Official Form
# 206G
# Schedule H
# Codebtors
# Summary
# Assets
# Liabilities
# Non-Individuals
# (Official Form
# Amended Schedule
# Chapter
# Chapter 9 Cases
# List
# Creditors
# Who
# the 20 Largest Unsecured Claims
# Not Insiders
# Official Form
# Other document
# that
# a declaration
# I
# penalty
# perjury
# the foregoing
# August
# X /s/ Philip Menegis
# Signature
# individual signing
# behalf
# debtor
#
#                                                                        Philip Menegis
# Printed name
# Managing Member
#                                                                        Position
# relationship
# debtor
#
#
#
#
# Official Form
# Penalty
# Perjury
# Non-Individual Debtors
# Software Copyright
# (c
# 2017 Best Case
# Best Case Bankruptcy
# 17-12211-smb                    Doc
# Entered 08/09/17
# 15:59:37                             Main Document
# Pg
# of 13
#
#  Fill
# this information
# the case
# Debtor name PGB 38 LLC
#  United States Bankruptcy Court
# the: SOUTHERN DISTRICT
# NEW                                                                                     Check
# an
#                                                 YORK
#  Case number
# amended filing
#
#
#
#
# Official Form 204
# Chapter 11 or Chapter 9 Cases
# List
# Creditors
# Who
# the 20 Largest Unsecured Claims
# Insiders
# 12/15
#
# A list
# creditors
# the 20 largest unsecured claims
# a Chapter 11 or Chapter 9 case
# Include
# claims
# which
# claims
# any person
# entity
# who
# an insider
# U.S.C. §
# claims
# secured creditors
# the unsecured claim
# inadequate collateral value
# the creditor
# the holders
# the 20 largest unsecured claims
# Name
# creditor
# Name
# telephone number Nature
# claim
# Amount
# claim
# example
# trade
# the claim
# only unsecured claim amount
# zip code        creditor contact
# debts
# bank loans
# unliquidated, or    claim
# total claim amount
# deduction
# professional services
# value
# collateral
# setoff
# unsecured claim
# government                                             Total claim
# Deduction
# value
# contracts
# collateral
# setoff
# Con Edison
# $21,943.21
#  Cooper Station
# P.O. Box
# NY
#  10276-0138
#  Internal Revenue
# $0.00
#  Service
#  Department
# the
#  Treasury
#  Holtsville
# NY
# 11742-0480
#  Kimco 1572 Corp                                                 Commercial Lease
# Unliquidated
# 15TH ST.
# 2 Avenue
# St Disputed
# Fort Lee
# NJ
# NY
#                                                                  10028
#  New York State Dept
# Taxation & Finance
#  WA Harriman
#  Campus
#  Albany
# NY
#  12227-0001
#  NYC Department
# $0.00
#  Finance
#  P.O. Box 3671
#  New York
# NY
# Official form
# Chapter
# Chapter 9 Cases
# List
# Creditors
# Who
# the 20 Largest Unsecured claims                                 page
# 1
#
# Software Copyright
# (c
# Best Case
# Best Case
# 17-12211-smb                  Doc
# Entered 08/09/17
# 15:59:37                 Main Document
# Pg
# 13
# B2030
# Form
# (12/15)
#                                                                United States Bankruptcy Court
# Southern District
# New York
# re
# PGB 38 LLC                                                                                        Case No.
#                                                                                       Debtor(s
# Chapter
# DISCLOSURE
# COMPENSATION
# ATTORNEY
# DEBTOR(S
# Pursuant
# 11 U
# Fed
# Bankr
# I
# I
# the attorney
# compensation
# me
# one year
# the filing
# the petition
# bankruptcy
# me
# services
# behalf
# contemplation
# connection
# the bankruptcy case
# legal services
# I
# the filing
# this statement
# I
# Balance Due
# The source
# the compensation
# me
# Debtor
# Other
# Philip Menegis
# The source
# compensation
# me
# Debtor
# Other
# I
# the above-disclosed compensation
# any other person
# they
# members
# associates
# my law firm
# I
# the above-disclosed compensation
# a person
# persons
# who
# members
# associates
# my law firm
# A
#             copy
# the agreement
# a list
# the names
# the people
# the compensation
# return
# the above-disclosed fee
# I
# legal service
# all aspects
# the bankruptcy case
# a.   Analysis
# the debtor's financial situation
# advice
# the debtor
# a petition
# bankruptcy
# b.   Preparation
# filing
# any petition
# schedules
# statement
# affairs
# plan
# which
# c.   Representation
# the debtor
# the meeting
# creditors
# confirmation hearing
# any adjourned hearings
# [Other provisions
# Negotiations
# secured creditors
# market value
# exemption planning
# preparation
# filing
# reaffirmation agreements
# applications
# preparation
# filing
# motions
# 11 USC
# avoidance
# liens
# household goods
# agreement
# the above-disclosed fee
# the following service
# Representation
# the debtors
# any dischargeability actions
# judicial lien avoidances
# relief
# stay actions
# any other adversary proceeding
# CERTIFICATION
# I
# the foregoing
# a complete statement
# any agreement
# arrangement
# payment
# me
# representation
# this bankruptcy proceeding
# August
# Gregory M. Messer
# Date                                                                             Gregory M. Messer
# Signature
# Attorney
# Law Office
# Gregory Messer
# Law Office
# Gregory Messer
# 26 Court Street
# Brooklyn
# NY
# Fax
# Name
# law firm
# Software Copyright
# (c
# 2017 Best Case
# Best Case Bankruptcy
# 17-12211-smb                    Doc
# Entered 08/09/17
# Main Document
# Pg
# 13
#                                                                United States Bankruptcy Court
# Southern District
# New York
# re      PGB
# 38 LLC
# Case
# No.
#                                                                                     Debtor(s)                         Chapter        11
#
#                                                          LIST
# EQUITY SECURITY HOLDERS
# the list
# the Debtor's equity security holders
# which
# accordance
# this Chapter 11 Case
# Name
# last known address
# place
# Security Class Number
# Securities
# Kind
# Interest
#  business
# holder
# Joseph Allaham
# Madison Ave
# NY
# Philip Menegis
# Managing Member
# Ocean Pkwy
#  Brooklyn
# NY
# DECLARATION
# PENALTY
# PERJURY
# BEHALF
# CORPORATION
# PARTNERSHIP
# I
# the Managing Member
# the corporation
# the debtor
# this case
# penalty
# perjury
# I
# the foregoing List
# Equity Security Holders
# it
# my information
# belief
# Date August
# Signature
# /s/ Philip Menegis
# Philip Menegis
#
#                        Penalty
# a false statement
# property
# Fine
# imprisonment
# up to 5 years
# U.S.C. §§
# Sheet
# List
# Equity Security Holders
# Software Copyright
# (c
# Best Case
# Best Case Bankruptcy
# 17-12211-smb                    Doc
# Entered 08/09/17
# 15:59:37            Main Document
# Pg
# United States Bankruptcy Court
# Southern District
# New York
# re      PGB
# 38 LLC
# Case
# No
# Debtor(s
# Chapter
# 11
#
#
#
#
#                                                VERIFICATION
# CREDITOR MATRIX
# I
# the Managing Member
# the corporation
# the debtor
# this case
# the attached list
# creditors
# my knowledge
# Date
# August
# Philip Menegis
# Philip Menegis/Managing Member
# Signer
# Title
#
#
#
#
# Software
# (c
# LLC - www.bestcase.com
# Best Case Bankruptcy
# 17-12211-smb
# Doc
# Entered 08/09/17 15:59:37   Main Document
# k
# C
# r
# e
# d
# i
# t
# o
# a
# x
#
#
#
#
#                            CON EDISON
# P.O. BOX
# NEW YORK
# NY 10276-0138
#
#
#                            EMMANUELLI
# PILOTTI
# ESQS
# 1188-A GRAND CONCOURSE
# NY
# INTERNAL REVENUE SERVICE
# DEPARTMENT
# THE TREASURY
# HOLTSVILLE
# NY 11742-0480
#
#
#                            KIMCO
# 1572 CORP
#                            1265 15TH ST.
# #1M
# FORT LEE
# NJ
# NEW YORK STATE DEPT
# TAXATION
# FINANCE
# WA HARRIMAN CAMPUS
# ALBANY
# NY 12227-0001
#
#
#                            NYC DEPARTMENT
# FINANCE
# P.O. BOX
# NEW YORK
# NY 10008-3671
#
#
#                            TLE ASSOCIATES
# INC.
# PO
# BOX
# 126 RIVERDALE STATION
# NY
# 17-12211-smb
# Doc
# Entered 08/09/17
# 15:59:37                    Main Document
# Pg
# 13
#
#
#
#                                                                United States Bankruptcy Court
# Southern District
# New York
# re      PGB
# 38 LLC
# Case No.
#                                                                                   Debtor(s
# Chapter     11
#
#
#
#
#                                            CORPORATE OWNERSHIP STATEMENT
# RULE
# Federal Rule
# Bankruptcy Procedure 7007.1
# the Judges
# possible disqualification
# recusal
# the undersigned counsel
# PGB 38 LLC
# the above captioned action
# the debtor
# a governmental unit
# any class
# the corporation's(s
# equity interests
# no entities
# FRBP
# August
# Date
# Gregory M. Messer
# Attorney
# Litigant
# 38 LLC
# Gregory Messer
# Law Office
# Gregory Messer
# 26 Court Street
# Brooklyn
# NY
# (c
# Best
# Case Bankruptcy
# 17-12211-smb                    Doc
# Entered 08/09/17
# 15:59:37                    Main Document
# Pg
# 13
#
#                                                                United States Bankruptcy Court
# Southern District
# New York
# re      PGB
# 38 LLC
# Case No.
#                                                                                   Debtor(s
# FILE PETITION
# I
# Philip Menegis
# penalty
# perjury
# I
# the Managing Member
# PGB
# LLC
# the following
# a true and correct copy
# the resolutions
# the Board
# Directors
# corporation
# a special meeting
# the 7th day
# August
# it
# the best interest
# this corporation
# a voluntary petition
# the United States
# Bankruptcy Court
# Chapter
# Title
# the United States Code
# It
# Philip Menegis
# Managing Member
# this Corporation
# all documents
# the filing
# a chapter 11 voluntary
# bankruptcy case
# behalf
# the corporation
# It
# Philip Menegis
# Managing Member
# this Corporation
# all bankruptcy proceedings
# behalf
# the corporation
# all acts
# deeds
# all necessary documents
# behalf
# the corporation
# connection
# such bankruptcy case
# It
# Philip Menegis
# Managing Member
# this Corporation
# Gregory M. Messer
# attorney
# the law firm
# Law Office
# Gregory Messer
# the
# corporation
# such bankruptcy case
# Date
# August 2017                                                             Signed s/ Philip Menegis
# (c
# Best
# Case Bankruptcy
# 17-12211-smb                    Doc
# Main Document
# Pg
# 13
#
#                                                                      Resolution
# Board
# Directors
# PGB 38 LLC
# it
# the best interest
# this corporation
# a voluntary petition
# the the United States
# Bankruptcy Court
# pursuant
# Chapter
# Title
# the United States Code
# It
# Philip Menegis
# Managing Member
# this Corporation
# all documents
# the filing
# a chapter 11 voluntary
# bankruptcy case
# behalf
# the corporation
# It
# Philip Menegis
# Managing Member
# this Corporation
# all bankruptcy proceedings
# behalf
# the corporation
# all acts
# deeds
# all necessary documents
# behalf
# the corporation
# connection
# such bankruptcy case
# It
# Philip Menegis
# Managing Member
# this Corporation
# Gregory M. Messer
# attorney
# the law firm
# Law Office
# Gregory Messer
# the
# corporation
# such bankruptcy case
# Date
# s/ Philip Menegis
# Philip Menegis
# Date
# (c
# LLC - www.bestcase.com
# Best Case Bankruptcy

# %%
# Entities
for ent in doc.ents:
    if ent.label_ == "ORG":
        print(ent.text, ent.label_)
# Out:
# Instructions for Bankruptcy Forms for Non-Individuals ORG
# PGB ORG
# LLC
#
# 2 ORG
# EIN ORG
# City, State & ZIP Code                           ORG
# City, State & ZIP ORG
# County                                                           ORG
# City, State & ZIP Code
#
#
# 5 ORG
# Limited Liability Company ORG
# LLC ORG
# Limited Liability Partnership ( ORG
# LLP ORG
# LLP ORG
# LLC ORG
# Health Care Business ORG
# 101(27A ORG
# Single Asset Real Estate ORG
# North American Industry Classification System ORG
# Securities ORG
# Voluntary Petition for Non-Individuals Filing ORG
# PGB ORG
# LLC                                                                                 ORG
# LLC ORG
# United States Code ORG
# MM / DD / YYYY ORG
# State
#
#
#
#
# Official Form 201 ORG
# Voluntary Petition for Non-Individuals Filing for Bankruptcy ORG
# LLC
#
#   ORG
# United States Bankruptcy Court ORG
# Non-Individual Debtors ORG
# Philip Menegis ORG
# Non-Individual Debtors
# Software Copyright ORG
# LLC ORG
# PGB ORG
# LLC ORG
# United States Bankruptcy Court ORG
# YORK ORG
# Con Edison                                                                              ORG
# Internal Revenue ORG
# Treasury ORG
# Holtsville ORG
# Kimco 1572 Corp                                                 Commercial Lease ORG
# ST. ORG
# Taxation & Finance ORG
# WA Harriman ORG
# Campus
#  Albany ORG
# NYC Department ORG
# LLC ORG
# United States Bankruptcy Court ORG
# LLC ORG
# Fed ORG
# Bankr ORG
# Office of Gregory Messer ORG
# Office of Gregory Messer ORG
# LLC ORG
# United States Bankruptcy Court ORG
# Debtor(s ORG
# Ocean Pkwy
#  Brooklyn ORG
# LLC ORG
# United States Bankruptcy Court ORG
# LLC ORG
# Debtor(s ORG
# Philip Menegis/Managing ORG
# Signer/ ORG
# LLC ORG
# EMMANUELLI & PILOTTI ORG
# ESQS ORG
# BRONX ORG
# INTERNAL REVENUE SERVICE
#                             ORG
# TREASURY ORG
# KIMCO 1572 CORP
#                             ORG
# ST. ORG
# FORT LEE ORG
# NJ 07024 ORG
# NYC DEPARTMENT OF FINANCE ORG
# TLE ASSOCIATES, INC ORG
# PO ORG
# United States Bankruptcy Court ORG
# LLC ORG
# LLC ORG
# PGB ORG
# LLC ORG
# Office of Gregory Messer ORG
# Office of Gregory Messer ORG
# LLC ORG
# United States Bankruptcy Court ORG
# LLC ORG
# STATEMENT REGARDING AUTHORITY ORG
# PGB ORG
# LLC ORG
# the Board of Directors ORG
# Law Office of Gregory Messer ORG
# LLC ORG
# Board of Directors ORG
# PGB ORG
# Law Office of Gregory Messer ORG
# LLC ORG
